# %%
import json
import pandas as pd
from collections import defaultdict, namedtuple

Metrics = namedtuple('Metrics', 'tp fp fn prec rec fscore')

# Tokenize the label and prediction into word/tag pairs
def tokenize_label_pred(text):
    print(text)
    return [(token.split('/')[-2], token.split('/')[-1]) for token in text.strip().split() if len(token.split("/")) > 1]

def calculate_metrics(correct, guessed, total):
    tp, fp, fn = correct, guessed-correct, total-correct
    p = 0 if tp + fp == 0 else 1.*tp / (tp + fp)
    r = 0 if tp + fn == 0 else 1.*tp / (tp + fn)
    f = 0 if p + r == 0 else 2 * p * r / (p + r)
    return Metrics(tp, fp, fn, p, r, f)

# Re-loading the new test labels and results
test_labels_path_new = 'test_with_labels.txt'
results_path_new = 'results-zeroshot-attempt-1.json'

# Reading the new test labels
with open(test_labels_path_new, 'r', encoding='utf-8') as f:
    ground_truth = f.readlines()

# Reading the new results
with open(results_path_new, 'r', encoding='utf-8') as f:
    predictions = json.load(f)

precs, recs, fscores = [], [], []
# Iterate through each label and prediction
for num, label in enumerate(ground_truth):
    # Initialize counters
    true_positives = 0
    true_negatives = 0
    false_positives = 0
    false_negatives = 0
    
    correct = 0
    id_ = num + 1
    print(f"######### {id_} ##############")
    
    # Tokenize the label and prediction
    label_tokens = tokenize_label_pred(label.strip())
    prediction_tokens = tokenize_label_pred(predictions[str(id_)].strip())
    
    # Keep track of words that have been seen in predictions
    seen_in_prediction = set()
    unknown = set()
    print(label_tokens)
    total = len(label_tokens)
    guessed = len(prediction_tokens)
    print("Total predictions", len(prediction_tokens))
    print("Total ground truth", len(label_tokens))
    for e_token, c_token in prediction_tokens:
        # Check if the prediction word exists in the label tokens
        if (e_token, c_token) in label_tokens:
            p_token = (e_token, c_token)
            print("Correct:", p_token)
            true_positives += 1
            correct += 1
            seen_in_prediction.add(p_token)  # Mark this token as seen
        else:
            words_label = [token[0] for token in label_tokens]
            unknown.add(e_token)
            #print(e_token, words_label)
            if e_token not in words_label:
                p_token = (e_token, c_token)
                #print("Unknown:", p_token)
                true_negatives +=1
    
    # Now, check for any false negatives (i.e., tokens that should be in the prediction but are missing)
    for l_token in label_tokens:
        if l_token not in seen_in_prediction:
            le_token, _ = l_token 
            if le_token in unknown:
                #print("Incorrect:", l_token)
                false_negatives += 1
            else:
                #print("Missing tokens:", l_token)
                false_positives += 1

    # Final counts
    #print(f"True Positives: {true_positives}")
    #print(f"True Negatives: {true_negatives}")
    #print(f"False Positive: {false_positives}")
    #print(f"False Negatives: {false_negatives}")

    print(f"Correct: {correct}", f"Guessed: {guessed}", f"Total: {total}")
    _, _, _, prec, rec, fscore = calculate_metrics(correct, guessed, total)
    precs.append(prec)
    recs.append(rec)
    fscores.append(fscore)
avg_precs = sum(precs)/len(precs)
avg_recs = sum(recs)/len(recs)
avg_fscores = sum(fscores)/len(fscores)
print("Total records test set", len(ground_truth))
print("Average precision", avg_precs)
print("Average Recall", avg_recs)
print("Average F1 score", avg_fscores)
# Out:
# ######### 1 ##############
# Tidak/O ada/O sesuatu/O yang/O lebih/O kecil/O dan/O yang/O lebih/O besar/O daripada/O itu/O ,/O kecuali/O semua/O tercatat/O dalam/O kitab/O yang/O nyata/O (/O Lauh/O Mahfuz/O )/O ./O
# Kitab yang nyata (Lauh Mahfuz) - HolyBook
# [('Tidak', 'O'), ('ada', 'O'), ('sesuatu', 'O'), ('yang', 'O'), ('lebih', 'O'), ('kecil', 'O'), ('dan', 'O'), ('yang', 'O'), ('lebih', 'O'), ('besar', 'O'), ('daripada', 'O'), ('itu', 'O'), (',', 'O'), ('kecuali', 'O'), ('semua', 'O'), ('tercatat', 'O'), ('dalam', 'O'), ('kitab', 'O'), ('yang', 'O'), ('nyata', 'O'), ('(', 'O'), ('Lauh', 'O'), ('Mahfuz', 'O'), (')', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 25
# Correct: 0 Guessed: 0 Total: 25
# ######### 2 ##############
# Ketahuilah/O bahwa/O sesungguhnya/O (/O bagi/O )/O para/O wali/O Allah/Allah itu/O tidak/O ada/O rasa/O takut/O yang/O menimpa/O mereka/O dan/O mereka/O pun/O tidak/O bersedih/O ./O
# wali Allah/O
# [('Ketahuilah', 'O'), ('bahwa', 'O'), ('sesungguhnya', 'O'), ('(', 'O'), ('bagi', 'O'), (')', 'O'), ('para', 'O'), ('wali', 'O'), ('Allah', 'Allah'), ('itu', 'O'), ('tidak', 'O'), ('ada', 'O'), ('rasa', 'O'), ('takut', 'O'), ('yang', 'O'), ('menimpa', 'O'), ('mereka', 'O'), ('dan', 'O'), ('mereka', 'O'), ('pun', 'O'), ('tidak', 'O'), ('bersedih', 'O'), ('.', 'O')]
# Total predictions 1
# Total ground truth 23
# Correct: 0 Guessed: 1 Total: 23
# ######### 3 ##############
# (/O Mereka/O adalah/O )/O orang-orang/O yang/O beriman/O dan/O selalu/O bertakwa/O ./O
# 'orang-orang' Person
# [('(', 'O'), ('Mereka', 'O'), ('adalah', 'O'), (')', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('beriman', 'O'), ('dan', 'O'), ('selalu', 'O'), ('bertakwa', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 11
# Correct: 0 Guessed: 0 Total: 11
# ######### 4 ##############
# Bagi/O mereka/O berita/O gembira/O di/O dalam/O kehidupan/O di/O dunia/O dan/O di/O akhirat/O ./O
# dalam -> GeographicalLocation
# di -> GeographicalLocation
# akhirat -> AfterlifeLocation
# [('Bagi', 'O'), ('mereka', 'O'), ('berita', 'O'), ('gembira', 'O'), ('di', 'O'), ('dalam', 'O'), ('kehidupan', 'O'), ('di', 'O'), ('dunia', 'O'), ('dan', 'O'), ('di', 'O'), ('akhirat', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 13
# Correct: 0 Guessed: 0 Total: 13
# ######### 5 ##############
# Tidak/O ada/O perubahan/O bagi/O kalimat-kalimat/O (/O ketetapan/O dan/O janji/O )/O Allah/Allah ./O
# Allah/Religion
# [('Tidak', 'O'), ('ada', 'O'), ('perubahan', 'O'), ('bagi', 'O'), ('kalimat-kalimat', 'O'), ('(', 'O'), ('ketetapan', 'O'), ('dan', 'O'), ('janji', 'O'), (')', 'O'), ('Allah', 'Allah'), ('.', 'O')]
# Total predictions 1
# Total ground truth 12
# Correct: 0 Guessed: 1 Total: 12
# ######### 6 ##############
# Demikian/O itulah/O kemenangan/O yang/O agung/O ./O
# No entities found.
# [('Demikian', 'O'), ('itulah', 'O'), ('kemenangan', 'O'), ('yang', 'O'), ('agung', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 6
# Correct: 0 Guessed: 0 Total: 6
# ######### 7 ##############
# Janganlah/O engkau/O (/O Nabi/O Muhammad/Messenger )/O sedih/O oleh/O perkataan/O mereka/O ./O
# (Nabi Muhammad, Person)
# [('Janganlah', 'O'), ('engkau', 'O'), ('(', 'O'), ('Nabi', 'O'), ('Muhammad', 'Messenger'), (')', 'O'), ('sedih', 'O'), ('oleh', 'O'), ('perkataan', 'O'), ('mereka', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 11
# Correct: 0 Guessed: 0 Total: 11
# ######### 8 ##############
# Sesungguhnya/O kekuasaan/O itu/O seluruhnya/O milik/O Allah/Allah ./O
# "Allah/Religion"
# [('Sesungguhnya', 'O'), ('kekuasaan', 'O'), ('itu', 'O'), ('seluruhnya', 'O'), ('milik', 'O'), ('Allah', 'Allah'), ('.', 'O')]
# Total predictions 1
# Total ground truth 7
# Correct: 0 Guessed: 1 Total: 7
# ######### 9 ##############
# Dia/O Maha/O Mendengar/O lagi/O Maha/O Mengetahui/O ./O
# Dia - Person
# Maha - Person
# [('Dia', 'O'), ('Maha', 'O'), ('Mendengar', 'O'), ('lagi', 'O'), ('Maha', 'O'), ('Mengetahui', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 7
# Correct: 0 Guessed: 0 Total: 7
# ######### 10 ##############
# Ketahuilah/O bahwa/O sesungguhnya/O milik/O Allahlah/O siapa/O yang/O ada/O di/O langit/O dan/O siapa/O yang/O ada/O di/O bumi/AstronomicalBody ./O
# siapa yang ada di langit - AstronomicalBody
# siapa yang ada di bumi - GeographicalLocation
# Allah - Allah
# [('Ketahuilah', 'O'), ('bahwa', 'O'), ('sesungguhnya', 'O'), ('milik', 'O'), ('Allahlah', 'O'), ('siapa', 'O'), ('yang', 'O'), ('ada', 'O'), ('di', 'O'), ('langit', 'O'), ('dan', 'O'), ('siapa', 'O'), ('yang', 'O'), ('ada', 'O'), ('di', 'O'), ('bumi', 'AstronomicalBody'), ('.', 'O')]
# Total predictions 0
# Total ground truth 17
# Correct: 0 Guessed: 0 Total: 17
# ######### 11 ##############
# Orang-orang/O yang/O menyeru/O sekutu-sekutu/O selain/O Allah/Allah tidaklah/O mengikuti/O (/O suatu/O kebenaran/O )/O ./O
# Orang-orang/O, Allah/Allah, suatu/Event
# [('Orang-orang', 'O'), ('yang', 'O'), ('menyeru', 'O'), ('sekutu-sekutu', 'O'), ('selain', 'O'), ('Allah', 'Allah'), ('tidaklah', 'O'), ('mengikuti', 'O'), ('(', 'O'), ('suatu', 'O'), ('kebenaran', 'O'), (')', 'O'), ('.', 'O')]
# Total predictions 3
# Total ground truth 13
# Correct: 0 Guessed: 3 Total: 13
# ######### 12 ##############
# Mereka/O hanya/O mengikuti/O persangkaan/O belaka/O dan/O mereka/O hanyalah/O menduga-duga/O ./O
# No entity mentions found in the given sentence.
# [('Mereka', 'O'), ('hanya', 'O'), ('mengikuti', 'O'), ('persangkaan', 'O'), ('belaka', 'O'), ('dan', 'O'), ('mereka', 'O'), ('hanyalah', 'O'), ('menduga-duga', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 10
# Correct: 0 Guessed: 0 Total: 10
# ######### 13 ##############
# Dialah/O yang/O menjadikan/O malam/O bagimu/O agar/O kamu/O beristirahat/O padanya/O dan/O (/O menjadikan/O )/O siang/O terang/O benderang/O ./O
# Dialah/O, malam/O, siang/O
# [('Dialah', 'O'), ('yang', 'O'), ('menjadikan', 'O'), ('malam', 'O'), ('bagimu', 'O'), ('agar', 'O'), ('kamu', 'O'), ('beristirahat', 'O'), ('padanya', 'O'), ('dan', 'O'), ('(', 'O'), ('menjadikan', 'O'), (')', 'O'), ('siang', 'O'), ('terang', 'O'), ('benderang', 'O'), ('.', 'O')]
# Total predictions 3
# Total ground truth 17
# Correct: ('siang', 'O')
# Correct: 1 Guessed: 3 Total: 17
# ######### 14 ##############
# Sesungguhnya/O pada/O yang/O demikian/O itu/O benar-benar/O terdapat/O tanda-tanda/O (/O kebesaran/O Allah/Allah )/O bagi/O kaum/O yang/O (/O mau/O )/O mendengar/O ./O
# ('kaum yang mau mendengar', 'GeographicalLocation')
# [('Sesungguhnya', 'O'), ('pada', 'O'), ('yang', 'O'), ('demikian', 'O'), ('itu', 'O'), ('benar-benar', 'O'), ('terdapat', 'O'), ('tanda-tanda', 'O'), ('(', 'O'), ('kebesaran', 'O'), ('Allah', 'Allah'), (')', 'O'), ('bagi', 'O'), ('kaum', 'O'), ('yang', 'O'), ('(', 'O'), ('mau', 'O'), (')', 'O'), ('mendengar', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 20
# Correct: 0 Guessed: 0 Total: 20
# ######### 15 ##############
# Mereka/O (/O yang/O menyekutukan/O Allah/Allah )/O berkata/O ,/O “/O Allah/Allah mengangkat/O anak/O ./O
# Mereka/O
# yang/O
# Allah/Religion
# mengangkat/O
# anak/O
# [('Mereka', 'O'), ('(', 'O'), ('yang', 'O'), ('menyekutukan', 'O'), ('Allah', 'Allah'), (')', 'O'), ('berkata', 'O'), (',', 'O'), ('“', 'O'), ('Allah', 'Allah'), ('mengangkat', 'O'), ('anak', 'O'), ('.', 'O')]
# Total predictions 5
# Total ground truth 13
# Correct: ('Mereka', 'O')
# Correct: ('yang', 'O')
# Correct: ('mengangkat', 'O')
# Correct: ('anak', 'O')
# Correct: 4 Guessed: 5 Total: 13
# ######### 16 ##############
# ”/O Mahasuci/O Dia/O ./O
# Mahasuci O
# [('”', 'O'), ('Mahasuci', 'O'), ('Dia', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 4
# Correct: 0 Guessed: 0 Total: 4
# ######### 17 ##############
# Dialah/O Yang Mahakaya/Allah ./O
# Dialah Yang Mahakaya.
# [('Dialah', 'O'), ('Mahakaya', 'Allah'), ('.', 'O')]
# Total predictions 0
# Total ground truth 3
# Correct: 0 Guessed: 0 Total: 3
# ######### 18 ##############
# Milik-Nyalah/O apa/O yang/O ada/O di/O langit/O dan/O apa/O yang/O ada/O di/O bumi/AstronomicalBody ./O
# Milik-Nyalah O
# apa yang ada di langit O
# apa yang ada di bumi O
# [('Milik-Nyalah', 'O'), ('apa', 'O'), ('yang', 'O'), ('ada', 'O'), ('di', 'O'), ('langit', 'O'), ('dan', 'O'), ('apa', 'O'), ('yang', 'O'), ('ada', 'O'), ('di', 'O'), ('bumi', 'AstronomicalBody'), ('.', 'O')]
# Total predictions 0
# Total ground truth 13
# Correct: 0 Guessed: 0 Total: 13
# ######### 19 ##############
# Kamu/O tidak/O mempunyai/O alasan/O kuat/O tentang/O ini/O ./O
# No entities found in the sentence.
# [('Kamu', 'O'), ('tidak', 'O'), ('mempunyai', 'O'), ('alasan', 'O'), ('kuat', 'O'), ('tentang', 'O'), ('ini', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 8
# Correct: 0 Guessed: 0 Total: 8
# ######### 20 ##############
# Pantaskah/O kamu/O mengatakan/O tentang/O Allah/Allah apa/O yang/O tidak/O kamu/O ketahui/O ?/O Katakanlah/O (/O Nabi/O Muhammad/Messenger )/O ,/O “/O Sesungguhnya/O orang-orang/O yang/O mengada-adakan/O kebohongan/O terhadap/O Allah/Allah tidak/O akan/O beruntung/O ./O
# Nabi Muhammad, Prophet
# Allah, Allah
# [('Pantaskah', 'O'), ('kamu', 'O'), ('mengatakan', 'O'), ('tentang', 'O'), ('Allah', 'Allah'), ('apa', 'O'), ('yang', 'O'), ('tidak', 'O'), ('kamu', 'O'), ('ketahui', 'O'), ('?', 'O'), ('Katakanlah', 'O'), ('(', 'O'), ('Nabi', 'O'), ('Muhammad', 'Messenger'), (')', 'O'), (',', 'O'), ('“', 'O'), ('Sesungguhnya', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('mengada-adakan', 'O'), ('kebohongan', 'O'), ('terhadap', 'O'), ('Allah', 'Allah'), ('tidak', 'O'), ('akan', 'O'), ('beruntung', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 29
# Correct: 0 Guessed: 0 Total: 29
# ######### 21 ##############
# ”/O (/O Bagi/O mereka/O )/O kesenangan/O (/O sesaat/O )/O ketika/O di/O dunia/O ,/O selanjutnya/O kepada/O Kamilah/O tempat/O mereka/O kembali/O ,/O kemudian/O Kami/O jadikan/O mereka/O merasakan/O azab/O yang/O keras/O karena/O mereka/O selalu/O kufur/O ./O
# Bagi - O
# kesenangan - O
# sesaat - O
# ketika - O
# di - O
# dunia - GeographicalLocation
# selanjutnya - O
# Kami - Person
# Kamilah - Person
# tempat - O
# mereka - Person
# kembali - O
# kemudian - O
# Kami - Person
# jadikan - O
# mereka - Person
# rasakan - O
# azab - O
# yang - O
# keras - O
# karena - O
# mereka - Person
# selalu - O
# kufur - O
# [('”', 'O'), ('(', 'O'), ('Bagi', 'O'), ('mereka', 'O'), (')', 'O'), ('kesenangan', 'O'), ('(', 'O'), ('sesaat', 'O'), (')', 'O'), ('ketika', 'O'), ('di', 'O'), ('dunia', 'O'), (',', 'O'), ('selanjutnya', 'O'), ('kepada', 'O'), ('Kamilah', 'O'), ('tempat', 'O'), ('mereka', 'O'), ('kembali', 'O'), (',', 'O'), ('kemudian', 'O'), ('Kami', 'O'), ('jadikan', 'O'), ('mereka', 'O'), ('merasakan', 'O'), ('azab', 'O'), ('yang', 'O'), ('keras', 'O'), ('karena', 'O'), ('mereka', 'O'), ('selalu', 'O'), ('kufur', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 33
# Correct: 0 Guessed: 0 Total: 33
# ######### 22 ##############
# Bacakanlah/O (/O sampaikanlah/O wahai/O Nabi/O Muhammad/Messenger )/O kepada/O mereka/O berita/O penting/O (/O tentang/O )/O Nuh/Messenger ketika/O dia/O berkata/O kepada/O kaumnya/O ,/O “/O Wahai/O kaumku/O ,/O jika/O terasa/O berat/O bagi/O kamu/O keberadaanku/O tinggal/O (/O bersamamu/O )/O dan/O peringatanku/O dengan/O ayat-ayat/O Allah/Allah ,/O kepada/O Allahlah/O aku/O bertawakal/O ./O
# Nabi Muhammad/Person
# Nuh/Person
# Allah/Religion
# [('Bacakanlah', 'O'), ('(', 'O'), ('sampaikanlah', 'O'), ('wahai', 'O'), ('Nabi', 'O'), ('Muhammad', 'Messenger'), (')', 'O'), ('kepada', 'O'), ('mereka', 'O'), ('berita', 'O'), ('penting', 'O'), ('(', 'O'), ('tentang', 'O'), (')', 'O'), ('Nuh', 'Messenger'), ('ketika', 'O'), ('dia', 'O'), ('berkata', 'O'), ('kepada', 'O'), ('kaumnya', 'O'), (',', 'O'), ('“', 'O'), ('Wahai', 'O'), ('kaumku', 'O'), (',', 'O'), ('jika', 'O'), ('terasa', 'O'), ('berat', 'O'), ('bagi', 'O'), ('kamu', 'O'), ('keberadaanku', 'O'), ('tinggal', 'O'), ('(', 'O'), ('bersamamu', 'O'), (')', 'O'), ('dan', 'O'), ('peringatanku', 'O'), ('dengan', 'O'), ('ayat-ayat', 'O'), ('Allah', 'Allah'), (',', 'O'), ('kepada', 'O'), ('Allahlah', 'O'), ('aku', 'O'), ('bertawakal', 'O'), ('.', 'O')]
# Total predictions 3
# Total ground truth 46
# Correct: 0 Guessed: 3 Total: 46
# ######### 23 ##############
# Oleh/O karena/O itu/O ,/O bulatkanlah/O keputusanmu/O dan/O kumpulkanlah/O sekutu-sekutumu/O (/O untuk/O membinasakanku/O )/O ,/O selanjutnya/O janganlah/O keputusanmu/O itu/O dirahasiakan/O ./O
# * Oleh karena itu, (O)
# * keputusanmu (O)
# * sekutu-sekutumu (O)
# * membinasakanku (O)
# * keputusanmu (O)
# * dirahasiakan (O)
# [('Oleh', 'O'), ('karena', 'O'), ('itu', 'O'), (',', 'O'), ('bulatkanlah', 'O'), ('keputusanmu', 'O'), ('dan', 'O'), ('kumpulkanlah', 'O'), ('sekutu-sekutumu', 'O'), ('(', 'O'), ('untuk', 'O'), ('membinasakanku', 'O'), (')', 'O'), (',', 'O'), ('selanjutnya', 'O'), ('janganlah', 'O'), ('keputusanmu', 'O'), ('itu', 'O'), ('dirahasiakan', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 20
# Correct: 0 Guessed: 0 Total: 20
# ######### 24 ##############
# Kemudian/O ,/O bertindaklah/O terhadap/O diriku/O dan/O janganlah/O kamu/O tunda-tunda/O (/O tindakan/O itu/O )/O kepadaku/O ./O
# 'bertindaklah' 'O'
# 'diriku' 'Person'
# 'kamu' 'Person'
# 'kpadaku' 'Person'
# [('Kemudian', 'O'), (',', 'O'), ('bertindaklah', 'O'), ('terhadap', 'O'), ('diriku', 'O'), ('dan', 'O'), ('janganlah', 'O'), ('kamu', 'O'), ('tunda-tunda', 'O'), ('(', 'O'), ('tindakan', 'O'), ('itu', 'O'), (')', 'O'), ('kepadaku', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 15
# Correct: 0 Guessed: 0 Total: 15
# ######### 25 ##############
# Jika/O kamu/O berpaling/O (/O dari/O peringatanku/O )/O ,/O aku/O tidak/O meminta/O imbalan/O sedikit/O pun/O darimu/O ./O
# * berpaling (O)
# * peringatanku (O)
# * aku (Person)
# * darimu (O)
# [('Jika', 'O'), ('kamu', 'O'), ('berpaling', 'O'), ('(', 'O'), ('dari', 'O'), ('peringatanku', 'O'), (')', 'O'), (',', 'O'), ('aku', 'O'), ('tidak', 'O'), ('meminta', 'O'), ('imbalan', 'O'), ('sedikit', 'O'), ('pun', 'O'), ('darimu', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 16
# Correct: 0 Guessed: 0 Total: 16
# ######### 26 ##############
# Imbalanku/O tidak/O lain/O hanyalah/O dari/O Allah/Allah dan/O aku/O diperintah/O agar/O aku/O masuk/O ke/O dalam/O golongan/O orang-orang/O muslim/O ./O
# Imbalanku/O, tidak lain/O, dari Allah/Religion, dan/O, aku/Person, diperintah/O, agar/O, aku/Person, masuk/O, ke/O, dalam/O, golongan/O, orang-orang/O, muslim/Religion.
# [('Imbalanku', 'O'), ('tidak', 'O'), ('lain', 'O'), ('hanyalah', 'O'), ('dari', 'O'), ('Allah', 'Allah'), ('dan', 'O'), ('aku', 'O'), ('diperintah', 'O'), ('agar', 'O'), ('aku', 'O'), ('masuk', 'O'), ('ke', 'O'), ('dalam', 'O'), ('golongan', 'O'), ('orang-orang', 'O'), ('muslim', 'O'), ('.', 'O')]
# Total predictions 14
# Total ground truth 18
# Correct: 0 Guessed: 14 Total: 18
# ######### 27 ##############
# ”/O Mereka/O mendustakannya/O (/O Nuh/Messenger )/O ./O
# Nuh/Person
# [('”', 'O'), ('Mereka', 'O'), ('mendustakannya', 'O'), ('(', 'O'), ('Nuh', 'Messenger'), (')', 'O'), ('.', 'O')]
# Total predictions 1
# Total ground truth 7
# Correct: 0 Guessed: 1 Total: 7
# ######### 28 ##############
# Lalu/O ,/O Kami/O selamatkan/O dia/O dan/O orang-orang/O yang/O bersamanya/O di/O dalam/O bahtera/O serta/O Kami/O jadikan/O mereka/O sebagai/O generasi/O penerus/O dan/O Kami/O tenggelamkan/O orang-orang/O yang/O mendustakan/O ayat-ayat/O Kami/O ./O
# Kami/O
# Lalu/O
# dia/O
# orang-orang/O
# bahtera/O
# Kami/O
# mereka/O
# generasi/O
# penerus/O
# Kami/O
# orang-orang/O
# ayah-ayah/O
# [('Lalu', 'O'), (',', 'O'), ('Kami', 'O'), ('selamatkan', 'O'), ('dia', 'O'), ('dan', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('bersamanya', 'O'), ('di', 'O'), ('dalam', 'O'), ('bahtera', 'O'), ('serta', 'O'), ('Kami', 'O'), ('jadikan', 'O'), ('mereka', 'O'), ('sebagai', 'O'), ('generasi', 'O'), ('penerus', 'O'), ('dan', 'O'), ('Kami', 'O'), ('tenggelamkan', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('mendustakan', 'O'), ('ayat-ayat', 'O'), ('Kami', 'O'), ('.', 'O')]
# Total predictions 12
# Total ground truth 28
# Correct: ('Kami', 'O')
# Correct: ('Lalu', 'O')
# Correct: ('dia', 'O')
# Correct: ('orang-orang', 'O')
# Correct: ('bahtera', 'O')
# Correct: ('Kami', 'O')
# Correct: ('mereka', 'O')
# Correct: ('generasi', 'O')
# Correct: ('penerus', 'O')
# Correct: ('Kami', 'O')
# Correct: ('orang-orang', 'O')
# Correct: 11 Guessed: 12 Total: 28
# ######### 29 ##############
# Perhatikanlah/O bagaimana/O kesudahan/O orang-orang/O yang/O diberi/O peringatan/O itu/O ./O
# 'orang-orang' Person
# [('Perhatikanlah', 'O'), ('bagaimana', 'O'), ('kesudahan', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('diberi', 'O'), ('peringatan', 'O'), ('itu', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 9
# Correct: 0 Guessed: 0 Total: 9
# ######### 30 ##############
# Kemudian/O ,/O Kami/O mengutus/O setelahnya/O (/O Nuh/Messenger )/O beberapa/O rasul/O kepada/O kaum/O mereka/O (/O umat/O masing-masing/O )/O ,/O maka/O rasul-rasul/O itu/O datang/O kepada/O mereka/O dengan/O membawa/O bukti-bukti/O yang/O nyata/O ,/O tetapi/O mereka/O tidak/O mau/O beriman/O karena/O mereka/O dahulu/O telah/O (/O biasa/O )/O mendustakannya/O ./O
# Nuh - Person
# umat masing-masing - GeographicalLocation
# rasul - Messenger
# rasul-rasul - Messenger
# Nuh - Person
# [('Kemudian', 'O'), (',', 'O'), ('Kami', 'O'), ('mengutus', 'O'), ('setelahnya', 'O'), ('(', 'O'), ('Nuh', 'Messenger'), (')', 'O'), ('beberapa', 'O'), ('rasul', 'O'), ('kepada', 'O'), ('kaum', 'O'), ('mereka', 'O'), ('(', 'O'), ('umat', 'O'), ('masing-masing', 'O'), (')', 'O'), (',', 'O'), ('maka', 'O'), ('rasul-rasul', 'O'), ('itu', 'O'), ('datang', 'O'), ('kepada', 'O'), ('mereka', 'O'), ('dengan', 'O'), ('membawa', 'O'), ('bukti-bukti', 'O'), ('yang', 'O'), ('nyata', 'O'), (',', 'O'), ('tetapi', 'O'), ('mereka', 'O'), ('tidak', 'O'), ('mau', 'O'), ('beriman', 'O'), ('karena', 'O'), ('mereka', 'O'), ('dahulu', 'O'), ('telah', 'O'), ('(', 'O'), ('biasa', 'O'), (')', 'O'), ('mendustakannya', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 44
# Correct: 0 Guessed: 0 Total: 44
# ######### 31 ##############
# Demikianlah/O Kami/O mengunci/O hati/O orang-orang/O yang/O melampaui/O batas/O ./O
# Demikianlah Kami (O)
# mengunci (O)
# hati (O)
# orang-orang (O)
# yang (O)
# melampaui (O)
# bats (O)
# batas (O)
# [('Demikianlah', 'O'), ('Kami', 'O'), ('mengunci', 'O'), ('hati', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('melampaui', 'O'), ('batas', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 9
# Correct: 0 Guessed: 0 Total: 9
# ######### 32 ##############
# Kemudian/O ,/O setelah/O mereka/O Kami/O mengutus/O Musa/Messenger dan/O Harun/Prophet kepada/O Fir‘aun/Person dan/O para/O pemuka/O kaumnya/O ,/O dengan/O membawa/O tanda-tanda/O (/O kekuasaan/O )/O Kami/O ./O
# Musa - Person
# Harun - Person
# Fir‘aun - Person
# [('Kemudian', 'O'), (',', 'O'), ('setelah', 'O'), ('mereka', 'O'), ('Kami', 'O'), ('mengutus', 'O'), ('Musa', 'Messenger'), ('dan', 'O'), ('Harun', 'Prophet'), ('kepada', 'O'), ('Fir‘aun', 'Person'), ('dan', 'O'), ('para', 'O'), ('pemuka', 'O'), ('kaumnya', 'O'), (',', 'O'), ('dengan', 'O'), ('membawa', 'O'), ('tanda-tanda', 'O'), ('(', 'O'), ('kekuasaan', 'O'), (')', 'O'), ('Kami', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 24
# Correct: 0 Guessed: 0 Total: 24
# ######### 33 ##############
# Lalu/O ,/O mereka/O menyombongkan/O diri/O dan/O mereka/O adalah/O kaum/O pendurhaka/O ./O
# kaum pendurhaka/GeographicalLocation
# [('Lalu', 'O'), (',', 'O'), ('mereka', 'O'), ('menyombongkan', 'O'), ('diri', 'O'), ('dan', 'O'), ('mereka', 'O'), ('adalah', 'O'), ('kaum', 'O'), ('pendurhaka', 'O'), ('.', 'O')]
# Total predictions 1
# Total ground truth 11
# Correct: 0 Guessed: 1 Total: 11
# ######### 34 ##############
# Ketika/O telah/O datang/O kepada/O mereka/O kebenaran/O (/O mukjizat/O )/O dari/O sisi/O Kami/O ,/O mereka/O berkata/O ,/O “/O Sesungguhnya/O ini/O benar-benar/O sihir/O yang/O nyata/O ./O
# mukjizat - Event
# [('Ketika', 'O'), ('telah', 'O'), ('datang', 'O'), ('kepada', 'O'), ('mereka', 'O'), ('kebenaran', 'O'), ('(', 'O'), ('mukjizat', 'O'), (')', 'O'), ('dari', 'O'), ('sisi', 'O'), ('Kami', 'O'), (',', 'O'), ('mereka', 'O'), ('berkata', 'O'), (',', 'O'), ('“', 'O'), ('Sesungguhnya', 'O'), ('ini', 'O'), ('benar-benar', 'O'), ('sihir', 'O'), ('yang', 'O'), ('nyata', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 24
# Correct: 0 Guessed: 0 Total: 24
# ######### 35 ##############
# ”/O Musa/Messenger berkata/O ,/O “/O Apakah/O (/O pantas/O )/O kamu/O mengatakan/O terhadap/O kebenaran/O (/O mukjizat/O )/O ketika/O ia/O datang/O kepadamu/O ,/O ‘sihirkah/O ini/O ?/O ’/O Padahal/O ,/O para/O penyihir/O itu/O tidaklah/O mendapat/O kemenangan/O ./O
# Musa/O
# sihirkah ini/O
# Mukjizat/HolyBook
# kepadamu/GeographicalLocation
# ia/Person
# Musa/Person
# [('”', 'O'), ('Musa', 'Messenger'), ('berkata', 'O'), (',', 'O'), ('“', 'O'), ('Apakah', 'O'), ('(', 'O'), ('pantas', 'O'), (')', 'O'), ('kamu', 'O'), ('mengatakan', 'O'), ('terhadap', 'O'), ('kebenaran', 'O'), ('(', 'O'), ('mukjizat', 'O'), (')', 'O'), ('ketika', 'O'), ('ia', 'O'), ('datang', 'O'), ('kepadamu', 'O'), (',', 'O'), ('‘sihirkah', 'O'), ('ini', 'O'), ('?', 'O'), ('’', 'O'), ('Padahal', 'O'), (',', 'O'), ('para', 'O'), ('penyihir', 'O'), ('itu', 'O'), ('tidaklah', 'O'), ('mendapat', 'O'), ('kemenangan', 'O'), ('.', 'O')]
# Total predictions 6
# Total ground truth 34
# Correct: ('ini', 'O')
# Correct: 1 Guessed: 6 Total: 34
# ######### 36 ##############
# ”/O Mereka/O berkata/O ,/O “/O Apakah/O engkau/O (/O Musa/Messenger )/O datang/O kepada/O kami/O untuk/O memalingkan/O kami/O dari/O apa/O yang/O kami/O dapati/O pada/O nenek/O moyang/O kami/O (/O menyembah/O berhala/O )/O ,/O dan/O agar/O kamu/O berdua/O (/O Musa/Messenger dan/O Harun/Prophet )/O mempunyai/O kekuasaan/O di/O bumi/AstronomicalBody (/O negeri/O Mesir/GeographicalLocation )/O ?/O Kami/O tidak/O akan/O beriman/O kepada/O kamu/O berdua/O ./O
# Musa - Person
# Harun - Person
# Musa - Person
# negeri Mesir - GeographicalLocation
# [('”', 'O'), ('Mereka', 'O'), ('berkata', 'O'), (',', 'O'), ('“', 'O'), ('Apakah', 'O'), ('engkau', 'O'), ('(', 'O'), ('Musa', 'Messenger'), (')', 'O'), ('datang', 'O'), ('kepada', 'O'), ('kami', 'O'), ('untuk', 'O'), ('memalingkan', 'O'), ('kami', 'O'), ('dari', 'O'), ('apa', 'O'), ('yang', 'O'), ('kami', 'O'), ('dapati', 'O'), ('pada', 'O'), ('nenek', 'O'), ('moyang', 'O'), ('kami', 'O'), ('(', 'O'), ('menyembah', 'O'), ('berhala', 'O'), (')', 'O'), (',', 'O'), ('dan', 'O'), ('agar', 'O'), ('kamu', 'O'), ('berdua', 'O'), ('(', 'O'), ('Musa', 'Messenger'), ('dan', 'O'), ('Harun', 'Prophet'), (')', 'O'), ('mempunyai', 'O'), ('kekuasaan', 'O'), ('di', 'O'), ('bumi', 'AstronomicalBody'), ('(', 'O'), ('negeri', 'O'), ('Mesir', 'GeographicalLocation'), (')', 'O'), ('?', 'O'), ('Kami', 'O'), ('tidak', 'O'), ('akan', 'O'), ('beriman', 'O'), ('kepada', 'O'), ('kamu', 'O'), ('berdua', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 56
# Correct: 0 Guessed: 0 Total: 56
# ######### 37 ##############
# ”/O Fir‘aun/Person berkata/O (/O kepada/O para/O pemuka/O kaumnya/O )/O ,/O “/O Datangkanlah/O kepadaku/O semua/O penyihir/O yang/O ulung/O !/O ”/O Ketika/O para/O penyihir/O itu/O datang/O ,/O Musa/Messenger berkata/O kepada/O mereka/O ,/O “/O Lemparkanlah/O apa/O yang/O hendak/O kamu/O lemparkan/O !/O ”/O Setelah/O mereka/O melemparkan/O (/O tali-temali/O )/O ,/O Musa/Messenger berkata/O ,/O “/O Apa/O yang/O kamu/O bawa/O itulah/O sihir/O ./O
# * Fir‘aun: Person
# * Musa: Prophet
# * Allah: HolyBook
# [('”', 'O'), ('Fir‘aun', 'Person'), ('berkata', 'O'), ('(', 'O'), ('kepada', 'O'), ('para', 'O'), ('pemuka', 'O'), ('kaumnya', 'O'), (')', 'O'), (',', 'O'), ('“', 'O'), ('Datangkanlah', 'O'), ('kepadaku', 'O'), ('semua', 'O'), ('penyihir', 'O'), ('yang', 'O'), ('ulung', 'O'), ('!', 'O'), ('”', 'O'), ('Ketika', 'O'), ('para', 'O'), ('penyihir', 'O'), ('itu', 'O'), ('datang', 'O'), (',', 'O'), ('Musa', 'Messenger'), ('berkata', 'O'), ('kepada', 'O'), ('mereka', 'O'), (',', 'O'), ('“', 'O'), ('Lemparkanlah', 'O'), ('apa', 'O'), ('yang', 'O'), ('hendak', 'O'), ('kamu', 'O'), ('lemparkan', 'O'), ('!', 'O'), ('”', 'O'), ('Setelah', 'O'), ('mereka', 'O'), ('melemparkan', 'O'), ('(', 'O'), ('tali-temali', 'O'), (')', 'O'), (',', 'O'), ('Musa', 'Messenger'), ('berkata', 'O'), (',', 'O'), ('“', 'O'), ('Apa', 'O'), ('yang', 'O'), ('kamu', 'O'), ('bawa', 'O'), ('itulah', 'O'), ('sihir', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 57
# Correct: 0 Guessed: 0 Total: 57
# ######### 38 ##############
# Sesungguhnya/O Allah/Allah akan/O membatalkan/O (/O mengalahkan/O )/O -nya/O ./O
# Allah/Religion
# [('Sesungguhnya', 'O'), ('Allah', 'Allah'), ('akan', 'O'), ('membatalkan', 'O'), ('(', 'O'), ('mengalahkan', 'O'), (')', 'O'), ('-nya', 'O'), ('.', 'O')]
# Total predictions 1
# Total ground truth 9
# Correct: 0 Guessed: 1 Total: 9
# ######### 39 ##############
# Sesungguhnya/O Allah/Allah tidak/O membiarkan/O perbuatan/O orang-orang/O yang/O berbuat/O kerusakan/O ./O
# Allah/Religion
# [('Sesungguhnya', 'O'), ('Allah', 'Allah'), ('tidak', 'O'), ('membiarkan', 'O'), ('perbuatan', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('berbuat', 'O'), ('kerusakan', 'O'), ('.', 'O')]
# Total predictions 1
# Total ground truth 10
# Correct: 0 Guessed: 1 Total: 10
# ######### 40 ##############
# Allah/Allah akan/O mengukuhkan/O kebenaran/O dengan/O ketetapan-ketetapan-Nya/O ,/O walaupun/O para/O pendurhaka/O tidak/O menyukainya/O ./O
# Allah/Religion
# [('Allah', 'Allah'), ('akan', 'O'), ('mengukuhkan', 'O'), ('kebenaran', 'O'), ('dengan', 'O'), ('ketetapan-ketetapan-Nya', 'O'), (',', 'O'), ('walaupun', 'O'), ('para', 'O'), ('pendurhaka', 'O'), ('tidak', 'O'), ('menyukainya', 'O'), ('.', 'O')]
# Total predictions 1
# Total ground truth 13
# Correct: 0 Guessed: 1 Total: 13
# ######### 41 ##############
# Tidak/O ada/O yang/O beriman/O kepada/O Musa/Messenger selain/O keturunan/O dari/O kaumnya/O disertai/O ketakutan/O kepada/O Fir‘aun/Person dan/O para/O pemuka/O kaumnya/O yang/O akan/O menyiksa/O mereka/O ./O
# Musa - Person
# Fir'aun - Person
# [('Tidak', 'O'), ('ada', 'O'), ('yang', 'O'), ('beriman', 'O'), ('kepada', 'O'), ('Musa', 'Messenger'), ('selain', 'O'), ('keturunan', 'O'), ('dari', 'O'), ('kaumnya', 'O'), ('disertai', 'O'), ('ketakutan', 'O'), ('kepada', 'O'), ('Fir‘aun', 'Person'), ('dan', 'O'), ('para', 'O'), ('pemuka', 'O'), ('kaumnya', 'O'), ('yang', 'O'), ('akan', 'O'), ('menyiksa', 'O'), ('mereka', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 23
# Correct: 0 Guessed: 0 Total: 23
# ######### 42 ##############
# Sesungguhnya/O Fir‘aun/Person benar-benar/O sewenang-wenang/O di/O bumi/AstronomicalBody ./O
# Fir‘aun/O
# [('Sesungguhnya', 'O'), ('Fir‘aun', 'Person'), ('benar-benar', 'O'), ('sewenang-wenang', 'O'), ('di', 'O'), ('bumi', 'AstronomicalBody'), ('.', 'O')]
# Total predictions 1
# Total ground truth 7
# Correct: 0 Guessed: 1 Total: 7
# ######### 43 ##############
# Sesungguhnya/O ia/O benar-benar/O termasuk/O orang-orang/O yang/O melampaui/O batas/O ./O
# O
# [('Sesungguhnya', 'O'), ('ia', 'O'), ('benar-benar', 'O'), ('termasuk', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('melampaui', 'O'), ('batas', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 9
# Correct: 0 Guessed: 0 Total: 9
# ######### 44 ##############
# Musa/Messenger berkata/O ,/O “/O Wahai/O kaumku/O ,/O jika/O kamu/O sungguh-sungguh/O beriman/O kepada/O Allah/Allah ,/O bertawakallah/O hanya/O kepada-Nya/O apabila/O kamu/O benar-benar/O orang-orang/O muslim/O (/O yang/O berserah/O diri/O kepada/O Allah/Allah )/O ./O
# Musa - Person
# Wahai kaumku - Person
# Allah - Allah
# kaumku - Person
# jika kamu sungguh-sungguh beriman - Event
# kepada Allah - Allah
# bertawakallah - Event
# hanya - O
# kepada-Nya - O
# apabila - Event
# kamu benar-benar - Event
# orang-orang - Person
# muslim - Person
# (yang berserah diri - Event
# kepada Allah - Allah)
# [('Musa', 'Messenger'), ('berkata', 'O'), (',', 'O'), ('“', 'O'), ('Wahai', 'O'), ('kaumku', 'O'), (',', 'O'), ('jika', 'O'), ('kamu', 'O'), ('sungguh-sungguh', 'O'), ('beriman', 'O'), ('kepada', 'O'), ('Allah', 'Allah'), (',', 'O'), ('bertawakallah', 'O'), ('hanya', 'O'), ('kepada-Nya', 'O'), ('apabila', 'O'), ('kamu', 'O'), ('benar-benar', 'O'), ('orang-orang', 'O'), ('muslim', 'O'), ('(', 'O'), ('yang', 'O'), ('berserah', 'O'), ('diri', 'O'), ('kepada', 'O'), ('Allah', 'Allah'), (')', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 30
# Correct: 0 Guessed: 0 Total: 30
# ######### 45 ##############
# ”/O Mereka/O pun/O berkata/O ,/O “/O Kepada/O Allahlah/O kami/O bertawakal/O ./O
# "Kepada Allahlah kami bertawakal" Allah, Religion
# [('”', 'O'), ('Mereka', 'O'), ('pun', 'O'), ('berkata', 'O'), (',', 'O'), ('“', 'O'), ('Kepada', 'O'), ('Allahlah', 'O'), ('kami', 'O'), ('bertawakal', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 11
# Correct: 0 Guessed: 0 Total: 11
# ######### 46 ##############
# Ya/O Tuhan/O kami/O ,/O janganlah/O Engkau/O jadikan/O kami/O (/O sasaran/O )/O fitnah/O bagi/O kaum/O yang/O zalim/O ./O
# Ya Tuhan kami, O
# janganlah Engkau jadikan kami O
# (sasaran) O
# fitnah O
# bagi kaum O
# yang zalim O
# [('Ya', 'O'), ('Tuhan', 'O'), ('kami', 'O'), (',', 'O'), ('janganlah', 'O'), ('Engkau', 'O'), ('jadikan', 'O'), ('kami', 'O'), ('(', 'O'), ('sasaran', 'O'), (')', 'O'), ('fitnah', 'O'), ('bagi', 'O'), ('kaum', 'O'), ('yang', 'O'), ('zalim', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 17
# Correct: 0 Guessed: 0 Total: 17
# ######### 47 ##############
# Selamatkanlah/O pula/O kami/O dengan/O rahmat-Mu/O dari/O kaum/O yang/O kafir/O ./O
# Selamatkanlah pula kami dengan rahmat-Mu dari kaum O.
# [('Selamatkanlah', 'O'), ('pula', 'O'), ('kami', 'O'), ('dengan', 'O'), ('rahmat-Mu', 'O'), ('dari', 'O'), ('kaum', 'O'), ('yang', 'O'), ('kafir', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 10
# Correct: 0 Guessed: 0 Total: 10
# ######### 48 ##############
# ”/O Telah/O Kami/O wahyukan/O kepada/O Musa/Messenger dan/O saudaranya/O (/O Harun/Prophet )/O ,/O “/O Ambillah/O oleh/O kamu/O berdua/O beberapa/O rumah/O di/O Mesir/GeographicalLocation untuk/O tempat/O tinggal/O kaummu/O ,/O jadikanlah/O rumah-rumahmu/O itu/O kiblat/O (/O tempat/O ibadah/O )/O ,/O dan/O tegakkanlah/O salat/O ./O
# "Telah Kami wahyukan kepada Musa dan saudaranya (Harun),“ Ambillah oleh kamu berdua beberapa rumah di Mesir untuk tempat tinggal kaummu, jadikanlah rumah-rumahmu itu kiblat (tempat ibadah), dan tegakkanlah salat.
# Musa - Person
# Harun - Person
# Mesir - GeographicalLocation"
# [('”', 'O'), ('Telah', 'O'), ('Kami', 'O'), ('wahyukan', 'O'), ('kepada', 'O'), ('Musa', 'Messenger'), ('dan', 'O'), ('saudaranya', 'O'), ('(', 'O'), ('Harun', 'Prophet'), (')', 'O'), (',', 'O'), ('“', 'O'), ('Ambillah', 'O'), ('oleh', 'O'), ('kamu', 'O'), ('berdua', 'O'), ('beberapa', 'O'), ('rumah', 'O'), ('di', 'O'), ('Mesir', 'GeographicalLocation'), ('untuk', 'O'), ('tempat', 'O'), ('tinggal', 'O'), ('kaummu', 'O'), (',', 'O'), ('jadikanlah', 'O'), ('rumah-rumahmu', 'O'), ('itu', 'O'), ('kiblat', 'O'), ('(', 'O'), ('tempat', 'O'), ('ibadah', 'O'), (')', 'O'), (',', 'O'), ('dan', 'O'), ('tegakkanlah', 'O'), ('salat', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 39
# Correct: 0 Guessed: 0 Total: 39
# ######### 49 ##############
# Gembirakanlah/O orang-orang/O mukmin/O ./O
# Gembirakanlah orang-orang O
# [('Gembirakanlah', 'O'), ('orang-orang', 'O'), ('mukmin', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 4
# Correct: 0 Guessed: 0 Total: 4
# ######### 50 ##############
# ”/O Musa/Messenger berkata/O ,/O “/O Ya/O Tuhan/O kami/O ,/O sesungguhnya/O Engkau/O telah/O memberikan/O kepada/O Fir‘aun/Person dan/O para/O pemuka/O kaumnya/O perhiasan/O dan/O harta/O kekayaan/O (/O yang/O banyak/O )/O dalam/O kehidupan/O dunia/O ./O
# Fir'aun Person
# Tuhan kami HolyBook
# Fir'aun Person
# Fir'aun Person
# kaumnya Person
# [('”', 'O'), ('Musa', 'Messenger'), ('berkata', 'O'), (',', 'O'), ('“', 'O'), ('Ya', 'O'), ('Tuhan', 'O'), ('kami', 'O'), (',', 'O'), ('sesungguhnya', 'O'), ('Engkau', 'O'), ('telah', 'O'), ('memberikan', 'O'), ('kepada', 'O'), ('Fir‘aun', 'Person'), ('dan', 'O'), ('para', 'O'), ('pemuka', 'O'), ('kaumnya', 'O'), ('perhiasan', 'O'), ('dan', 'O'), ('harta', 'O'), ('kekayaan', 'O'), ('(', 'O'), ('yang', 'O'), ('banyak', 'O'), (')', 'O'), ('dalam', 'O'), ('kehidupan', 'O'), ('dunia', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 31
# Correct: 0 Guessed: 0 Total: 31
# ######### 51 ##############
# Ya/O Tuhan/O kami/O ,/O (/O akibat/O pemberian/O itu/O )/O mereka/O menyesatkan/O (/O manusia/O )/O dari/O jalan-Mu/O ./O
# Note: The entity mentions are labeled as 'O' as they do not belong to any of the specified entity classes.
# [('Ya', 'O'), ('Tuhan', 'O'), ('kami', 'O'), (',', 'O'), ('(', 'O'), ('akibat', 'O'), ('pemberian', 'O'), ('itu', 'O'), (')', 'O'), ('mereka', 'O'), ('menyesatkan', 'O'), ('(', 'O'), ('manusia', 'O'), (')', 'O'), ('dari', 'O'), ('jalan-Mu', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 17
# Correct: 0 Guessed: 0 Total: 17
# ######### 52 ##############
# Ya/O Tuhan/O kami/O ,/O binasakanlah/O harta/O benda/O mereka/O dan/O kunci/O matilah/O hati/O mereka/O sehingga/O mereka/O tidak/O beriman/O sampai/O mereka/O melihat/O azab/O yang/O sangat/O pedih/O ./O
# Ya Tuhan kami, O
# binasakanlah harta benda O
# dan kunci matilah hati O
# sehingga O tidak beriman sampai O melihat azab O yang sangat pedih.
# [('Ya', 'O'), ('Tuhan', 'O'), ('kami', 'O'), (',', 'O'), ('binasakanlah', 'O'), ('harta', 'O'), ('benda', 'O'), ('mereka', 'O'), ('dan', 'O'), ('kunci', 'O'), ('matilah', 'O'), ('hati', 'O'), ('mereka', 'O'), ('sehingga', 'O'), ('mereka', 'O'), ('tidak', 'O'), ('beriman', 'O'), ('sampai', 'O'), ('mereka', 'O'), ('melihat', 'O'), ('azab', 'O'), ('yang', 'O'), ('sangat', 'O'), ('pedih', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 25
# Correct: 0 Guessed: 0 Total: 25
# ######### 53 ##############
# ”/O Dia/O (/O Allah/Allah )/O berfirman/O ,/O “/O Sungguh/O ,/O permohonan/O kamu/O berdua/O telah/O diperkenankan/O ./O
# Dia (Allah) - Allah
# [('”', 'O'), ('Dia', 'O'), ('(', 'O'), ('Allah', 'Allah'), (')', 'O'), ('berfirman', 'O'), (',', 'O'), ('“', 'O'), ('Sungguh', 'O'), (',', 'O'), ('permohonan', 'O'), ('kamu', 'O'), ('berdua', 'O'), ('telah', 'O'), ('diperkenankan', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 16
# Correct: 0 Guessed: 0 Total: 16
# ######### 54 ##############
# Maka/O ,/O tetaplah/O kamu/O berdua/O (/O pada/O jalan/O yang/O lurus/O )/O dan/O janganlah/O sekali-kali/O kamu/O berdua/O mengikuti/O jalan/O orang-orang/O yang/O tidak/O mengetahui/O ./O
# No entities found.
# [('Maka', 'O'), (',', 'O'), ('tetaplah', 'O'), ('kamu', 'O'), ('berdua', 'O'), ('(', 'O'), ('pada', 'O'), ('jalan', 'O'), ('yang', 'O'), ('lurus', 'O'), (')', 'O'), ('dan', 'O'), ('janganlah', 'O'), ('sekali-kali', 'O'), ('kamu', 'O'), ('berdua', 'O'), ('mengikuti', 'O'), ('jalan', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('tidak', 'O'), ('mengetahui', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 23
# Correct: 0 Guessed: 0 Total: 23
# ######### 55 ##############
# ”/O Kami/O jadikan/O Bani Israil/Person bisa/O melintasi/O laut/O itu/O (/O Laut Merah/GeographicalLocation )/O ./O
# Bani Israil/O, Laut Merah/AstronomicalBody
# [('”', 'O'), ('Kami', 'O'), ('jadikan', 'O'), ('Israil', 'Person'), ('bisa', 'O'), ('melintasi', 'O'), ('laut', 'O'), ('itu', 'O'), ('(', 'O'), ('Merah', 'GeographicalLocation'), (')', 'O'), ('.', 'O')]
# Total predictions 2
# Total ground truth 12
# Correct: 0 Guessed: 2 Total: 12
# ######### 56 ##############
# Lalu/O ,/O Fir‘aun/Person dan/O bala/O tentaranya/O mengikuti/O mereka/O untuk/O menganiaya/O dan/O menindas/O hingga/O ketika/O Fir‘aun/Person hampir/O (/O mati/O )/O tenggelam/O ,/O dia/O berkata/O ,/O “/O Aku/O percaya/O bahwa/O tidak/O ada/O tuhan/O selain/O (/O Tuhan/O )/O yang/O telah/O dipercayai/O oleh/O Bani Israil/Person dan/O aku/O termasuk/O orang-orang/O muslim/O (/O yang/O berserah/O diri/O kepada-Nya/O )/O ./O
# Fir‘aun - Person
# Bani Israil - GeographicalLocation
# Tuhan - Allah
# muslim - Person
# [('Lalu', 'O'), (',', 'O'), ('Fir‘aun', 'Person'), ('dan', 'O'), ('bala', 'O'), ('tentaranya', 'O'), ('mengikuti', 'O'), ('mereka', 'O'), ('untuk', 'O'), ('menganiaya', 'O'), ('dan', 'O'), ('menindas', 'O'), ('hingga', 'O'), ('ketika', 'O'), ('Fir‘aun', 'Person'), ('hampir', 'O'), ('(', 'O'), ('mati', 'O'), (')', 'O'), ('tenggelam', 'O'), (',', 'O'), ('dia', 'O'), ('berkata', 'O'), (',', 'O'), ('“', 'O'), ('Aku', 'O'), ('percaya', 'O'), ('bahwa', 'O'), ('tidak', 'O'), ('ada', 'O'), ('tuhan', 'O'), ('selain', 'O'), ('(', 'O'), ('Tuhan', 'O'), (')', 'O'), ('yang', 'O'), ('telah', 'O'), ('dipercayai', 'O'), ('oleh', 'O'), ('Israil', 'Person'), ('dan', 'O'), ('aku', 'O'), ('termasuk', 'O'), ('orang-orang', 'O'), ('muslim', 'O'), ('(', 'O'), ('yang', 'O'), ('berserah', 'O'), ('diri', 'O'), ('kepada-Nya', 'O'), (')', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 52
# Correct: 0 Guessed: 0 Total: 52
# ######### 57 ##############
# ”/O Apakah/O (/O baru/O )/O sekarang/O (/O kamu/O beriman/O )/O ,/O padahal/O sungguh/O kamu/O telah/O durhaka/O sejak/O dahulu/O dan/O kamu/O termasuk/O orang-orang/O yang/O berbuat/O kerusakan/O ?/O Pada/O hari/O ini/O Kami/O selamatkan/O jasadmu/O agar/O kamu/O menjadi/O pelajaran/O bagi/O orang-orang/O yang/O datang/O setelah/O kamu/O ./O
# * Apakah (O)
# * sekarang (O)
# * kamu (Person)
# * beriman (O)
# * padahal (O)
# * sungguh (O)
# * kamu (Person)
# * telah (O)
# * durhaka (O)
# * sejak (O)
# * dahulu (O)
# * dan (O)
# * kamu (Person)
# * termasuk (O)
# * orang-orang (O)
# * yang (O)
# * berbuat (O)
# * kerusakan (O)
# * Pada (O)
# * hari (O)
# * ini (O)
# * Kami (Angel)
# * selamatkan (O)
# * jasadmu (O)
# * agar (O)
# * kamu (Person)
# * menjadi (O)
# * pelajaran (O)
# * bagi (O)
# * orang-orang (O)
# * yang (O)
# * datang (O)
# * setelah (O)
# * kamu (Person)
# [('”', 'O'), ('Apakah', 'O'), ('(', 'O'), ('baru', 'O'), (')', 'O'), ('sekarang', 'O'), ('(', 'O'), ('kamu', 'O'), ('beriman', 'O'), (')', 'O'), (',', 'O'), ('padahal', 'O'), ('sungguh', 'O'), ('kamu', 'O'), ('telah', 'O'), ('durhaka', 'O'), ('sejak', 'O'), ('dahulu', 'O'), ('dan', 'O'), ('kamu', 'O'), ('termasuk', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('berbuat', 'O'), ('kerusakan', 'O'), ('?', 'O'), ('Pada', 'O'), ('hari', 'O'), ('ini', 'O'), ('Kami', 'O'), ('selamatkan', 'O'), ('jasadmu', 'O'), ('agar', 'O'), ('kamu', 'O'), ('menjadi', 'O'), ('pelajaran', 'O'), ('bagi', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('datang', 'O'), ('setelah', 'O'), ('kamu', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 43
# Correct: 0 Guessed: 0 Total: 43
# ######### 58 ##############
# Sesungguhnya/O kebanyakan/O manusia/O benar-benar/O lengah/O (/O tidak/O mengindahkan/O )/O tanda-tanda/O (/O kekuasaan/O )/O Kami/O ./O
# Kami/O
# [('Sesungguhnya', 'O'), ('kebanyakan', 'O'), ('manusia', 'O'), ('benar-benar', 'O'), ('lengah', 'O'), ('(', 'O'), ('tidak', 'O'), ('mengindahkan', 'O'), (')', 'O'), ('tanda-tanda', 'O'), ('(', 'O'), ('kekuasaan', 'O'), (')', 'O'), ('Kami', 'O'), ('.', 'O')]
# Total predictions 1
# Total ground truth 15
# Correct: ('Kami', 'O')
# Correct: 1 Guessed: 1 Total: 15
# ######### 59 ##############
# Sungguh/O ,/O Kami/O benar-benar/O telah/O menempatkan/O Bani Israil/Person di/O tempat/O kediaman/O yang/O benar/O (/O bagus/O dan/O nyaman/O )/O dan/O Kami/O beri/O mereka/O rezeki/O yang/O baik/O ./O
# Bani Israil/Person
# [('Sungguh', 'O'), (',', 'O'), ('Kami', 'O'), ('benar-benar', 'O'), ('telah', 'O'), ('menempatkan', 'O'), ('Israil', 'Person'), ('di', 'O'), ('tempat', 'O'), ('kediaman', 'O'), ('yang', 'O'), ('benar', 'O'), ('(', 'O'), ('bagus', 'O'), ('dan', 'O'), ('nyaman', 'O'), (')', 'O'), ('dan', 'O'), ('Kami', 'O'), ('beri', 'O'), ('mereka', 'O'), ('rezeki', 'O'), ('yang', 'O'), ('baik', 'O'), ('.', 'O')]
# Total predictions 1
# Total ground truth 25
# Correct: ('Israil', 'Person')
# Correct: 1 Guessed: 1 Total: 25
# ######### 60 ##############
# Maka/O ,/O mereka/O tidak/O berselisih/O hingga/O datang/O kepada/O mereka/O pengetahuan/O (/O yang/O tersurat/O dalam/O Taurat/HolyBook )/O ./O
# Maka, mereka [O], tidak berselisih hingga datang kepada mereka [O], pengetahuan [O] (yang tersurat dalam [HolyBook])
# [('Maka', 'O'), (',', 'O'), ('mereka', 'O'), ('tidak', 'O'), ('berselisih', 'O'), ('hingga', 'O'), ('datang', 'O'), ('kepada', 'O'), ('mereka', 'O'), ('pengetahuan', 'O'), ('(', 'O'), ('yang', 'O'), ('tersurat', 'O'), ('dalam', 'O'), ('Taurat', 'HolyBook'), (')', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 17
# Correct: 0 Guessed: 0 Total: 17
# ######### 61 ##############
# Sesungguhnya/O Tuhanmu/O akan/O memberi/O keputusan/O antara/O mereka/O pada/O hari Kiamat/Event tentang/O apa/O yang/O selalu/O mereka/O perselisihkan/O ./O
# Tuhan ('Allah')
# [('Sesungguhnya', 'O'), ('Tuhanmu', 'O'), ('akan', 'O'), ('memberi', 'O'), ('keputusan', 'O'), ('antara', 'O'), ('mereka', 'O'), ('pada', 'O'), ('Kiamat', 'Event'), ('tentang', 'O'), ('apa', 'O'), ('yang', 'O'), ('selalu', 'O'), ('mereka', 'O'), ('perselisihkan', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 16
# Correct: 0 Guessed: 0 Total: 16
# ######### 62 ##############
# Jika/O engkau/O (/O Nabi/O Muhammad/Messenger )/O berada/O dalam/O keraguan/O tentang/O apa/O (/O kisah/O nabi-nabi/O terdahulu/O )/O yang/O Kami/O turunkan/O kepadamu/O ,/O tanyakanlah/O kepada/O orang-orang/O yang/O membaca/O kitab/O sebelum/O kamu/O ./O
# (Nabi Muhammad, Person)
# (kisah nabi-nabi terdahulu, Event)
# (Kami, Angel)
# (orang-orang, Person)
# (kitab, HolyBook)
# [('Jika', 'O'), ('engkau', 'O'), ('(', 'O'), ('Nabi', 'O'), ('Muhammad', 'Messenger'), (')', 'O'), ('berada', 'O'), ('dalam', 'O'), ('keraguan', 'O'), ('tentang', 'O'), ('apa', 'O'), ('(', 'O'), ('kisah', 'O'), ('nabi-nabi', 'O'), ('terdahulu', 'O'), (')', 'O'), ('yang', 'O'), ('Kami', 'O'), ('turunkan', 'O'), ('kepadamu', 'O'), (',', 'O'), ('tanyakanlah', 'O'), ('kepada', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('membaca', 'O'), ('kitab', 'O'), ('sebelum', 'O'), ('kamu', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 30
# Correct: 0 Guessed: 0 Total: 30
# ######### 63 ##############
# Sungguh/O ,/O telah/O datang/O kebenaran/O kepadamu/O dari/O Tuhanmu/O ./O
# Tuhanmu/Person
# [('Sungguh', 'O'), (',', 'O'), ('telah', 'O'), ('datang', 'O'), ('kebenaran', 'O'), ('kepadamu', 'O'), ('dari', 'O'), ('Tuhanmu', 'O'), ('.', 'O')]
# Total predictions 1
# Total ground truth 9
# Correct: 0 Guessed: 1 Total: 9
# ######### 64 ##############
# Maka/O ,/O janganlah/O sekali-kali/O engkau/O termasuk/O orang-orang/O yang/O ragu/O ./O
# Maka (O)
# [('Maka', 'O'), (',', 'O'), ('janganlah', 'O'), ('sekali-kali', 'O'), ('engkau', 'O'), ('termasuk', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('ragu', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 10
# Correct: 0 Guessed: 0 Total: 10
# ######### 65 ##############
# Janganlah/O sekali-kali/O kamu/O termasuk/O orang-orang/O yang/O mendustakan/O ayat-ayat/O Allah/Allah yang/O menyebabkan/O kamu/O tergolong/O orang-orang/O yang/O merugi/O ./O
# Janganlah sekali-kali kamu termasuk orang-orang yang mendustakan ayat-ayat Allah [Religion] yang menyebabkan kamu tergolong orang-orang yang merugi.
# [('Janganlah', 'O'), ('sekali-kali', 'O'), ('kamu', 'O'), ('termasuk', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('mendustakan', 'O'), ('ayat-ayat', 'O'), ('Allah', 'Allah'), ('yang', 'O'), ('menyebabkan', 'O'), ('kamu', 'O'), ('tergolong', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('merugi', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 17
# Correct: 0 Guessed: 0 Total: 17
# ######### 66 ##############
# Sesungguhnya/O orang-orang/O yang/O telah/O pasti/O mendapatkan/O ketentuan/O Tuhanmu/O (/O menjadi/O kufur/O atas/O pilihan/O sendiri/O )/O itu/O tidak/O akan/O beriman/O ./O
# Tuhanmu (Religion)
# [('Sesungguhnya', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('telah', 'O'), ('pasti', 'O'), ('mendapatkan', 'O'), ('ketentuan', 'O'), ('Tuhanmu', 'O'), ('(', 'O'), ('menjadi', 'O'), ('kufur', 'O'), ('atas', 'O'), ('pilihan', 'O'), ('sendiri', 'O'), (')', 'O'), ('itu', 'O'), ('tidak', 'O'), ('akan', 'O'), ('beriman', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 20
# Correct: 0 Guessed: 0 Total: 20
# ######### 67 ##############
# Meskipun/O semua/O tanda-tanda/O (/O kebesaran/O Allah/Allah )/O datang/O kepada/O mereka/O ,/O (/O mereka/O tidak/O juga/O beriman/O )/O hingga/O mereka/O menyaksikan/O azab/O yang/O sangat/O pedih/O ./O
# kebesaran Allah (Religion)
# [('Meskipun', 'O'), ('semua', 'O'), ('tanda-tanda', 'O'), ('(', 'O'), ('kebesaran', 'O'), ('Allah', 'Allah'), (')', 'O'), ('datang', 'O'), ('kepada', 'O'), ('mereka', 'O'), (',', 'O'), ('(', 'O'), ('mereka', 'O'), ('tidak', 'O'), ('juga', 'O'), ('beriman', 'O'), (')', 'O'), ('hingga', 'O'), ('mereka', 'O'), ('menyaksikan', 'O'), ('azab', 'O'), ('yang', 'O'), ('sangat', 'O'), ('pedih', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 25
# Correct: 0 Guessed: 0 Total: 25
# ######### 68 ##############
# Mengapa/O tidak/O ada/O (/O penduduk/O )/O suatu/O negeri/O pun/O yang/O segera/O beriman/O sehingga/O imannya/O itu/O bermanfaat/O kepadanya/O ,/O selain/O kaum Yunus/Person ?/O Ketika/O mereka/O beriman/O ,/O Kami/O hilangkan/O dari/O mereka/O azab/O yang/O menghinakan/O dalam/O kehidupan/O dunia/O dan/O Kami/O berikan/O kesenangan/O hidup/O (/O sementara/O )/O kepada/O mereka/O sampai/O waktu/O yang/O ditentukan/O ./O
# * Yunus: Person
# [('Mengapa', 'O'), ('tidak', 'O'), ('ada', 'O'), ('(', 'O'), ('penduduk', 'O'), (')', 'O'), ('suatu', 'O'), ('negeri', 'O'), ('pun', 'O'), ('yang', 'O'), ('segera', 'O'), ('beriman', 'O'), ('sehingga', 'O'), ('imannya', 'O'), ('itu', 'O'), ('bermanfaat', 'O'), ('kepadanya', 'O'), (',', 'O'), ('selain', 'O'), ('Yunus', 'Person'), ('?', 'O'), ('Ketika', 'O'), ('mereka', 'O'), ('beriman', 'O'), (',', 'O'), ('Kami', 'O'), ('hilangkan', 'O'), ('dari', 'O'), ('mereka', 'O'), ('azab', 'O'), ('yang', 'O'), ('menghinakan', 'O'), ('dalam', 'O'), ('kehidupan', 'O'), ('dunia', 'O'), ('dan', 'O'), ('Kami', 'O'), ('berikan', 'O'), ('kesenangan', 'O'), ('hidup', 'O'), ('(', 'O'), ('sementara', 'O'), (')', 'O'), ('kepada', 'O'), ('mereka', 'O'), ('sampai', 'O'), ('waktu', 'O'), ('yang', 'O'), ('ditentukan', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 50
# Correct: 0 Guessed: 0 Total: 50
# ######### 69 ##############
# Seandainya/O Tuhanmu/O menghendaki/O ,/O tentulah/O semua/O orang/O di/O bumi/AstronomicalBody seluruhnya/O beriman/O ./O
# Tuhanmu (Religion)
# [('Seandainya', 'O'), ('Tuhanmu', 'O'), ('menghendaki', 'O'), (',', 'O'), ('tentulah', 'O'), ('semua', 'O'), ('orang', 'O'), ('di', 'O'), ('bumi', 'AstronomicalBody'), ('seluruhnya', 'O'), ('beriman', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 12
# Correct: 0 Guessed: 0 Total: 12
# ######### 70 ##############
# Apakah/O engkau/O (/O Nabi/O Muhammad/Messenger )/O akan/O memaksa/O manusia/O hingga/O mereka/O menjadi/O orang-orang/O mukmin/O ?/O Tidak/O seorang/O pun/O akan/O beriman/O ,/O kecuali/O dengan/O izin/O Allah/Allah dan/O Dia/O menimpakan/O azab/O kepada/O orang-orang/O yang/O tidak/O mau/O mengerti/O ./O
# (Nabi Muhammad) - Person
# Allah - Allah
# Allah - Allah
# [('Apakah', 'O'), ('engkau', 'O'), ('(', 'O'), ('Nabi', 'O'), ('Muhammad', 'Messenger'), (')', 'O'), ('akan', 'O'), ('memaksa', 'O'), ('manusia', 'O'), ('hingga', 'O'), ('mereka', 'O'), ('menjadi', 'O'), ('orang-orang', 'O'), ('mukmin', 'O'), ('?', 'O'), ('Tidak', 'O'), ('seorang', 'O'), ('pun', 'O'), ('akan', 'O'), ('beriman', 'O'), (',', 'O'), ('kecuali', 'O'), ('dengan', 'O'), ('izin', 'O'), ('Allah', 'Allah'), ('dan', 'O'), ('Dia', 'O'), ('menimpakan', 'O'), ('azab', 'O'), ('kepada', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('tidak', 'O'), ('mau', 'O'), ('mengerti', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 36
# Correct: 0 Guessed: 0 Total: 36
# ######### 71 ##############
# Katakanlah/O (/O Nabi/O Muhammad/Messenger )/O ,/O “/O Perhatikanlah/O apa/O saja/O yang/O ada/O di/O langit/O dan/O di/O bumi/AstronomicalBody !/O ”/O Tidaklah/O berguna/O tanda-tanda/O (/O kebesaran/O Allah/Allah )/O dan/O peringatan-peringatan/O itu/O (/O untuk/O menghindarkan/O azab/O Allah/Allah )/O dari/O kaum/O yang/O tidak/O beriman/O ./O
# (Nabi Muhammad) - Prophet
# (kebesaran Allah) - Allah
# (azab Allah) - Allah
# ...
# Total predictions 7
# Total ground truth 30
# Correct: 0 Guessed: 7 Total: 30
# ######### 288 ##############
# Oleh/O karena/O itu/O ,/O Allah/Allah menimpakan/O kepada/O mereka/O bencana/O kelaparan/O dan/O ketakutan/O karena/O apa/O yang/O selalu/O mereka/O perbuat/O ./O
# Allah/Religion
# [('Oleh', 'O'), ('karena', 'O'), ('itu', 'O'), (',', 'O'), ('Allah', 'Allah'), ('menimpakan', 'O'), ('kepada', 'O'), ('mereka', 'O'), ('bencana', 'O'), ('kelaparan', 'O'), ('dan', 'O'), ('ketakutan', 'O'), ('karena', 'O'), ('apa', 'O'), ('yang', 'O'), ('selalu', 'O'), ('mereka', 'O'), ('perbuat', 'O'), ('.', 'O')]
# Total predictions 1
# Total ground truth 19
# Correct: 0 Guessed: 1 Total: 19
# ######### 289 ##############
# Sungguh/O ,/O telah/O datang/O kepada/O mereka/O seorang/O rasul/O dari/O (/O kalangan/O )/O mereka/O sendiri/O ,/O tetapi/O mereka/O mendustakannya/O ./O
# rasul dari kalangan mereka sendiri - Person
# [('Sungguh', 'O'), (',', 'O'), ('telah', 'O'), ('datang', 'O'), ('kepada', 'O'), ('mereka', 'O'), ('seorang', 'O'), ('rasul', 'O'), ('dari', 'O'), ('(', 'O'), ('kalangan', 'O'), (')', 'O'), ('mereka', 'O'), ('sendiri', 'O'), (',', 'O'), ('tetapi', 'O'), ('mereka', 'O'), ('mendustakannya', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 19
# Correct: 0 Guessed: 0 Total: 19
# ######### 290 ##############
# Oleh/O karena/O itu/O ,/O mereka/O ditimpa/O azab/O dan/O mereka/O itulah/O orang-orang/O zalim/O ./O
# Oleh karena itu, mereka/O, mereka/O, mereka/O
# azab/O
# mereka/O, mereka/O
# orang-orang/O, orang-orang/O, zalim/O
# [('Oleh', 'O'), ('karena', 'O'), ('itu', 'O'), (',', 'O'), ('mereka', 'O'), ('ditimpa', 'O'), ('azab', 'O'), ('dan', 'O'), ('mereka', 'O'), ('itulah', 'O'), ('orang-orang', 'O'), ('zalim', 'O'), ('.', 'O')]
# Total predictions 9
# Total ground truth 13
# Correct: ('mereka', 'O')
# Correct: ('azab', 'O')
# Correct: ('mereka', 'O')
# Correct: ('zalim', 'O')
# Correct: 4 Guessed: 9 Total: 13
# ######### 291 ##############
# Makanlah/O sebagian/O apa/O yang/O telah/O Allah/Allah anugerahkan/O kepadamu/O sebagai/O (/O rezeki/O )/O yang/O halal/O lagi/O baik/O dan/O syukurilah/O nikmat/O Allah/Allah jika/O kamu/O hanya/O menyembah/O kepada-Nya/O ./O
# ('Allah', 'Allah')
# [('Makanlah', 'O'), ('sebagian', 'O'), ('apa', 'O'), ('yang', 'O'), ('telah', 'O'), ('Allah', 'Allah'), ('anugerahkan', 'O'), ('kepadamu', 'O'), ('sebagai', 'O'), ('(', 'O'), ('rezeki', 'O'), (')', 'O'), ('yang', 'O'), ('halal', 'O'), ('lagi', 'O'), ('baik', 'O'), ('dan', 'O'), ('syukurilah', 'O'), ('nikmat', 'O'), ('Allah', 'Allah'), ('jika', 'O'), ('kamu', 'O'), ('hanya', 'O'), ('menyembah', 'O'), ('kepada-Nya', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 26
# Correct: 0 Guessed: 0 Total: 26
# ######### 292 ##############
# Sesungguhnya/O Allah/Allah hanya/O mengharamkan/O atasmu/O bangkai/O ,/O darah/O ,/O daging/O babi/O ,/O dan/O (/O hewan/O )/O yang/O disembelih/O dengan/O (/O menyebut/O nama/O )/O selain/O Allah/Allah ./O
# * Allah - Allah
# * hewan - O
# * menyebut nama - O
# [('Sesungguhnya', 'O'), ('Allah', 'Allah'), ('hanya', 'O'), ('mengharamkan', 'O'), ('atasmu', 'O'), ('bangkai', 'O'), (',', 'O'), ('darah', 'O'), (',', 'O'), ('daging', 'O'), ('babi', 'O'), (',', 'O'), ('dan', 'O'), ('(', 'O'), ('hewan', 'O'), (')', 'O'), ('yang', 'O'), ('disembelih', 'O'), ('dengan', 'O'), ('(', 'O'), ('menyebut', 'O'), ('nama', 'O'), (')', 'O'), ('selain', 'O'), ('Allah', 'Allah'), ('.', 'O')]
# Total predictions 0
# Total ground truth 26
# Correct: 0 Guessed: 0 Total: 26
# ######### 293 ##############
# Akan/O tetapi/O ,/O siapa/O yang/O terpaksa/O (/O memakannya/O )/O bukan/O karena/O menginginkan/O dan/O tidak/O (/O pula/O )/O melampaui/O batas/O ,/O sesungguhnya/O Allah/Allah Maha/O Pengampun/O lagi/O Maha/O Penyayang/O ./O
# Allah/Maha Pengampun
# [('Akan', 'O'), ('tetapi', 'O'), (',', 'O'), ('siapa', 'O'), ('yang', 'O'), ('terpaksa', 'O'), ('(', 'O'), ('memakannya', 'O'), (')', 'O'), ('bukan', 'O'), ('karena', 'O'), ('menginginkan', 'O'), ('dan', 'O'), ('tidak', 'O'), ('(', 'O'), ('pula', 'O'), (')', 'O'), ('melampaui', 'O'), ('batas', 'O'), (',', 'O'), ('sesungguhnya', 'O'), ('Allah', 'Allah'), ('Maha', 'O'), ('Pengampun', 'O'), ('lagi', 'O'), ('Maha', 'O'), ('Penyayang', 'O'), ('.', 'O')]
# Total predictions 1
# Total ground truth 28
# Correct: 0 Guessed: 1 Total: 28
# ######### 294 ##############
# Janganlah/O kamu/O mengatakan/O terhadap/O apa/O yang/O diucapkan/O oleh/O lidahmu/O secara/O bohong/O ,/O “/O Ini/O halal/O dan/O ini/O haram/O ,/O ”/O untuk/O mengada-adakan/O kebohongan/O terhadap/O Allah/Allah ./O
# Allah/Religion
# [('Janganlah', 'O'), ('kamu', 'O'), ('mengatakan', 'O'), ('terhadap', 'O'), ('apa', 'O'), ('yang', 'O'), ('diucapkan', 'O'), ('oleh', 'O'), ('lidahmu', 'O'), ('secara', 'O'), ('bohong', 'O'), (',', 'O'), ('“', 'O'), ('Ini', 'O'), ('halal', 'O'), ('dan', 'O'), ('ini', 'O'), ('haram', 'O'), (',', 'O'), ('”', 'O'), ('untuk', 'O'), ('mengada-adakan', 'O'), ('kebohongan', 'O'), ('terhadap', 'O'), ('Allah', 'Allah'), ('.', 'O')]
# Total predictions 1
# Total ground truth 26
# Correct: 0 Guessed: 1 Total: 26
# ######### 295 ##############
# Sesungguhnya/O orang-orang/O yang/O mengada-adakan/O kebohongan/O terhadap/O Allah/Allah tidak/O akan/O beruntung/O ./O
# Orang-orang [Person]
# [('Sesungguhnya', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('mengada-adakan', 'O'), ('kebohongan', 'O'), ('terhadap', 'O'), ('Allah', 'Allah'), ('tidak', 'O'), ('akan', 'O'), ('beruntung', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 11
# Correct: 0 Guessed: 0 Total: 11
# ######### 296 ##############
# (/O Itu/O adalah/O )/O kesenangan/O yang/O sedikit/O dan/O bagi/O mereka/O ada/O azab/O yang/O pedih/O ./O
# Itu O
# kesenangan O
# yang O
# sedikit O
# dan O
# bagi O
# mereka O
# ada O
# azab O
# yang O
# pedih O
# [('(', 'O'), ('Itu', 'O'), ('adalah', 'O'), (')', 'O'), ('kesenangan', 'O'), ('yang', 'O'), ('sedikit', 'O'), ('dan', 'O'), ('bagi', 'O'), ('mereka', 'O'), ('ada', 'O'), ('azab', 'O'), ('yang', 'O'), ('pedih', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 15
# Correct: 0 Guessed: 0 Total: 15
# ######### 297 ##############
# Terhadap/O orang Yahudi/Person Kami/O haramkan/O apa/O yang/O telah/O Kami/O ceritakan/O kepadamu/O (/O Nabi/O Muhammad/Messenger )/O dahulu/O ./O
# Nabi Muhammad Person
# [('Terhadap', 'O'), ('Yahudi', 'Person'), ('Kami', 'O'), ('haramkan', 'O'), ('apa', 'O'), ('yang', 'O'), ('telah', 'O'), ('Kami', 'O'), ('ceritakan', 'O'), ('kepadamu', 'O'), ('(', 'O'), ('Nabi', 'O'), ('Muhammad', 'Messenger'), (')', 'O'), ('dahulu', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 16
# Correct: 0 Guessed: 0 Total: 16
# ######### 298 ##############
# Kami/O tidak/O menzalimi/O mereka/O ,/O tetapi/O merekalah/O yang/O menzalimi/O diri/O sendiri/O ./O
# Kami/O
# [('Kami', 'O'), ('tidak', 'O'), ('menzalimi', 'O'), ('mereka', 'O'), (',', 'O'), ('tetapi', 'O'), ('merekalah', 'O'), ('yang', 'O'), ('menzalimi', 'O'), ('diri', 'O'), ('sendiri', 'O'), ('.', 'O')]
# Total predictions 1
# Total ground truth 12
# Correct: ('Kami', 'O')
# Correct: 1 Guessed: 1 Total: 12
# ######### 299 ##############
# Kemudian/O ,/O sesungguhnya/O Tuhanmu/O (/O mengampuni/O )/O orang-orang/O yang/O melakukan/O keburukan/O karena/O kebodohan/O (/O tidak/O menyadari/O akibatnya/O )/O ,/O lalu/O bertobat/O dan/O memperbaiki/O (/O dirinya/O )/O ./O
# Tuhanmu (Religion)
# [('Kemudian', 'O'), (',', 'O'), ('sesungguhnya', 'O'), ('Tuhanmu', 'O'), ('(', 'O'), ('mengampuni', 'O'), (')', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('melakukan', 'O'), ('keburukan', 'O'), ('karena', 'O'), ('kebodohan', 'O'), ('(', 'O'), ('tidak', 'O'), ('menyadari', 'O'), ('akibatnya', 'O'), (')', 'O'), (',', 'O'), ('lalu', 'O'), ('bertobat', 'O'), ('dan', 'O'), ('memperbaiki', 'O'), ('(', 'O'), ('dirinya', 'O'), (')', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 27
# Correct: 0 Guessed: 0 Total: 27
# ######### 300 ##############
# Sesungguhnya/O Tuhanmu/O setelah/O itu/O benar-benar/O Maha/O Pengampun/O lagi/O Maha/O Penyayang/O ./O
# Tuhanmu - Person
# [('Sesungguhnya', 'O'), ('Tuhanmu', 'O'), ('setelah', 'O'), ('itu', 'O'), ('benar-benar', 'O'), ('Maha', 'O'), ('Pengampun', 'O'), ('lagi', 'O'), ('Maha', 'O'), ('Penyayang', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 11
# Correct: 0 Guessed: 0 Total: 11
# ######### 301 ##############
# Sesungguhnya/O Ibrahim/Messenger adalah/O imam/O (/O sosokanutan/O )/O yang/O patuh/O kepada/O Allah/Allah ,/O hanif/O (/O lurus/O )/O ,/O dan/O bukan/O termasuk/O orang-orang/O musyrik/O ./O
# Ibrahim/O, Allah/Religion, Allah/Religion, Ibrahim/Person
# [('Sesungguhnya', 'O'), ('Ibrahim', 'Messenger'), ('adalah', 'O'), ('imam', 'O'), ('(', 'O'), ('sosokanutan', 'O'), (')', 'O'), ('yang', 'O'), ('patuh', 'O'), ('kepada', 'O'), ('Allah', 'Allah'), (',', 'O'), ('hanif', 'O'), ('(', 'O'), ('lurus', 'O'), (')', 'O'), (',', 'O'), ('dan', 'O'), ('bukan', 'O'), ('termasuk', 'O'), ('orang-orang', 'O'), ('musyrik', 'O'), ('.', 'O')]
# Total predictions 4
# Total ground truth 23
# Correct: 0 Guessed: 4 Total: 23
# ######### 302 ##############
# (/O Ibrahim/Messenger )/O bersyukur/O atas/O nikmat-nikmat-Nya/O (/O dan/O Allah/Allah )/O telah/O memilih/O serta/O menunjukinya/O ke/O jalan/O yang/O lurus/O ./O
# Ibrahim Person
# Nya O
# dan O
# Allah HolyBook
# [('(', 'O'), ('Ibrahim', 'Messenger'), (')', 'O'), ('bersyukur', 'O'), ('atas', 'O'), ('nikmat-nikmat-Nya', 'O'), ('(', 'O'), ('dan', 'O'), ('Allah', 'Allah'), (')', 'O'), ('telah', 'O'), ('memilih', 'O'), ('serta', 'O'), ('menunjukinya', 'O'), ('ke', 'O'), ('jalan', 'O'), ('yang', 'O'), ('lurus', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 19
# Correct: 0 Guessed: 0 Total: 19
# ######### 303 ##############
# Kami/O berikan/O kepadanya/O kebaikan/O di/O dunia/O dan/O sesungguhnya/O di/O akhirat/O dia/O termasuk/O orang-orang/O yang/O saleh/O ./O
# Orang-orang yang saleh [Person]
# [('Kami', 'O'), ('berikan', 'O'), ('kepadanya', 'O'), ('kebaikan', 'O'), ('di', 'O'), ('dunia', 'O'), ('dan', 'O'), ('sesungguhnya', 'O'), ('di', 'O'), ('akhirat', 'O'), ('dia', 'O'), ('termasuk', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('saleh', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 16
# Correct: 0 Guessed: 0 Total: 16
# ######### 304 ##############
# Kemudian/O ,/O Kami/O wahyukan/O kepadamu/O (/O Nabi/O Muhammad/Messenger )/O ,/O “/O Ikutilah/O agama Ibrahim/Religion sebagai/O (/O sosok/O )/O yang/O hanif/O dan/O tidak/O termasuk/O orang-orang/O musyrik/O ./O
# Nabi Muhammad/Person, Ibrahim/Person, sosok/HolyBook
# [('Kemudian', 'O'), (',', 'O'), ('Kami', 'O'), ('wahyukan', 'O'), ('kepadamu', 'O'), ('(', 'O'), ('Nabi', 'O'), ('Muhammad', 'Messenger'), (')', 'O'), (',', 'O'), ('“', 'O'), ('Ikutilah', 'O'), ('Ibrahim', 'Religion'), ('sebagai', 'O'), ('(', 'O'), ('sosok', 'O'), (')', 'O'), ('yang', 'O'), ('hanif', 'O'), ('dan', 'O'), ('tidak', 'O'), ('termasuk', 'O'), ('orang-orang', 'O'), ('musyrik', 'O'), ('.', 'O')]
# Total predictions 3
# Total ground truth 25
# Correct: 0 Guessed: 3 Total: 25
# ######### 305 ##############
# ”/O Sesungguhnya/O (/O mengagungkan/O )/O hari Sabtu/Event hanya/O diwajibkan/O bagi/O orang-orang/O (/O Yahudi/Person )/O yang/O memperselisihkannya/O ./O
# (Yahudi, Person)
# [('”', 'O'), ('Sesungguhnya', 'O'), ('(', 'O'), ('mengagungkan', 'O'), (')', 'O'), ('Sabtu', 'Event'), ('hanya', 'O'), ('diwajibkan', 'O'), ('bagi', 'O'), ('orang-orang', 'O'), ('(', 'O'), ('Yahudi', 'Person'), (')', 'O'), ('yang', 'O'), ('memperselisihkannya', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 16
# Correct: 0 Guessed: 0 Total: 16
# ######### 306 ##############
# Sesungguhnya/O Tuhanmu/O benar-benar/O akan/O memberi/O keputusan/O di/O antara/O mereka/O pada/O hari Kiamat/Event tentang/O apa/O yang/O mereka/O perselisihkan/O ./O
# Tuhanmu Person
# Kiamat Event
# [('Sesungguhnya', 'O'), ('Tuhanmu', 'O'), ('benar-benar', 'O'), ('akan', 'O'), ('memberi', 'O'), ('keputusan', 'O'), ('di', 'O'), ('antara', 'O'), ('mereka', 'O'), ('pada', 'O'), ('Kiamat', 'Event'), ('tentang', 'O'), ('apa', 'O'), ('yang', 'O'), ('mereka', 'O'), ('perselisihkan', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 17
# Correct: 0 Guessed: 0 Total: 17
# ######### 307 ##############
# Serulah/O (/O manusia/O )/O ke/O jalan/O Tuhanmu/O dengan/O hikmah/O dan/O pengajaran/O yang/O baik/O serta/O debatlah/O mereka/O dengan/O cara/O yang/O lebih/O baik/O ./O
# Serulah (O) ke jalan (O) dengan hikmah (O) dan pengajaran (O) yang baik (O) serta debatlah (O) mereka (O) dengan cara (O) yang lebih baik (O).
# [('Serulah', 'O'), ('(', 'O'), ('manusia', 'O'), (')', 'O'), ('ke', 'O'), ('jalan', 'O'), ('Tuhanmu', 'O'), ('dengan', 'O'), ('hikmah', 'O'), ('dan', 'O'), ('pengajaran', 'O'), ('yang', 'O'), ('baik', 'O'), ('serta', 'O'), ('debatlah', 'O'), ('mereka', 'O'), ('dengan', 'O'), ('cara', 'O'), ('yang', 'O'), ('lebih', 'O'), ('baik', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 22
# Correct: 0 Guessed: 0 Total: 22
# ######### 308 ##############
# Sesungguhnya/O Tuhanmu/O Dialah/O yang/O paling/O tahu/O siapa/O yang/O tersesat/O dari/O jalan-Nya/O dan/O Dia/O (/O pula/O )/O yang/O paling/O tahu/O siapa/O yang/O mendapat/O petunjuk/O ./O
# Tuhan ('Allah')
# [('Sesungguhnya', 'O'), ('Tuhanmu', 'O'), ('Dialah', 'O'), ('yang', 'O'), ('paling', 'O'), ('tahu', 'O'), ('siapa', 'O'), ('yang', 'O'), ('tersesat', 'O'), ('dari', 'O'), ('jalan-Nya', 'O'), ('dan', 'O'), ('Dia', 'O'), ('(', 'O'), ('pula', 'O'), (')', 'O'), ('yang', 'O'), ('paling', 'O'), ('tahu', 'O'), ('siapa', 'O'), ('yang', 'O'), ('mendapat', 'O'), ('petunjuk', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 24
# Correct: 0 Guessed: 0 Total: 24
# ######### 309 ##############
# Jika/O kamu/O membalas/O ,/O balaslah/O dengan/O (/O balasan/O )/O yang/O sama/O dengan/O siksaan/O yang/O ditimpakan/O kepadamu/O ./O
# balasan/O
# [('Jika', 'O'), ('kamu', 'O'), ('membalas', 'O'), (',', 'O'), ('balaslah', 'O'), ('dengan', 'O'), ('(', 'O'), ('balasan', 'O'), (')', 'O'), ('yang', 'O'), ('sama', 'O'), ('dengan', 'O'), ('siksaan', 'O'), ('yang', 'O'), ('ditimpakan', 'O'), ('kepadamu', 'O'), ('.', 'O')]
# Total predictions 1
# Total ground truth 17
# Correct: ('balasan', 'O')
# Correct: 1 Guessed: 1 Total: 17
# ######### 310 ##############
# Sungguh/O ,/O jika/O kamu/O bersabar/O ,/O hal/O itu/O benar-benar/O lebih/O baik/O bagi/O orang-orang/O yang/O sabar/O ./O
# kamu - Person
# orang-orang - Person
# [('Sungguh', 'O'), (',', 'O'), ('jika', 'O'), ('kamu', 'O'), ('bersabar', 'O'), (',', 'O'), ('hal', 'O'), ('itu', 'O'), ('benar-benar', 'O'), ('lebih', 'O'), ('baik', 'O'), ('bagi', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('sabar', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 16
# Correct: 0 Guessed: 0 Total: 16
# ######### 311 ##############
# Bersabarlah/O (/O Nabi/O Muhammad/Messenger )/O dan/O kesabaranmu/O itu/O semata-mata/O dengan/O (/O pertolongan/O )/O Allah/Allah ,/O janganlah/O bersedih/O terhadap/O (/O kekufuran/O )/O mereka/O ,/O dan/O jangan/O (/O pula/O )/O bersempit/O dada/O terhadap/O tipu/O daya/O yang/O mereka/O rencanakan/O ./O
# (Nabi Muhammad) - Person
# (Allah) - Allah
# (kekufuran) - Event
# (Allah) - Allah
# [('Bersabarlah', 'O'), ('(', 'O'), ('Nabi', 'O'), ('Muhammad', 'Messenger'), (')', 'O'), ('dan', 'O'), ('kesabaranmu', 'O'), ('itu', 'O'), ('semata-mata', 'O'), ('dengan', 'O'), ('(', 'O'), ('pertolongan', 'O'), (')', 'O'), ('Allah', 'Allah'), (',', 'O'), ('janganlah', 'O'), ('bersedih', 'O'), ('terhadap', 'O'), ('(', 'O'), ('kekufuran', 'O'), (')', 'O'), ('mereka', 'O'), (',', 'O'), ('dan', 'O'), ('jangan', 'O'), ('(', 'O'), ('pula', 'O'), (')', 'O'), ('bersempit', 'O'), ('dada', 'O'), ('terhadap', 'O'), ('tipu', 'O'), ('daya', 'O'), ('yang', 'O'), ('mereka', 'O'), ('rencanakan', 'O'), ('.', 'O')]
# Total predictions 0
# Total ground truth 37
# Correct: 0 Guessed: 0 Total: 37
# Total records test set 311
# Average precision 0.0824456536675186
# Average Recall 0.01319043026684801
# Average F1 score 0.021070686776526414
