# %%
import json
import pandas as pd
from collections import defaultdict, namedtuple, Counter

# Namedtuple to store evaluation metrics
Metrics = namedtuple('Metrics', 'tp fp fn prec rec fscore')

# Tokenize the label and prediction into word/tag pairs
def tokenize_label_pred(text):
    tokens = []
    for token in text.split():
        if "//" in token:
            token = token.replace("//", "/")
        if len(token.split("/")) == 2:
            r = (token.split('/')[-2], token.split('/')[-1])
            tokens.append(r)
        else:
            #Split into two results
            #print(token)
            if len(token.split("/"))==3:
                r1 = (token.split("/")[0], token.split("/")[1][0])
                r2 = (token.split("/")[1][1:], token.split("/")[2])
                tokens.append(r1)
                tokens.append(r2)
            else:
                print("uncover", token)
    return tokens

# Function to calculate precision, recall, and F1 score
def calculate_metrics(correct, guessed, total):
    tp, fp, fn = correct, guessed - correct, total - correct
    # Precision, Recall, F1 Score calculations
    p = 0 if tp + fp == 0 else tp / (tp + fp)
    r = 0 if tp + fn == 0 else tp / (tp + fn)
    f = 0 if p + r == 0 else 2 * p * r / (p + r)
    return Metrics(tp, fp, fn, p, r, f)

# File paths for test labels and predictions
test_labels_path_new = '../new-datasets/test_with_labels.txt'
results_path_new = 'results/results-one-shot-gpt.json'

# Read ground truth labels
with open(test_labels_path_new, 'r', encoding='utf-8') as f:
    ground_truth = f.readlines()

# Read predictions from the model
with open(results_path_new, 'r', encoding='utf-8') as f:
    predictions = json.load(f)

# Lists to store precision, recall, F1 for each instance
precs, recs, fscores = [], [], []

# Iterate over each label and corresponding prediction
for num, label in enumerate(ground_truth):
    # Initialize counters for correct matches and errors
    correct = 0
    id_ = str(num + 1)  # Key in the predictions JSON
    print(f"######### Instance {id_} ##############")
    
    # Tokenize label and prediction
    label_tokens = tokenize_label_pred(label.strip())
    prediction_tokens = tokenize_label_pred(predictions[id_].strip())

    # Count frequencies of tokens in label and prediction
    label_token_counts = Counter(label_tokens)
    prediction_token_counts = Counter(prediction_tokens)
    
    # Print for debugging
    print("Label Tokens:\n", label_tokens)
    print("prediction", predictions[id_])
    print("Prediction Tokens:\n", prediction_tokens)

    total = len(label_tokens)  # Total actual tokens
    guessed = len(prediction_tokens)  # Total predicted tokens

    # Track seen tokens from the prediction to avoid duplicates
    seen_in_prediction = []
    
    for pred_token in prediction_tokens:
        # Only count correct if the frequency in prediction <= frequency in label
        if pred_token in label_tokens and prediction_token_counts[pred_token] <= label_token_counts[pred_token]:
            if seen_in_prediction.count(pred_token) < label_token_counts[pred_token]:
                correct += 1  # Count true positives
                seen_in_prediction.append(pred_token)  # Mark as seen

    print("correct:\n", seen_in_prediction)
    # Final counts: TP = correct, FP = guessed - correct, FN = total - correct
    print(f"Correct: {correct}, Guessed: {guessed}, Total: {total}")
    metrics = calculate_metrics(correct, guessed, total)
    print(metrics)
    
    # Append the precision, recall, and F1 score for this instance
    precs.append(metrics.prec)
    recs.append(metrics.rec)
    fscores.append(metrics.fscore)

# Compute averages over all instances
avg_precs = sum(precs) / len(precs)
avg_recs = sum(recs) / len(recs)
avg_fscores = sum(fscores) / len(fscores)

# Print final averages
print("Total records in the test set:", len(ground_truth))
print("Average Precision:", avg_precs)
print("Average Recall:", avg_recs)
print("Average F1 Score:", avg_fscores)
# Out:
# ######### Instance 1 ##############
# uncover ```plaintext
# uncover ```
# Label Tokens:
#  [('Tidak', 'O'), ('ada', 'O'), ('sesuatu', 'O'), ('yang', 'O'), ('lebih', 'O'), ('kecil', 'O'), ('dan', 'O'), ('yang', 'O'), ('lebih', 'O'), ('besar', 'O'), ('daripada', 'O'), ('itu', 'O'), (',', 'O'), ('kecuali', 'O'), ('semua', 'O'), ('tercatat', 'O'), ('dalam', 'O'), ('kitab', 'O'), ('yang', 'O'), ('nyata', 'O'), ('(', 'O'), ('Lauh', 'O'), ('Mahfuz', 'O'), (')', 'O'), ('.', 'O')]
# prediction ```plaintext
# Tidak/O ada/O sesuatu/O yang/O lebih/O kecil/O dan/O yang/O lebih/O besar/O daripada/O itu/O ,/O kecuali/O semua/O tercatat/O dalam/O kitab/O yang/O nyata/O (/O Lauh/Buku Mahfuz/HolyBook )/O ./O
# ```
# Prediction Tokens:
#  [('Tidak', 'O'), ('ada', 'O'), ('sesuatu', 'O'), ('yang', 'O'), ('lebih', 'O'), ('kecil', 'O'), ('dan', 'O'), ('yang', 'O'), ('lebih', 'O'), ('besar', 'O'), ('daripada', 'O'), ('itu', 'O'), (',', 'O'), ('kecuali', 'O'), ('semua', 'O'), ('tercatat', 'O'), ('dalam', 'O'), ('kitab', 'O'), ('yang', 'O'), ('nyata', 'O'), ('(', 'O'), ('Lauh', 'Buku'), ('Mahfuz', 'HolyBook'), (')', 'O'), ('.', 'O')]
# correct:
#  [('Tidak', 'O'), ('ada', 'O'), ('sesuatu', 'O'), ('yang', 'O'), ('lebih', 'O'), ('kecil', 'O'), ('dan', 'O'), ('yang', 'O'), ('lebih', 'O'), ('besar', 'O'), ('daripada', 'O'), ('itu', 'O'), (',', 'O'), ('kecuali', 'O'), ('semua', 'O'), ('tercatat', 'O'), ('dalam', 'O'), ('kitab', 'O'), ('yang', 'O'), ('nyata', 'O'), ('(', 'O'), (')', 'O'), ('.', 'O')]
# Correct: 23, Guessed: 25, Total: 25
# Metrics(tp=23, fp=2, fn=2, prec=0.92, rec=0.92, fscore=0.92)
# ######### Instance 2 ##############
# Label Tokens:
#  [('Ketahuilah', 'O'), ('bahwa', 'O'), ('sesungguhnya', 'O'), ('(', 'O'), ('bagi', 'O'), (')', 'O'), ('para', 'O'), ('wali', 'O'), ('Allah', 'Allah'), ('itu', 'O'), ('tidak', 'O'), ('ada', 'O'), ('rasa', 'O'), ('takut', 'O'), ('yang', 'O'), ('menimpa', 'O'), ('mereka', 'O'), ('dan', 'O'), ('mereka', 'O'), ('pun', 'O'), ('tidak', 'O'), ('bersedih', 'O'), ('.', 'O')]
# prediction
# Ketahuilah/O bahwa/O sesungguhnya/O (/O bagi/O )/O para/O wali/O Allah/Allah itu/O tidak/O ada/O rasa/O takut/O yang/O menimpa/O mereka/O dan/O mereka/O pun/O tidak/O bersedih/O ./O
# Prediction Tokens:
#  [('Ketahuilah', 'O'), ('bahwa', 'O'), ('sesungguhnya', 'O'), ('(', 'O'), ('bagi', 'O'), (')', 'O'), ('para', 'O'), ('wali', 'O'), ('Allah', 'Allah'), ('itu', 'O'), ('tidak', 'O'), ('ada', 'O'), ('rasa', 'O'), ('takut', 'O'), ('yang', 'O'), ('menimpa', 'O'), ('mereka', 'O'), ('dan', 'O'), ('mereka', 'O'), ('pun', 'O'), ('tidak', 'O'), ('bersedih', 'O'), ('.', 'O')]
# correct:
#  [('Ketahuilah', 'O'), ('bahwa', 'O'), ('sesungguhnya', 'O'), ('(', 'O'), ('bagi', 'O'), (')', 'O'), ('para', 'O'), ('wali', 'O'), ('Allah', 'Allah'), ('itu', 'O'), ('tidak', 'O'), ('ada', 'O'), ('rasa', 'O'), ('takut', 'O'), ('yang', 'O'), ('menimpa', 'O'), ('mereka', 'O'), ('dan', 'O'), ('mereka', 'O'), ('pun', 'O'), ('tidak', 'O'), ('bersedih', 'O'), ('.', 'O')]
# Correct: 23, Guessed: 23, Total: 23
# Metrics(tp=23, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 3 ##############
# uncover (
# uncover O
# Label Tokens:
#  [('(', 'O'), ('Mereka', 'O'), ('adalah', 'O'), (')', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('beriman', 'O'), ('dan', 'O'), ('selalu', 'O'), ('bertakwa', 'O'), ('.', 'O')]
# prediction
# ( O Mereka/O adalah/O )/O orang-orang/O yang/O beriman/O dan/O selalu/O bertakwa/O ./O
# Prediction Tokens:
#  [('Mereka', 'O'), ('adalah', 'O'), (')', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('beriman', 'O'), ('dan', 'O'), ('selalu', 'O'), ('bertakwa', 'O'), ('.', 'O')]
# correct:
#  [('Mereka', 'O'), ('adalah', 'O'), (')', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('beriman', 'O'), ('dan', 'O'), ('selalu', 'O'), ('bertakwa', 'O'), ('.', 'O')]
# Correct: 10, Guessed: 10, Total: 11
# Metrics(tp=10, fp=0, fn=1, prec=1.0, rec=0.9090909090909091, fscore=0.9523809523809523)
# ######### Instance 4 ##############
# Label Tokens:
#  [('Bagi', 'O'), ('mereka', 'O'), ('berita', 'O'), ('gembira', 'O'), ('di', 'O'), ('dalam', 'O'), ('kehidupan', 'O'), ('di', 'O'), ('dunia', 'O'), ('dan', 'O'), ('di', 'O'), ('akhirat', 'O'), ('.', 'O')]
# prediction
# Bagi/O mereka/O berita/O gembira/O di/O dalam/O kehidupan/O di/O dunia/Location dan/O di/O akhirat/Location ./O
# Prediction Tokens:
#  [('Bagi', 'O'), ('mereka', 'O'), ('berita', 'O'), ('gembira', 'O'), ('di', 'O'), ('dalam', 'O'), ('kehidupan', 'O'), ('di', 'O'), ('dunia', 'Location'), ('dan', 'O'), ('di', 'O'), ('akhirat', 'Location'), ('.', 'O')]
# correct:
#  [('Bagi', 'O'), ('mereka', 'O'), ('berita', 'O'), ('gembira', 'O'), ('di', 'O'), ('dalam', 'O'), ('kehidupan', 'O'), ('di', 'O'), ('dan', 'O'), ('di', 'O'), ('.', 'O')]
# Correct: 11, Guessed: 13, Total: 13
# Metrics(tp=11, fp=2, fn=2, prec=0.8461538461538461, rec=0.8461538461538461, fscore=0.8461538461538461)
# ######### Instance 5 ##############
# Label Tokens:
#  [('Tidak', 'O'), ('ada', 'O'), ('perubahan', 'O'), ('bagi', 'O'), ('kalimat-kalimat', 'O'), ('(', 'O'), ('ketetapan', 'O'), ('dan', 'O'), ('janji', 'O'), (')', 'O'), ('Allah', 'Allah'), ('.', 'O')]
# prediction
# Tidak/O ada/O perubahan/O bagi/O kalimat-kalimat/O (/O ketetapan/O dan/O janji/O )/O Allah/Allah ./O
# Prediction Tokens:
#  [('Tidak', 'O'), ('ada', 'O'), ('perubahan', 'O'), ('bagi', 'O'), ('kalimat-kalimat', 'O'), ('(', 'O'), ('ketetapan', 'O'), ('dan', 'O'), ('janji', 'O'), (')', 'O'), ('Allah', 'Allah'), ('.', 'O')]
# correct:
#  [('Tidak', 'O'), ('ada', 'O'), ('perubahan', 'O'), ('bagi', 'O'), ('kalimat-kalimat', 'O'), ('(', 'O'), ('ketetapan', 'O'), ('dan', 'O'), ('janji', 'O'), (')', 'O'), ('Allah', 'Allah'), ('.', 'O')]
# Correct: 12, Guessed: 12, Total: 12
# Metrics(tp=12, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 6 ##############
# Label Tokens:
#  [('Demikian', 'O'), ('itulah', 'O'), ('kemenangan', 'O'), ('yang', 'O'), ('agung', 'O'), ('.', 'O')]
# prediction Demikian/O itulah/O kemenangan/O yang/O agung/O ./O
# Prediction Tokens:
#  [('Demikian', 'O'), ('itulah', 'O'), ('kemenangan', 'O'), ('yang', 'O'), ('agung', 'O'), ('.', 'O')]
# correct:
#  [('Demikian', 'O'), ('itulah', 'O'), ('kemenangan', 'O'), ('yang', 'O'), ('agung', 'O'), ('.', 'O')]
# Correct: 6, Guessed: 6, Total: 6
# Metrics(tp=6, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 7 ##############
# Label Tokens:
#  [('Janganlah', 'O'), ('engkau', 'O'), ('(', 'O'), ('Nabi', 'O'), ('Muhammad', 'Messenger'), (')', 'O'), ('sedih', 'O'), ('oleh', 'O'), ('perkataan', 'O'), ('mereka', 'O'), ('.', 'O')]
# prediction
# Janganlah/O engkau/O (/O Nabi/O Muhammad/Messenger )/O sedih/O oleh/O perkataan/O mereka/O ./O
# Prediction Tokens:
#  [('Janganlah', 'O'), ('engkau', 'O'), ('(', 'O'), ('Nabi', 'O'), ('Muhammad', 'Messenger'), (')', 'O'), ('sedih', 'O'), ('oleh', 'O'), ('perkataan', 'O'), ('mereka', 'O'), ('.', 'O')]
# correct:
#  [('Janganlah', 'O'), ('engkau', 'O'), ('(', 'O'), ('Nabi', 'O'), ('Muhammad', 'Messenger'), (')', 'O'), ('sedih', 'O'), ('oleh', 'O'), ('perkataan', 'O'), ('mereka', 'O'), ('.', 'O')]
# Correct: 11, Guessed: 11, Total: 11
# Metrics(tp=11, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 8 ##############
# Label Tokens:
#  [('Sesungguhnya', 'O'), ('kekuasaan', 'O'), ('itu', 'O'), ('seluruhnya', 'O'), ('milik', 'O'), ('Allah', 'Allah'), ('.', 'O')]
# prediction
# Sesungguhnya/O kekuasaan/O itu/O seluruhnya/O milik/O Allah/Allah ./O
# Prediction Tokens:
#  [('Sesungguhnya', 'O'), ('kekuasaan', 'O'), ('itu', 'O'), ('seluruhnya', 'O'), ('milik', 'O'), ('Allah', 'Allah'), ('.', 'O')]
# correct:
#  [('Sesungguhnya', 'O'), ('kekuasaan', 'O'), ('itu', 'O'), ('seluruhnya', 'O'), ('milik', 'O'), ('Allah', 'Allah'), ('.', 'O')]
# Correct: 7, Guessed: 7, Total: 7
# Metrics(tp=7, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 9 ##############
# Label Tokens:
#  [('Dia', 'O'), ('Maha', 'O'), ('Mendengar', 'O'), ('lagi', 'O'), ('Maha', 'O'), ('Mengetahui', 'O'), ('.', 'O')]
# prediction
# Dia/O Maha/O Mendengar/O lagi/O Maha/O Mengetahui/O ./O
# Prediction Tokens:
#  [('Dia', 'O'), ('Maha', 'O'), ('Mendengar', 'O'), ('lagi', 'O'), ('Maha', 'O'), ('Mengetahui', 'O'), ('.', 'O')]
# correct:
#  [('Dia', 'O'), ('Maha', 'O'), ('Mendengar', 'O'), ('lagi', 'O'), ('Maha', 'O'), ('Mengetahui', 'O'), ('.', 'O')]
# Correct: 7, Guessed: 7, Total: 7
# Metrics(tp=7, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 10 ##############
# Label Tokens:
#  [('Ketahuilah', 'O'), ('bahwa', 'O'), ('sesungguhnya', 'O'), ('milik', 'O'), ('Allahlah', 'O'), ('siapa', 'O'), ('yang', 'O'), ('ada', 'O'), ('di', 'O'), ('langit', 'O'), ('dan', 'O'), ('siapa', 'O'), ('yang', 'O'), ('ada', 'O'), ('di', 'O'), ('bumi', 'AstronomicalBody'), ('.', 'O')]
# prediction
# Ketahuilah/O bahwa/O sesungguhnya/O milik/O Allahlah/Allah siapa/O yang/O ada/O di/O langit/O dan/O siapa/O yang/O ada/O di/O bumi/O ./O
# Prediction Tokens:
#  [('Ketahuilah', 'O'), ('bahwa', 'O'), ('sesungguhnya', 'O'), ('milik', 'O'), ('Allahlah', 'Allah'), ('siapa', 'O'), ('yang', 'O'), ('ada', 'O'), ('di', 'O'), ('langit', 'O'), ('dan', 'O'), ('siapa', 'O'), ('yang', 'O'), ('ada', 'O'), ('di', 'O'), ('bumi', 'O'), ('.', 'O')]
# correct:
#  [('Ketahuilah', 'O'), ('bahwa', 'O'), ('sesungguhnya', 'O'), ('milik', 'O'), ('siapa', 'O'), ('yang', 'O'), ('ada', 'O'), ('di', 'O'), ('langit', 'O'), ('dan', 'O'), ('siapa', 'O'), ('yang', 'O'), ('ada', 'O'), ('di', 'O'), ('.', 'O')]
# Correct: 15, Guessed: 17, Total: 17
# Metrics(tp=15, fp=2, fn=2, prec=0.8823529411764706, rec=0.8823529411764706, fscore=0.8823529411764706)
# ######### Instance 11 ##############
# Label Tokens:
#  [('Orang-orang', 'O'), ('yang', 'O'), ('menyeru', 'O'), ('sekutu-sekutu', 'O'), ('selain', 'O'), ('Allah', 'Allah'), ('tidaklah', 'O'), ('mengikuti', 'O'), ('(', 'O'), ('suatu', 'O'), ('kebenaran', 'O'), (')', 'O'), ('.', 'O')]
# prediction
# Orang-orang/O yang/O menyeru/O sekutu-sekutu/O selain/O Allah/Allah tidaklah/O mengikuti/O (/O suatu/O kebenaran/Concept )/O ./O
# Prediction Tokens:
#  [('Orang-orang', 'O'), ('yang', 'O'), ('menyeru', 'O'), ('sekutu-sekutu', 'O'), ('selain', 'O'), ('Allah', 'Allah'), ('tidaklah', 'O'), ('mengikuti', 'O'), ('(', 'O'), ('suatu', 'O'), ('kebenaran', 'Concept'), (')', 'O'), ('.', 'O')]
# correct:
#  [('Orang-orang', 'O'), ('yang', 'O'), ('menyeru', 'O'), ('sekutu-sekutu', 'O'), ('selain', 'O'), ('Allah', 'Allah'), ('tidaklah', 'O'), ('mengikuti', 'O'), ('(', 'O'), ('suatu', 'O'), (')', 'O'), ('.', 'O')]
# Correct: 12, Guessed: 13, Total: 13
# Metrics(tp=12, fp=1, fn=1, prec=0.9230769230769231, rec=0.9230769230769231, fscore=0.9230769230769231)
# ######### Instance 12 ##############
# Label Tokens:
#  [('Mereka', 'O'), ('hanya', 'O'), ('mengikuti', 'O'), ('persangkaan', 'O'), ('belaka', 'O'), ('dan', 'O'), ('mereka', 'O'), ('hanyalah', 'O'), ('menduga-duga', 'O'), ('.', 'O')]
# prediction
# Mereka/O hanya/O mengikuti/O persangkaan/O belaka/O dan/O mereka/O hanyalah/O menduga-duga/O ./O
# Prediction Tokens:
#  [('Mereka', 'O'), ('hanya', 'O'), ('mengikuti', 'O'), ('persangkaan', 'O'), ('belaka', 'O'), ('dan', 'O'), ('mereka', 'O'), ('hanyalah', 'O'), ('menduga-duga', 'O'), ('.', 'O')]
# correct:
#  [('Mereka', 'O'), ('hanya', 'O'), ('mengikuti', 'O'), ('persangkaan', 'O'), ('belaka', 'O'), ('dan', 'O'), ('mereka', 'O'), ('hanyalah', 'O'), ('menduga-duga', 'O'), ('.', 'O')]
# Correct: 10, Guessed: 10, Total: 10
# Metrics(tp=10, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 13 ##############
# Label Tokens:
#  [('Dialah', 'O'), ('yang', 'O'), ('menjadikan', 'O'), ('malam', 'O'), ('bagimu', 'O'), ('agar', 'O'), ('kamu', 'O'), ('beristirahat', 'O'), ('padanya', 'O'), ('dan', 'O'), ('(', 'O'), ('menjadikan', 'O'), (')', 'O'), ('siang', 'O'), ('terang', 'O'), ('benderang', 'O'), ('.', 'O')]
# prediction
# Dialah/O yang/O menjadikan/O malam/O bagimu/O agar/O kamu/O beristirahat/O padanya/O dan/O (/O menjadikan/O )/O siang/O terang/O benderang/O ./O
# Prediction Tokens:
#  [('Dialah', 'O'), ('yang', 'O'), ('menjadikan', 'O'), ('malam', 'O'), ('bagimu', 'O'), ('agar', 'O'), ('kamu', 'O'), ('beristirahat', 'O'), ('padanya', 'O'), ('dan', 'O'), ('(', 'O'), ('menjadikan', 'O'), (')', 'O'), ('siang', 'O'), ('terang', 'O'), ('benderang', 'O'), ('.', 'O')]
# correct:
#  [('Dialah', 'O'), ('yang', 'O'), ('menjadikan', 'O'), ('malam', 'O'), ('bagimu', 'O'), ('agar', 'O'), ('kamu', 'O'), ('beristirahat', 'O'), ('padanya', 'O'), ('dan', 'O'), ('(', 'O'), ('menjadikan', 'O'), (')', 'O'), ('siang', 'O'), ('terang', 'O'), ('benderang', 'O'), ('.', 'O')]
# Correct: 17, Guessed: 17, Total: 17
# Metrics(tp=17, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 14 ##############
# Label Tokens:
#  [('Sesungguhnya', 'O'), ('pada', 'O'), ('yang', 'O'), ('demikian', 'O'), ('itu', 'O'), ('benar-benar', 'O'), ('terdapat', 'O'), ('tanda-tanda', 'O'), ('(', 'O'), ('kebesaran', 'O'), ('Allah', 'Allah'), (')', 'O'), ('bagi', 'O'), ('kaum', 'O'), ('yang', 'O'), ('(', 'O'), ('mau', 'O'), (')', 'O'), ('mendengar', 'O'), ('.', 'O')]
# prediction
# Sesungguhnya/O pada/O yang/O demikian/O itu/O benar-benar/O terdapat/O tanda-tanda/O (/O kebesaran/O Allah/Allah )/O bagi/O kaum/O yang/O (/O mau/O )/O mendengar/O ./O
# Prediction Tokens:
#  [('Sesungguhnya', 'O'), ('pada', 'O'), ('yang', 'O'), ('demikian', 'O'), ('itu', 'O'), ('benar-benar', 'O'), ('terdapat', 'O'), ('tanda-tanda', 'O'), ('(', 'O'), ('kebesaran', 'O'), ('Allah', 'Allah'), (')', 'O'), ('bagi', 'O'), ('kaum', 'O'), ('yang', 'O'), ('(', 'O'), ('mau', 'O'), (')', 'O'), ('mendengar', 'O'), ('.', 'O')]
# correct:
#  [('Sesungguhnya', 'O'), ('pada', 'O'), ('yang', 'O'), ('demikian', 'O'), ('itu', 'O'), ('benar-benar', 'O'), ('terdapat', 'O'), ('tanda-tanda', 'O'), ('(', 'O'), ('kebesaran', 'O'), ('Allah', 'Allah'), (')', 'O'), ('bagi', 'O'), ('kaum', 'O'), ('yang', 'O'), ('(', 'O'), ('mau', 'O'), (')', 'O'), ('mendengar', 'O'), ('.', 'O')]
# Correct: 20, Guessed: 20, Total: 20
# Metrics(tp=20, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 15 ##############
# Label Tokens:
#  [('Mereka', 'O'), ('(', 'O'), ('yang', 'O'), ('menyekutukan', 'O'), ('Allah', 'Allah'), (')', 'O'), ('berkata', 'O'), (',', 'O'), ('“', 'O'), ('Allah', 'Allah'), ('mengangkat', 'O'), ('anak', 'O'), ('.', 'O')]
# prediction
# Mereka/O (/O yang/O menyekutukan/O Allah/Allah )/O berkata/O ,/O “/O Allah/Allah mengangkat/O anak/O ./O
# Prediction Tokens:
#  [('Mereka', 'O'), ('(', 'O'), ('yang', 'O'), ('menyekutukan', 'O'), ('Allah', 'Allah'), (')', 'O'), ('berkata', 'O'), (',', 'O'), ('“', 'O'), ('Allah', 'Allah'), ('mengangkat', 'O'), ('anak', 'O'), ('.', 'O')]
# correct:
#  [('Mereka', 'O'), ('(', 'O'), ('yang', 'O'), ('menyekutukan', 'O'), ('Allah', 'Allah'), (')', 'O'), ('berkata', 'O'), (',', 'O'), ('“', 'O'), ('Allah', 'Allah'), ('mengangkat', 'O'), ('anak', 'O'), ('.', 'O')]
# Correct: 13, Guessed: 13, Total: 13
# Metrics(tp=13, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 16 ##############
# Label Tokens:
#  [('”', 'O'), ('Mahasuci', 'O'), ('Dia', 'O'), ('.', 'O')]
# prediction
# ”/O Mahasuci/O Dia/Allah ./O
# Prediction Tokens:
#  [('”', 'O'), ('Mahasuci', 'O'), ('Dia', 'Allah'), ('.', 'O')]
# correct:
#  [('”', 'O'), ('Mahasuci', 'O'), ('.', 'O')]
# Correct: 3, Guessed: 4, Total: 4
# Metrics(tp=3, fp=1, fn=1, prec=0.75, rec=0.75, fscore=0.75)
# ######### Instance 17 ##############
# uncover Yang
# Label Tokens:
#  [('Dialah', 'O'), ('Mahakaya', 'Allah'), ('.', 'O')]
# prediction
# Dialah/O Yang/O Mahakaya/DivineQuality ./O
# Prediction Tokens:
#  [('Dialah', 'O'), ('Yang', 'O'), ('Mahakaya', 'DivineQuality'), ('.', 'O')]
# correct:
#  [('Dialah', 'O'), ('.', 'O')]
# Correct: 2, Guessed: 4, Total: 3
# Metrics(tp=2, fp=2, fn=1, prec=0.5, rec=0.6666666666666666, fscore=0.5714285714285715)
# ######### Instance 18 ##############
# uncover ```json
# uncover ```
# Label Tokens:
#  [('Milik-Nyalah', 'O'), ('apa', 'O'), ('yang', 'O'), ('ada', 'O'), ('di', 'O'), ('langit', 'O'), ('dan', 'O'), ('apa', 'O'), ('yang', 'O'), ('ada', 'O'), ('di', 'O'), ('bumi', 'AstronomicalBody'), ('.', 'O')]
# prediction ```json
# Milik-Nya/O apa/O yang/O ada/O di/O langit/Nature dan/O apa/O yang/O ada/O di/O bumi/Nature ./O
# ```
# Prediction Tokens:
#  [('Milik-Nya', 'O'), ('apa', 'O'), ('yang', 'O'), ('ada', 'O'), ('di', 'O'), ('langit', 'Nature'), ('dan', 'O'), ('apa', 'O'), ('yang', 'O'), ('ada', 'O'), ('di', 'O'), ('bumi', 'Nature'), ('.', 'O')]
# correct:
#  [('apa', 'O'), ('yang', 'O'), ('ada', 'O'), ('di', 'O'), ('dan', 'O'), ('apa', 'O'), ('yang', 'O'), ('ada', 'O'), ('di', 'O'), ('.', 'O')]
# Correct: 10, Guessed: 13, Total: 13
# Metrics(tp=10, fp=3, fn=3, prec=0.7692307692307693, rec=0.7692307692307693, fscore=0.7692307692307693)
# ######### Instance 19 ##############
# uncover ```plaintext
# uncover ```
# Label Tokens:
#  [('Kamu', 'O'), ('tidak', 'O'), ('mempunyai', 'O'), ('alasan', 'O'), ('kuat', 'O'), ('tentang', 'O'), ('ini', 'O'), ('.', 'O')]
# prediction ```plaintext
# Kamu/O tidak/O mempunyai/O alasan/O kuat/O tentang/O ini/O ./O
# ```
# Prediction Tokens:
#  [('Kamu', 'O'), ('tidak', 'O'), ('mempunyai', 'O'), ('alasan', 'O'), ('kuat', 'O'), ('tentang', 'O'), ('ini', 'O'), ('.', 'O')]
# correct:
#  [('Kamu', 'O'), ('tidak', 'O'), ('mempunyai', 'O'), ('alasan', 'O'), ('kuat', 'O'), ('tentang', 'O'), ('ini', 'O'), ('.', 'O')]
# Correct: 8, Guessed: 8, Total: 8
# Metrics(tp=8, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 20 ##############
# Label Tokens:
#  [('Pantaskah', 'O'), ('kamu', 'O'), ('mengatakan', 'O'), ('tentang', 'O'), ('Allah', 'Allah'), ('apa', 'O'), ('yang', 'O'), ('tidak', 'O'), ('kamu', 'O'), ('ketahui', 'O'), ('?', 'O'), ('Katakanlah', 'O'), ('(', 'O'), ('Nabi', 'O'), ('Muhammad', 'Messenger'), (')', 'O'), (',', 'O'), ('“', 'O'), ('Sesungguhnya', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('mengada-adakan', 'O'), ('kebohongan', 'O'), ('terhadap', 'O'), ('Allah', 'Allah'), ('tidak', 'O'), ('akan', 'O'), ('beruntung', 'O'), ('.', 'O')]
# prediction
# Pantaskah/O kamu/O mengatakan/O tentang/O Allah/Allah apa/O yang/O tidak/O kamu/O ketahui/O ?/O Katakanlah/O (/O Nabi/O Muhammad/Messenger )/O ,/O “/O Sesungguhnya/O orang-orang/O yang/O mengada-adakan/O kebohongan/O terhadap/O Allah/Allah tidak/O akan/O beruntung/O ./O
# Prediction Tokens:
#  [('Pantaskah', 'O'), ('kamu', 'O'), ('mengatakan', 'O'), ('tentang', 'O'), ('Allah', 'Allah'), ('apa', 'O'), ('yang', 'O'), ('tidak', 'O'), ('kamu', 'O'), ('ketahui', 'O'), ('?', 'O'), ('Katakanlah', 'O'), ('(', 'O'), ('Nabi', 'O'), ('Muhammad', 'Messenger'), (')', 'O'), (',', 'O'), ('“', 'O'), ('Sesungguhnya', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('mengada-adakan', 'O'), ('kebohongan', 'O'), ('terhadap', 'O'), ('Allah', 'Allah'), ('tidak', 'O'), ('akan', 'O'), ('beruntung', 'O'), ('.', 'O')]
# correct:
#  [('Pantaskah', 'O'), ('kamu', 'O'), ('mengatakan', 'O'), ('tentang', 'O'), ('Allah', 'Allah'), ('apa', 'O'), ('yang', 'O'), ('tidak', 'O'), ('kamu', 'O'), ('ketahui', 'O'), ('?', 'O'), ('Katakanlah', 'O'), ('(', 'O'), ('Nabi', 'O'), ('Muhammad', 'Messenger'), (')', 'O'), (',', 'O'), ('“', 'O'), ('Sesungguhnya', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('mengada-adakan', 'O'), ('kebohongan', 'O'), ('terhadap', 'O'), ('Allah', 'Allah'), ('tidak', 'O'), ('akan', 'O'), ('beruntung', 'O'), ('.', 'O')]
# Correct: 29, Guessed: 29, Total: 29
# Metrics(tp=29, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 21 ##############
# Label Tokens:
#  [('”', 'O'), ('(', 'O'), ('Bagi', 'O'), ('mereka', 'O'), (')', 'O'), ('kesenangan', 'O'), ('(', 'O'), ('sesaat', 'O'), (')', 'O'), ('ketika', 'O'), ('di', 'O'), ('dunia', 'O'), (',', 'O'), ('selanjutnya', 'O'), ('kepada', 'O'), ('Kamilah', 'O'), ('tempat', 'O'), ('mereka', 'O'), ('kembali', 'O'), (',', 'O'), ('kemudian', 'O'), ('Kami', 'O'), ('jadikan', 'O'), ('mereka', 'O'), ('merasakan', 'O'), ('azab', 'O'), ('yang', 'O'), ('keras', 'O'), ('karena', 'O'), ('mereka', 'O'), ('selalu', 'O'), ('kufur', 'O'), ('.', 'O')]
# prediction
#     "/O (/O Bagi/O mereka/People )/O kesenangan/O (/O sesaat/O )/O ketika/O di/O dunia/O ,/O selanjutnya/O kepada/O Kami/Allah lah/O tempat/O mereka/People kembali/O ,/O kemudian/O Kami/Allah jadikan/O mereka/People merasakan/O azab/O yang/O keras/O karena/O mereka/People selalu/O kufur/O ./O
# Prediction Tokens:
#  [('"', 'O'), ('(', 'O'), ('Bagi', 'O'), ('mereka', 'People'), (')', 'O'), ('kesenangan', 'O'), ('(', 'O'), ('sesaat', 'O'), (')', 'O'), ('ketika', 'O'), ('di', 'O'), ('dunia', 'O'), (',', 'O'), ('selanjutnya', 'O'), ('kepada', 'O'), ('Kami', 'Allah'), ('lah', 'O'), ('tempat', 'O'), ('mereka', 'People'), ('kembali', 'O'), (',', 'O'), ('kemudian', 'O'), ('Kami', 'Allah'), ('jadikan', 'O'), ('mereka', 'People'), ('merasakan', 'O'), ('azab', 'O'), ('yang', 'O'), ('keras', 'O'), ('karena', 'O'), ('mereka', 'People'), ('selalu', 'O'), ('kufur', 'O'), ('.', 'O')]
# correct:
#  [('(', 'O'), ('Bagi', 'O'), (')', 'O'), ('kesenangan', 'O'), ('(', 'O'), ('sesaat', 'O'), (')', 'O'), ('ketika', 'O'), ('di', 'O'), ('dunia', 'O'), (',', 'O'), ('selanjutnya', 'O'), ('kepada', 'O'), ('tempat', 'O'), ('kembali', 'O'), (',', 'O'), ('kemudian', 'O'), ('jadikan', 'O'), ('merasakan', 'O'), ('azab', 'O'), ('yang', 'O'), ('keras', 'O'), ('karena', 'O'), ('selalu', 'O'), ('kufur', 'O'), ('.', 'O')]
# Correct: 26, Guessed: 34, Total: 33
# Metrics(tp=26, fp=8, fn=7, prec=0.7647058823529411, rec=0.7878787878787878, fscore=0.7761194029850745)
# ######### Instance 22 ##############
# Label Tokens:
#  [('Bacakanlah', 'O'), ('(', 'O'), ('sampaikanlah', 'O'), ('wahai', 'O'), ('Nabi', 'O'), ('Muhammad', 'Messenger'), (')', 'O'), ('kepada', 'O'), ('mereka', 'O'), ('berita', 'O'), ('penting', 'O'), ('(', 'O'), ('tentang', 'O'), (')', 'O'), ('Nuh', 'Messenger'), ('ketika', 'O'), ('dia', 'O'), ('berkata', 'O'), ('kepada', 'O'), ('kaumnya', 'O'), (',', 'O'), ('“', 'O'), ('Wahai', 'O'), ('kaumku', 'O'), (',', 'O'), ('jika', 'O'), ('terasa', 'O'), ('berat', 'O'), ('bagi', 'O'), ('kamu', 'O'), ('keberadaanku', 'O'), ('tinggal', 'O'), ('(', 'O'), ('bersamamu', 'O'), (')', 'O'), ('dan', 'O'), ('peringatanku', 'O'), ('dengan', 'O'), ('ayat-ayat', 'O'), ('Allah', 'Allah'), (',', 'O'), ('kepada', 'O'), ('Allahlah', 'O'), ('aku', 'O'), ('bertawakal', 'O'), ('.', 'O')]
# prediction
# Bacakanlah/O (/O sampaikanlah/O wahai/O Nabi/O Muhammad/Messenger )/O kepada/O mereka/O berita/O penting/O (/O tentang/O )/O Nuh/Prophet ketika/O dia/O berkata/O kepada/O kaumnya/O ,/O “/O Wahai/O kaumku/O ,/O jika/O terasa/O berat/O bagi/O kamu/O keberadaanku/O tinggal/O (/O bersamamu/O )/O dan/O peringatanku/O dengan/O ayat-ayat/O Allah/Allah ,/O kepada/O Allahlah/Allah aku/O bertawakal/O ./O
# Prediction Tokens:
#  [('Bacakanlah', 'O'), ('(', 'O'), ('sampaikanlah', 'O'), ('wahai', 'O'), ('Nabi', 'O'), ('Muhammad', 'Messenger'), (')', 'O'), ('kepada', 'O'), ('mereka', 'O'), ('berita', 'O'), ('penting', 'O'), ('(', 'O'), ('tentang', 'O'), (')', 'O'), ('Nuh', 'Prophet'), ('ketika', 'O'), ('dia', 'O'), ('berkata', 'O'), ('kepada', 'O'), ('kaumnya', 'O'), (',', 'O'), ('“', 'O'), ('Wahai', 'O'), ('kaumku', 'O'), (',', 'O'), ('jika', 'O'), ('terasa', 'O'), ('berat', 'O'), ('bagi', 'O'), ('kamu', 'O'), ('keberadaanku', 'O'), ('tinggal', 'O'), ('(', 'O'), ('bersamamu', 'O'), (')', 'O'), ('dan', 'O'), ('peringatanku', 'O'), ('dengan', 'O'), ('ayat-ayat', 'O'), ('Allah', 'Allah'), (',', 'O'), ('kepada', 'O'), ('Allahlah', 'Allah'), ('aku', 'O'), ('bertawakal', 'O'), ('.', 'O')]
# correct:
#  [('Bacakanlah', 'O'), ('(', 'O'), ('sampaikanlah', 'O'), ('wahai', 'O'), ('Nabi', 'O'), ('Muhammad', 'Messenger'), (')', 'O'), ('kepada', 'O'), ('mereka', 'O'), ('berita', 'O'), ('penting', 'O'), ('(', 'O'), ('tentang', 'O'), (')', 'O'), ('ketika', 'O'), ('dia', 'O'), ('berkata', 'O'), ('kepada', 'O'), ('kaumnya', 'O'), (',', 'O'), ('“', 'O'), ('Wahai', 'O'), ('kaumku', 'O'), (',', 'O'), ('jika', 'O'), ('terasa', 'O'), ('berat', 'O'), ('bagi', 'O'), ('kamu', 'O'), ('keberadaanku', 'O'), ('tinggal', 'O'), ('(', 'O'), ('bersamamu', 'O'), (')', 'O'), ('dan', 'O'), ('peringatanku', 'O'), ('dengan', 'O'), ('ayat-ayat', 'O'), ('Allah', 'Allah'), (',', 'O'), ('kepada', 'O'), ('aku', 'O'), ('bertawakal', 'O'), ('.', 'O')]
# Correct: 44, Guessed: 46, Total: 46
# Metrics(tp=44, fp=2, fn=2, prec=0.9565217391304348, rec=0.9565217391304348, fscore=0.9565217391304348)
# ######### Instance 23 ##############
# Label Tokens:
#  [('Oleh', 'O'), ('karena', 'O'), ('itu', 'O'), (',', 'O'), ('bulatkanlah', 'O'), ('keputusanmu', 'O'), ('dan', 'O'), ('kumpulkanlah', 'O'), ('sekutu-sekutumu', 'O'), ('(', 'O'), ('untuk', 'O'), ('membinasakanku', 'O'), (')', 'O'), (',', 'O'), ('selanjutnya', 'O'), ('janganlah', 'O'), ('keputusanmu', 'O'), ('itu', 'O'), ('dirahasiakan', 'O'), ('.', 'O')]
# prediction
# Oleh/O karena/O itu/O ,/O bulatkanlah/O keputusanmu/O dan/O kumpulkanlah/O sekutu-sekutumu/O (/O untuk/O membinasakanku/O )/O ,/O selanjutnya/O janganlah/O keputusanmu/O itu/O dirahasiakan/O ./O
# Prediction Tokens:
#  [('Oleh', 'O'), ('karena', 'O'), ('itu', 'O'), (',', 'O'), ('bulatkanlah', 'O'), ('keputusanmu', 'O'), ('dan', 'O'), ('kumpulkanlah', 'O'), ('sekutu-sekutumu', 'O'), ('(', 'O'), ('untuk', 'O'), ('membinasakanku', 'O'), (')', 'O'), (',', 'O'), ('selanjutnya', 'O'), ('janganlah', 'O'), ('keputusanmu', 'O'), ('itu', 'O'), ('dirahasiakan', 'O'), ('.', 'O')]
# correct:
#  [('Oleh', 'O'), ('karena', 'O'), ('itu', 'O'), (',', 'O'), ('bulatkanlah', 'O'), ('keputusanmu', 'O'), ('dan', 'O'), ('kumpulkanlah', 'O'), ('sekutu-sekutumu', 'O'), ('(', 'O'), ('untuk', 'O'), ('membinasakanku', 'O'), (')', 'O'), (',', 'O'), ('selanjutnya', 'O'), ('janganlah', 'O'), ('keputusanmu', 'O'), ('itu', 'O'), ('dirahasiakan', 'O'), ('.', 'O')]
# Correct: 20, Guessed: 20, Total: 20
# Metrics(tp=20, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 24 ##############
# Label Tokens:
#  [('Kemudian', 'O'), (',', 'O'), ('bertindaklah', 'O'), ('terhadap', 'O'), ('diriku', 'O'), ('dan', 'O'), ('janganlah', 'O'), ('kamu', 'O'), ('tunda-tunda', 'O'), ('(', 'O'), ('tindakan', 'O'), ('itu', 'O'), (')', 'O'), ('kepadaku', 'O'), ('.', 'O')]
# prediction
# Kemudian/O ,/O bertindaklah/O terhadap/O diriku/O dan/O janganlah/O kamu/O tunda-tunda/O (/O tindakan/O itu/O )/O kepadaku/O ./O
# Prediction Tokens:
#  [('Kemudian', 'O'), (',', 'O'), ('bertindaklah', 'O'), ('terhadap', 'O'), ('diriku', 'O'), ('dan', 'O'), ('janganlah', 'O'), ('kamu', 'O'), ('tunda-tunda', 'O'), ('(', 'O'), ('tindakan', 'O'), ('itu', 'O'), (')', 'O'), ('kepadaku', 'O'), ('.', 'O')]
# correct:
#  [('Kemudian', 'O'), (',', 'O'), ('bertindaklah', 'O'), ('terhadap', 'O'), ('diriku', 'O'), ('dan', 'O'), ('janganlah', 'O'), ('kamu', 'O'), ('tunda-tunda', 'O'), ('(', 'O'), ('tindakan', 'O'), ('itu', 'O'), (')', 'O'), ('kepadaku', 'O'), ('.', 'O')]
# Correct: 15, Guessed: 15, Total: 15
# Metrics(tp=15, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 25 ##############
# uncover ```
# uncover ```
# Label Tokens:
#  [('Jika', 'O'), ('kamu', 'O'), ('berpaling', 'O'), ('(', 'O'), ('dari', 'O'), ('peringatanku', 'O'), (')', 'O'), (',', 'O'), ('aku', 'O'), ('tidak', 'O'), ('meminta', 'O'), ('imbalan', 'O'), ('sedikit', 'O'), ('pun', 'O'), ('darimu', 'O'), ('.', 'O')]
# prediction ```
# Jika/O kamu/O berpaling/O (/O dari/O peringatanku/O )/O ,/O aku/O tidak/O meminta/O imbalan/O sedikit/O pun/O darimu/O ./O
# ```
# Prediction Tokens:
#  [('Jika', 'O'), ('kamu', 'O'), ('berpaling', 'O'), ('(', 'O'), ('dari', 'O'), ('peringatanku', 'O'), (')', 'O'), (',', 'O'), ('aku', 'O'), ('tidak', 'O'), ('meminta', 'O'), ('imbalan', 'O'), ('sedikit', 'O'), ('pun', 'O'), ('darimu', 'O'), ('.', 'O')]
# correct:
#  [('Jika', 'O'), ('kamu', 'O'), ('berpaling', 'O'), ('(', 'O'), ('dari', 'O'), ('peringatanku', 'O'), (')', 'O'), (',', 'O'), ('aku', 'O'), ('tidak', 'O'), ('meminta', 'O'), ('imbalan', 'O'), ('sedikit', 'O'), ('pun', 'O'), ('darimu', 'O'), ('.', 'O')]
# Correct: 16, Guessed: 16, Total: 16
# Metrics(tp=16, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 26 ##############
# uncover ```plaintext
# uncover ```
# Label Tokens:
#  [('Imbalanku', 'O'), ('tidak', 'O'), ('lain', 'O'), ('hanyalah', 'O'), ('dari', 'O'), ('Allah', 'Allah'), ('dan', 'O'), ('aku', 'O'), ('diperintah', 'O'), ('agar', 'O'), ('aku', 'O'), ('masuk', 'O'), ('ke', 'O'), ('dalam', 'O'), ('golongan', 'O'), ('orang-orang', 'O'), ('muslim', 'O'), ('.', 'O')]
# prediction ```plaintext
# Imbalanku/O tidak/O lain/O hanyalah/O dari/O Allah/Allah dan/O aku/O diperintah/O agar/O aku/O masuk/O ke/O dalam/O golongan/O orang-orang/O muslim/Believer ./O
# ```
# Prediction Tokens:
#  [('Imbalanku', 'O'), ('tidak', 'O'), ('lain', 'O'), ('hanyalah', 'O'), ('dari', 'O'), ('Allah', 'Allah'), ('dan', 'O'), ('aku', 'O'), ('diperintah', 'O'), ('agar', 'O'), ('aku', 'O'), ('masuk', 'O'), ('ke', 'O'), ('dalam', 'O'), ('golongan', 'O'), ('orang-orang', 'O'), ('muslim', 'Believer'), ('.', 'O')]
# correct:
#  [('Imbalanku', 'O'), ('tidak', 'O'), ('lain', 'O'), ('hanyalah', 'O'), ('dari', 'O'), ('Allah', 'Allah'), ('dan', 'O'), ('aku', 'O'), ('diperintah', 'O'), ('agar', 'O'), ('aku', 'O'), ('masuk', 'O'), ('ke', 'O'), ('dalam', 'O'), ('golongan', 'O'), ('orang-orang', 'O'), ('.', 'O')]
# Correct: 17, Guessed: 18, Total: 18
# Metrics(tp=17, fp=1, fn=1, prec=0.9444444444444444, rec=0.9444444444444444, fscore=0.9444444444444444)
# ######### Instance 27 ##############
# Label Tokens:
#  [('”', 'O'), ('Mereka', 'O'), ('mendustakannya', 'O'), ('(', 'O'), ('Nuh', 'Messenger'), (')', 'O'), ('.', 'O')]
# prediction
# ”/O Mereka/O mendustakannya/O (/O Nuh/Messenger )./O
# Prediction Tokens:
#  [('”', 'O'), ('Mereka', 'O'), ('mendustakannya', 'O'), ('(', 'O'), ('Nuh', 'Messenger'), (').', 'O')]
# correct:
#  [('”', 'O'), ('Mereka', 'O'), ('mendustakannya', 'O'), ('(', 'O'), ('Nuh', 'Messenger')]
# Correct: 5, Guessed: 6, Total: 7
# Metrics(tp=5, fp=1, fn=2, prec=0.8333333333333334, rec=0.7142857142857143, fscore=0.7692307692307692)
# ######### Instance 28 ##############
# Label Tokens:
#  [('Lalu', 'O'), (',', 'O'), ('Kami', 'O'), ('selamatkan', 'O'), ('dia', 'O'), ('dan', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('bersamanya', 'O'), ('di', 'O'), ('dalam', 'O'), ('bahtera', 'O'), ('serta', 'O'), ('Kami', 'O'), ('jadikan', 'O'), ('mereka', 'O'), ('sebagai', 'O'), ('generasi', 'O'), ('penerus', 'O'), ('dan', 'O'), ('Kami', 'O'), ('tenggelamkan', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('mendustakan', 'O'), ('ayat-ayat', 'O'), ('Kami', 'O'), ('.', 'O')]
# prediction
# Lalu/O ,/O Kami/O selamatkan/O dia/O dan/O orang-orang/O yang/O bersamanya/O di/O dalam/O bahtera/Noah'sArk serta/O Kami/O jadikan/O mereka/O sebagai/O generasi/O penerus/O dan/O Kami/O tenggelamkan/O orang-orang/O yang/O mendustakan/O ayat-ayat/O Kami/O ./O
# Prediction Tokens:
#  [('Lalu', 'O'), (',', 'O'), ('Kami', 'O'), ('selamatkan', 'O'), ('dia', 'O'), ('dan', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('bersamanya', 'O'), ('di', 'O'), ('dalam', 'O'), ('bahtera', "Noah'sArk"), ('serta', 'O'), ('Kami', 'O'), ('jadikan', 'O'), ('mereka', 'O'), ('sebagai', 'O'), ('generasi', 'O'), ('penerus', 'O'), ('dan', 'O'), ('Kami', 'O'), ('tenggelamkan', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('mendustakan', 'O'), ('ayat-ayat', 'O'), ('Kami', 'O'), ('.', 'O')]
# correct:
#  [('Lalu', 'O'), (',', 'O'), ('Kami', 'O'), ('selamatkan', 'O'), ('dia', 'O'), ('dan', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('bersamanya', 'O'), ('di', 'O'), ('dalam', 'O'), ('serta', 'O'), ('Kami', 'O'), ('jadikan', 'O'), ('mereka', 'O'), ('sebagai', 'O'), ('generasi', 'O'), ('penerus', 'O'), ('dan', 'O'), ('Kami', 'O'), ('tenggelamkan', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('mendustakan', 'O'), ('ayat-ayat', 'O'), ('Kami', 'O'), ('.', 'O')]
# Correct: 27, Guessed: 28, Total: 28
# Metrics(tp=27, fp=1, fn=1, prec=0.9642857142857143, rec=0.9642857142857143, fscore=0.9642857142857143)
# ######### Instance 29 ##############
# Label Tokens:
#  [('Perhatikanlah', 'O'), ('bagaimana', 'O'), ('kesudahan', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('diberi', 'O'), ('peringatan', 'O'), ('itu', 'O'), ('.', 'O')]
# prediction
# Perhatikanlah/O bagaimana/O kesudahan/O orang-orang/O yang/O diberi/O peringatan/O itu/O ./O
# Prediction Tokens:
#  [('Perhatikanlah', 'O'), ('bagaimana', 'O'), ('kesudahan', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('diberi', 'O'), ('peringatan', 'O'), ('itu', 'O'), ('.', 'O')]
# correct:
#  [('Perhatikanlah', 'O'), ('bagaimana', 'O'), ('kesudahan', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('diberi', 'O'), ('peringatan', 'O'), ('itu', 'O'), ('.', 'O')]
# Correct: 9, Guessed: 9, Total: 9
# Metrics(tp=9, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 30 ##############
# uncover ```
# uncover ```
# Label Tokens:
#  [('Kemudian', 'O'), (',', 'O'), ('Kami', 'O'), ('mengutus', 'O'), ('setelahnya', 'O'), ('(', 'O'), ('Nuh', 'Messenger'), (')', 'O'), ('beberapa', 'O'), ('rasul', 'O'), ('kepada', 'O'), ('kaum', 'O'), ('mereka', 'O'), ('(', 'O'), ('umat', 'O'), ('masing-masing', 'O'), (')', 'O'), (',', 'O'), ('maka', 'O'), ('rasul-rasul', 'O'), ('itu', 'O'), ('datang', 'O'), ('kepada', 'O'), ('mereka', 'O'), ('dengan', 'O'), ('membawa', 'O'), ('bukti-bukti', 'O'), ('yang', 'O'), ('nyata', 'O'), (',', 'O'), ('tetapi', 'O'), ('mereka', 'O'), ('tidak', 'O'), ('mau', 'O'), ('beriman', 'O'), ('karena', 'O'), ('mereka', 'O'), ('dahulu', 'O'), ('telah', 'O'), ('(', 'O'), ('biasa', 'O'), (')', 'O'), ('mendustakannya', 'O'), ('.', 'O')]
# prediction ```
# Kemudian,/O Kami/O mengutus/O setelahnya/O (/O Nuh/Messenger )/O beberapa/O rasul/O kepada/O kaum/O mereka/O (/O umat/Community masing-masing/O ),/O maka/O rasul-rasul/O itu/O datang/O kepada/O mereka/O dengan/O membawa/O bukti-bukti/O yang/O nyata/O ,/O tetapi/O mereka/O tidak/O mau/O beriman/O karena/O mereka/O dahulu/O telah/O (/O biasa/O )/O mendustakannya/O ./O
# ```
# Prediction Tokens:
#  [('Kemudian,', 'O'), ('Kami', 'O'), ('mengutus', 'O'), ('setelahnya', 'O'), ('(', 'O'), ('Nuh', 'Messenger'), (')', 'O'), ('beberapa', 'O'), ('rasul', 'O'), ('kepada', 'O'), ('kaum', 'O'), ('mereka', 'O'), ('(', 'O'), ('umat', 'Community'), ('masing-masing', 'O'), ('),', 'O'), ('maka', 'O'), ('rasul-rasul', 'O'), ('itu', 'O'), ('datang', 'O'), ('kepada', 'O'), ('mereka', 'O'), ('dengan', 'O'), ('membawa', 'O'), ('bukti-bukti', 'O'), ('yang', 'O'), ('nyata', 'O'), (',', 'O'), ('tetapi', 'O'), ('mereka', 'O'), ('tidak', 'O'), ('mau', 'O'), ('beriman', 'O'), ('karena', 'O'), ('mereka', 'O'), ('dahulu', 'O'), ('telah', 'O'), ('(', 'O'), ('biasa', 'O'), (')', 'O'), ('mendustakannya', 'O'), ('.', 'O')]
# correct:
#  [('Kami', 'O'), ('mengutus', 'O'), ('setelahnya', 'O'), ('(', 'O'), ('Nuh', 'Messenger'), (')', 'O'), ('beberapa', 'O'), ('rasul', 'O'), ('kepada', 'O'), ('kaum', 'O'), ('mereka', 'O'), ('(', 'O'), ('masing-masing', 'O'), ('maka', 'O'), ('rasul-rasul', 'O'), ('itu', 'O'), ('datang', 'O'), ('kepada', 'O'), ('mereka', 'O'), ('dengan', 'O'), ('membawa', 'O'), ('bukti-bukti', 'O'), ('yang', 'O'), ('nyata', 'O'), (',', 'O'), ('tetapi', 'O'), ('mereka', 'O'), ('tidak', 'O'), ('mau', 'O'), ('beriman', 'O'), ('karena', 'O'), ('mereka', 'O'), ('dahulu', 'O'), ('telah', 'O'), ('(', 'O'), ('biasa', 'O'), (')', 'O'), ('mendustakannya', 'O'), ('.', 'O')]
# Correct: 39, Guessed: 42, Total: 44
# Metrics(tp=39, fp=3, fn=5, prec=0.9285714285714286, rec=0.8863636363636364, fscore=0.9069767441860465)
# ######### Instance 31 ##############
# uncover ```plaintext
# uncover ```
# Label Tokens:
#  [('Demikianlah', 'O'), ('Kami', 'O'), ('mengunci', 'O'), ('hati', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('melampaui', 'O'), ('batas', 'O'), ('.', 'O')]
# prediction ```plaintext
# Demikianlah/O Kami/O mengunci/O hati/O orang-orang/O yang/O melampaui/O batas/O ./O
# ```
# Prediction Tokens:
#  [('Demikianlah', 'O'), ('Kami', 'O'), ('mengunci', 'O'), ('hati', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('melampaui', 'O'), ('batas', 'O'), ('.', 'O')]
# correct:
#  [('Demikianlah', 'O'), ('Kami', 'O'), ('mengunci', 'O'), ('hati', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('melampaui', 'O'), ('batas', 'O'), ('.', 'O')]
# Correct: 9, Guessed: 9, Total: 9
# Metrics(tp=9, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 32 ##############
# Label Tokens:
#  [('Kemudian', 'O'), (',', 'O'), ('setelah', 'O'), ('mereka', 'O'), ('Kami', 'O'), ('mengutus', 'O'), ('Musa', 'Messenger'), ('dan', 'O'), ('Harun', 'Prophet'), ('kepada', 'O'), ('Fir‘aun', 'Person'), ('dan', 'O'), ('para', 'O'), ('pemuka', 'O'), ('kaumnya', 'O'), (',', 'O'), ('dengan', 'O'), ('membawa', 'O'), ('tanda-tanda', 'O'), ('(', 'O'), ('kekuasaan', 'O'), (')', 'O'), ('Kami', 'O'), ('.', 'O')]
# prediction
# Kemudian/O ,/O setelah/O mereka/O Kami/O mengutus/O Musa/Messenger dan/O Harun/Messenger kepada/O Fir‘aun/Leader dan/O para/O pemuka/O kaumnya/O ,/O dengan/O membawa/O tanda-tanda/O (/O kekuasaan/O )/O Kami/O ./O
# Prediction Tokens:
#  [('Kemudian', 'O'), (',', 'O'), ('setelah', 'O'), ('mereka', 'O'), ('Kami', 'O'), ('mengutus', 'O'), ('Musa', 'Messenger'), ('dan', 'O'), ('Harun', 'Messenger'), ('kepada', 'O'), ('Fir‘aun', 'Leader'), ('dan', 'O'), ('para', 'O'), ('pemuka', 'O'), ('kaumnya', 'O'), (',', 'O'), ('dengan', 'O'), ('membawa', 'O'), ('tanda-tanda', 'O'), ('(', 'O'), ('kekuasaan', 'O'), (')', 'O'), ('Kami', 'O'), ('.', 'O')]
# correct:
#  [('Kemudian', 'O'), (',', 'O'), ('setelah', 'O'), ('mereka', 'O'), ('Kami', 'O'), ('mengutus', 'O'), ('Musa', 'Messenger'), ('dan', 'O'), ('kepada', 'O'), ('dan', 'O'), ('para', 'O'), ('pemuka', 'O'), ('kaumnya', 'O'), (',', 'O'), ('dengan', 'O'), ('membawa', 'O'), ('tanda-tanda', 'O'), ('(', 'O'), ('kekuasaan', 'O'), (')', 'O'), ('Kami', 'O'), ('.', 'O')]
# Correct: 22, Guessed: 24, Total: 24
# Metrics(tp=22, fp=2, fn=2, prec=0.9166666666666666, rec=0.9166666666666666, fscore=0.9166666666666666)
# ######### Instance 33 ##############
# uncover ```json
# uncover ```
# Label Tokens:
#  [('Lalu', 'O'), (',', 'O'), ('mereka', 'O'), ('menyombongkan', 'O'), ('diri', 'O'), ('dan', 'O'), ('mereka', 'O'), ('adalah', 'O'), ('kaum', 'O'), ('pendurhaka', 'O'), ('.', 'O')]
# prediction ```json
# Lalu/O ,/O mereka/O menyombongkan/O diri/O dan/O mereka/O adalah/O kaum/O pendurhaka/O ./O
# ```
# Prediction Tokens:
#  [('Lalu', 'O'), (',', 'O'), ('mereka', 'O'), ('menyombongkan', 'O'), ('diri', 'O'), ('dan', 'O'), ('mereka', 'O'), ('adalah', 'O'), ('kaum', 'O'), ('pendurhaka', 'O'), ('.', 'O')]
# correct:
#  [('Lalu', 'O'), (',', 'O'), ('mereka', 'O'), ('menyombongkan', 'O'), ('diri', 'O'), ('dan', 'O'), ('mereka', 'O'), ('adalah', 'O'), ('kaum', 'O'), ('pendurhaka', 'O'), ('.', 'O')]
# Correct: 11, Guessed: 11, Total: 11
# Metrics(tp=11, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 34 ##############
# Label Tokens:
#  [('Ketika', 'O'), ('telah', 'O'), ('datang', 'O'), ('kepada', 'O'), ('mereka', 'O'), ('kebenaran', 'O'), ('(', 'O'), ('mukjizat', 'O'), (')', 'O'), ('dari', 'O'), ('sisi', 'O'), ('Kami', 'O'), (',', 'O'), ('mereka', 'O'), ('berkata', 'O'), (',', 'O'), ('“', 'O'), ('Sesungguhnya', 'O'), ('ini', 'O'), ('benar-benar', 'O'), ('sihir', 'O'), ('yang', 'O'), ('nyata', 'O'), ('.', 'O')]
# prediction
# Ketika/O telah/O datang/O kepada/O mereka/O kebenaran/O (/O mukjizat/Miracle )/O dari/O sisi/O Kami/O ,/O mereka/O berkata/O ,/O “/O Sesungguhnya/O ini/O benar-benar/O sihir/O yang/O nyata/O ./O
# Prediction Tokens:
#  [('Ketika', 'O'), ('telah', 'O'), ('datang', 'O'), ('kepada', 'O'), ('mereka', 'O'), ('kebenaran', 'O'), ('(', 'O'), ('mukjizat', 'Miracle'), (')', 'O'), ('dari', 'O'), ('sisi', 'O'), ('Kami', 'O'), (',', 'O'), ('mereka', 'O'), ('berkata', 'O'), (',', 'O'), ('“', 'O'), ('Sesungguhnya', 'O'), ('ini', 'O'), ('benar-benar', 'O'), ('sihir', 'O'), ('yang', 'O'), ('nyata', 'O'), ('.', 'O')]
# correct:
#  [('Ketika', 'O'), ('telah', 'O'), ('datang', 'O'), ('kepada', 'O'), ('mereka', 'O'), ('kebenaran', 'O'), ('(', 'O'), (')', 'O'), ('dari', 'O'), ('sisi', 'O'), ('Kami', 'O'), (',', 'O'), ('mereka', 'O'), ('berkata', 'O'), (',', 'O'), ('“', 'O'), ('Sesungguhnya', 'O'), ('ini', 'O'), ('benar-benar', 'O'), ('sihir', 'O'), ('yang', 'O'), ('nyata', 'O'), ('.', 'O')]
# Correct: 23, Guessed: 24, Total: 24
# Metrics(tp=23, fp=1, fn=1, prec=0.9583333333333334, rec=0.9583333333333334, fscore=0.9583333333333334)
# ######### Instance 35 ##############
# Label Tokens:
#  [('”', 'O'), ('Musa', 'Messenger'), ('berkata', 'O'), (',', 'O'), ('“', 'O'), ('Apakah', 'O'), ('(', 'O'), ('pantas', 'O'), (')', 'O'), ('kamu', 'O'), ('mengatakan', 'O'), ('terhadap', 'O'), ('kebenaran', 'O'), ('(', 'O'), ('mukjizat', 'O'), (')', 'O'), ('ketika', 'O'), ('ia', 'O'), ('datang', 'O'), ('kepadamu', 'O'), (',', 'O'), ('‘sihirkah', 'O'), ('ini', 'O'), ('?', 'O'), ('’', 'O'), ('Padahal', 'O'), (',', 'O'), ('para', 'O'), ('penyihir', 'O'), ('itu', 'O'), ('tidaklah', 'O'), ('mendapat', 'O'), ('kemenangan', 'O'), ('.', 'O')]
# prediction
# ”/O Musa/Messenger berkata/O ,/O “/O Apakah/O (/O pantas/O )/O kamu/O mengatakan/O terhadap/O kebenaran/O (/O mukjizat/Miracle )/O ketika/O ia/O datang/O kepadamu/O ,/O ‘/O sihirkah/O ini/O ?/O ’/O Padahal/O ,/O para/O penyihir/O itu/O tidaklah/O mendapat/O kemenangan/O ./O
# Prediction Tokens:
#  [('”', 'O'), ('Musa', 'Messenger'), ('berkata', 'O'), (',', 'O'), ('“', 'O'), ('Apakah', 'O'), ('(', 'O'), ('pantas', 'O'), (')', 'O'), ('kamu', 'O'), ('mengatakan', 'O'), ('terhadap', 'O'), ('kebenaran', 'O'), ('(', 'O'), ('mukjizat', 'Miracle'), (')', 'O'), ('ketika', 'O'), ('ia', 'O'), ('datang', 'O'), ('kepadamu', 'O'), (',', 'O'), ('‘', 'O'), ('sihirkah', 'O'), ('ini', 'O'), ('?', 'O'), ('’', 'O'), ('Padahal', 'O'), (',', 'O'), ('para', 'O'), ('penyihir', 'O'), ('itu', 'O'), ('tidaklah', 'O'), ('mendapat', 'O'), ('kemenangan', 'O'), ('.', 'O')]
# correct:
#  [('”', 'O'), ('Musa', 'Messenger'), ('berkata', 'O'), (',', 'O'), ('“', 'O'), ('Apakah', 'O'), ('(', 'O'), ('pantas', 'O'), (')', 'O'), ('kamu', 'O'), ('mengatakan', 'O'), ('terhadap', 'O'), ('kebenaran', 'O'), ('(', 'O'), (')', 'O'), ('ketika', 'O'), ('ia', 'O'), ('datang', 'O'), ('kepadamu', 'O'), (',', 'O'), ('ini', 'O'), ('?', 'O'), ('’', 'O'), ('Padahal', 'O'), (',', 'O'), ('para', 'O'), ('penyihir', 'O'), ('itu', 'O'), ('tidaklah', 'O'), ('mendapat', 'O'), ('kemenangan', 'O'), ('.', 'O')]
# Correct: 32, Guessed: 35, Total: 34
# Metrics(tp=32, fp=3, fn=2, prec=0.9142857142857143, rec=0.9411764705882353, fscore=0.9275362318840579)
# ######### Instance 36 ##############
# Label Tokens:
#  [('”', 'O'), ('Mereka', 'O'), ('berkata', 'O'), (',', 'O'), ('“', 'O'), ('Apakah', 'O'), ('engkau', 'O'), ('(', 'O'), ('Musa', 'Messenger'), (')', 'O'), ('datang', 'O'), ('kepada', 'O'), ('kami', 'O'), ('untuk', 'O'), ('memalingkan', 'O'), ('kami', 'O'), ('dari', 'O'), ('apa', 'O'), ('yang', 'O'), ('kami', 'O'), ('dapati', 'O'), ('pada', 'O'), ('nenek', 'O'), ('moyang', 'O'), ('kami', 'O'), ('(', 'O'), ('menyembah', 'O'), ('berhala', 'O'), (')', 'O'), (',', 'O'), ('dan', 'O'), ('agar', 'O'), ('kamu', 'O'), ('berdua', 'O'), ('(', 'O'), ('Musa', 'Messenger'), ('dan', 'O'), ('Harun', 'Prophet'), (')', 'O'), ('mempunyai', 'O'), ('kekuasaan', 'O'), ('di', 'O'), ('bumi', 'AstronomicalBody'), ('(', 'O'), ('negeri', 'O'), ('Mesir', 'GeographicalLocation'), (')', 'O'), ('?', 'O'), ('Kami', 'O'), ('tidak', 'O'), ('akan', 'O'), ('beriman', 'O'), ('kepada', 'O'), ('kamu', 'O'), ('berdua', 'O'), ('.', 'O')]
# prediction
# ”/O Mereka/O berkata/O ,/O “/O Apakah/O engkau/O (/O Musa/Messenger )/O datang/O kepada/O kami/O untuk/O memalingkan/O kami/O dari/O apa/O yang/O kami/O dapati/O pada/O nenek/O moyang/O kami/O (/O menyembah/O berhala/ReveredFigure )/O ,/O dan/O agar/O kamu/O berdua/O (/O Musa/Messenger dan/O Harun/Messenger )/O mempunyai/O kekuasaan/O di/O bumi/O (/O negeri/O Mesir/Location )/O ?/O Kami/O tidak/O akan/O beriman/O kepada/O kamu/O berdua/O ./O
# Prediction Tokens:
#  [('”', 'O'), ('Mereka', 'O'), ('berkata', 'O'), (',', 'O'), ('“', 'O'), ('Apakah', 'O'), ('engkau', 'O'), ('(', 'O'), ('Musa', 'Messenger'), (')', 'O'), ('datang', 'O'), ('kepada', 'O'), ('kami', 'O'), ('untuk', 'O'), ('memalingkan', 'O'), ('kami', 'O'), ('dari', 'O'), ('apa', 'O'), ('yang', 'O'), ('kami', 'O'), ('dapati', 'O'), ('pada', 'O'), ('nenek', 'O'), ('moyang', 'O'), ('kami', 'O'), ('(', 'O'), ('menyembah', 'O'), ('berhala', 'ReveredFigure'), (')', 'O'), (',', 'O'), ('dan', 'O'), ('agar', 'O'), ('kamu', 'O'), ('berdua', 'O'), ('(', 'O'), ('Musa', 'Messenger'), ('dan', 'O'), ('Harun', 'Messenger'), (')', 'O'), ('mempunyai', 'O'), ('kekuasaan', 'O'), ('di', 'O'), ('bumi', 'O'), ('(', 'O'), ('negeri', 'O'), ('Mesir', 'Location'), (')', 'O'), ('?', 'O'), ('Kami', 'O'), ('tidak', 'O'), ('akan', 'O'), ('beriman', 'O'), ('kepada', 'O'), ('kamu', 'O'), ('berdua', 'O'), ('.', 'O')]
# correct:
#  [('”', 'O'), ('Mereka', 'O'), ('berkata', 'O'), (',', 'O'), ('“', 'O'), ('Apakah', 'O'), ('engkau', 'O'), ('(', 'O'), ('Musa', 'Messenger'), (')', 'O'), ('datang', 'O'), ('kepada', 'O'), ('kami', 'O'), ('untuk', 'O'), ('memalingkan', 'O'), ('kami', 'O'), ('dari', 'O'), ('apa', 'O'), ('yang', 'O'), ('kami', 'O'), ('dapati', 'O'), ('pada', 'O'), ('nenek', 'O'), ('moyang', 'O'), ('kami', 'O'), ('(', 'O'), ('menyembah', 'O'), (')', 'O'), (',', 'O'), ('dan', 'O'), ('agar', 'O'), ('kamu', 'O'), ('berdua', 'O'), ('(', 'O'), ('Musa', 'Messenger'), ('dan', 'O'), (')', 'O'), ('mempunyai', 'O'), ('kekuasaan', 'O'), ('di', 'O'), ('(', 'O'), ('negeri', 'O'), (')', 'O'), ('?', 'O'), ('Kami', 'O'), ('tidak', 'O'), ('akan', 'O'), ('beriman', 'O'), ('kepada', 'O'), ('kamu', 'O'), ('berdua', 'O'), ('.', 'O')]
# Correct: 52, Guessed: 56, Total: 56
# Metrics(tp=52, fp=4, fn=4, prec=0.9285714285714286, rec=0.9285714285714286, fscore=0.9285714285714286)
# ######### Instance 37 ##############
# Label Tokens:
#  [('”', 'O'), ('Fir‘aun', 'Person'), ('berkata', 'O'), ('(', 'O'), ('kepada', 'O'), ('para', 'O'), ('pemuka', 'O'), ('kaumnya', 'O'), (')', 'O'), (',', 'O'), ('“', 'O'), ('Datangkanlah', 'O'), ('kepadaku', 'O'), ('semua', 'O'), ('penyihir', 'O'), ('yang', 'O'), ('ulung', 'O'), ('!', 'O'), ('”', 'O'), ('Ketika', 'O'), ('para', 'O'), ('penyihir', 'O'), ('itu', 'O'), ('datang', 'O'), (',', 'O'), ('Musa', 'Messenger'), ('berkata', 'O'), ('kepada', 'O'), ('mereka', 'O'), (',', 'O'), ('“', 'O'), ('Lemparkanlah', 'O'), ('apa', 'O'), ('yang', 'O'), ('hendak', 'O'), ('kamu', 'O'), ('lemparkan', 'O'), ('!', 'O'), ('”', 'O'), ('Setelah', 'O'), ('mereka', 'O'), ('melemparkan', 'O'), ('(', 'O'), ('tali-temali', 'O'), (')', 'O'), (',', 'O'), ('Musa', 'Messenger'), ('berkata', 'O'), (',', 'O'), ('“', 'O'), ('Apa', 'O'), ('yang', 'O'), ('kamu', 'O'), ('bawa', 'O'), ('itulah', 'O'), ('sihir', 'O'), ('.', 'O')]
# prediction
# ”/O Fir‘aun/Leader berkata/O (/O kepada/O para/O pemuka/O kaumnya/O )/O ,/O “/O Datangkanlah/O kepadaku/O semua/O penyihir/O yang/O ulung/O !/O ”/O Ketika/O para/O penyihir/O itu/O datang/O ,/O Musa/Messenger berkata/O kepada/O mereka/O ,/O “/O Lemparkanlah/O apa/O yang/O hendak/O kamu/O lemparkan/O !/O ”/O Setelah/O mereka/O melemparkan/O (/O tali-temali/O )/O ,/O Musa/Messenger berkata/O ,/O “/O Apa/O yang/O kamu/O bawa/O itulah/O sihir/O ./O
# Prediction Tokens:
#  [('”', 'O'), ('Fir‘aun', 'Leader'), ('berkata', 'O'), ('(', 'O'), ('kepada', 'O'), ('para', 'O'), ('pemuka', 'O'), ('kaumnya', 'O'), (')', 'O'), (',', 'O'), ('“', 'O'), ('Datangkanlah', 'O'), ('kepadaku', 'O'), ('semua', 'O'), ('penyihir', 'O'), ('yang', 'O'), ('ulung', 'O'), ('!', 'O'), ('”', 'O'), ('Ketika', 'O'), ('para', 'O'), ('penyihir', 'O'), ('itu', 'O'), ('datang', 'O'), (',', 'O'), ('Musa', 'Messenger'), ('berkata', 'O'), ('kepada', 'O'), ('mereka', 'O'), (',', 'O'), ('“', 'O'), ('Lemparkanlah', 'O'), ('apa', 'O'), ('yang', 'O'), ('hendak', 'O'), ('kamu', 'O'), ('lemparkan', 'O'), ('!', 'O'), ('”', 'O'), ('Setelah', 'O'), ('mereka', 'O'), ('melemparkan', 'O'), ('(', 'O'), ('tali-temali', 'O'), (')', 'O'), (',', 'O'), ('Musa', 'Messenger'), ('berkata', 'O'), (',', 'O'), ('“', 'O'), ('Apa', 'O'), ('yang', 'O'), ('kamu', 'O'), ('bawa', 'O'), ('itulah', 'O'), ('sihir', 'O'), ('.', 'O')]
# correct:
# ...
# Prediction Tokens:
#  [('Apakah', 'O'), ('dia', 'O'), ('akan', 'O'), ('memeliharanya', 'O'), ('dengan', 'O'), ('(', 'O'), ('menanggung', 'O'), (')', 'O'), ('kehinaan', 'O'), ('atau', 'O'), ('akan', 'O'), ('membenamkannya', 'O'), ('ke', 'O'), ('dalam', 'O'), ('tanah', 'O'), ('(', 'O'), ('hidup-hidup', 'O'), (')', 'O'), ('?', 'O'), ('Ingatlah', 'O'), (',', 'O'), ('alangkah', 'O'), ('buruk', 'O'), ('(', 'O'), ('putusan', 'O'), (')', 'O'), ('yang', 'O'), ('mereka', 'O'), ('tetapkan', 'O'), ('itu', 'O'), ('!', 'O'), ('Orang-orang', 'O'), ('yang', 'O'), ('tidak', 'O'), ('beriman', 'O'), ('pada', 'O'), ('(', 'O'), ('kehidupan', 'O'), (')', 'O'), ('akhirat', 'Akhirat'), ('mempunyai', 'O'), ('sifat', 'O'), ('yang', 'O'), ('buruk', 'O'), (',', 'O'), ('sedangkan', 'O'), ('Allah', 'Allah'), ('mempunyai', 'O'), ('sifat', 'O'), ('Yang', 'O'), ('Mahatinggi', 'O'), ('.', 'O')]
# correct:
#  [('Apakah', 'O'), ('dia', 'O'), ('akan', 'O'), ('memeliharanya', 'O'), ('dengan', 'O'), ('(', 'O'), ('menanggung', 'O'), (')', 'O'), ('kehinaan', 'O'), ('atau', 'O'), ('akan', 'O'), ('membenamkannya', 'O'), ('ke', 'O'), ('dalam', 'O'), ('tanah', 'O'), ('(', 'O'), ('hidup-hidup', 'O'), (')', 'O'), ('?', 'O'), ('Ingatlah', 'O'), (',', 'O'), ('alangkah', 'O'), ('buruk', 'O'), ('(', 'O'), ('putusan', 'O'), (')', 'O'), ('yang', 'O'), ('mereka', 'O'), ('tetapkan', 'O'), ('itu', 'O'), ('!', 'O'), ('Orang-orang', 'O'), ('yang', 'O'), ('tidak', 'O'), ('beriman', 'O'), ('pada', 'O'), ('(', 'O'), ('kehidupan', 'O'), (')', 'O'), ('mempunyai', 'O'), ('sifat', 'O'), ('yang', 'O'), ('buruk', 'O'), (',', 'O'), ('sedangkan', 'O'), ('Allah', 'Allah'), ('mempunyai', 'O'), ('sifat', 'O'), ('.', 'O')]
# Correct: 49, Guessed: 52, Total: 51
# Metrics(tp=49, fp=3, fn=2, prec=0.9423076923076923, rec=0.9607843137254902, fscore=0.9514563106796117)
# ######### Instance 191 ##############
# Label Tokens:
#  [('Dia', 'O'), ('Mahaperkasa', 'O'), ('lagi', 'O'), ('Mahabijaksana', 'O'), ('.', 'O')]
# prediction
# Dia/O Mahaperkasa/O lagi/O Mahabijaksana/O ./O
# Prediction Tokens:
#  [('Dia', 'O'), ('Mahaperkasa', 'O'), ('lagi', 'O'), ('Mahabijaksana', 'O'), ('.', 'O')]
# correct:
#  [('Dia', 'O'), ('Mahaperkasa', 'O'), ('lagi', 'O'), ('Mahabijaksana', 'O'), ('.', 'O')]
# Correct: 5, Guessed: 5, Total: 5
# Metrics(tp=5, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 192 ##############
# uncover ```
# uncover ```
# Label Tokens:
#  [('Seandainya', 'O'), ('Allah', 'Allah'), ('menghukum', 'O'), ('manusia', 'O'), ('karena', 'O'), ('kezaliman', 'O'), ('mereka', 'O'), (',', 'O'), ('niscaya', 'O'), ('Dia', 'O'), ('tidak', 'O'), ('meninggalkan', 'O'), ('satu', 'O'), ('makhluk', 'O'), ('melata', 'O'), ('pun', 'O'), ('di', 'O'), ('atasnya', 'O'), ('(', 'O'), ('bumi', 'AstronomicalBody'), (')', 'O'), (',', 'O'), ('tetapi', 'O'), ('Dia', 'O'), ('menangguhkan', 'O'), ('mereka', 'O'), ('sampai', 'O'), ('waktu', 'O'), ('yang', 'O'), ('sudah', 'O'), ('ditentukan', 'O'), ('.', 'O')]
# prediction ```
# Seandainya/O Allah/Allah menghukum/O manusia/O karena/O kezaliman/O mereka/O ,/O niscaya/O Dia/Allah tidak/O meninggalkan/O satu/O makhluk/O melata/O pun/O di/O atasnya/O (/O bumi/Nature ),/O tetapi/O Dia/Allah menangguhkan/O mereka/O sampai/O waktu/O yang/O sudah/O ditentukan/O ./O
# ```
# Prediction Tokens:
#  [('Seandainya', 'O'), ('Allah', 'Allah'), ('menghukum', 'O'), ('manusia', 'O'), ('karena', 'O'), ('kezaliman', 'O'), ('mereka', 'O'), (',', 'O'), ('niscaya', 'O'), ('Dia', 'Allah'), ('tidak', 'O'), ('meninggalkan', 'O'), ('satu', 'O'), ('makhluk', 'O'), ('melata', 'O'), ('pun', 'O'), ('di', 'O'), ('atasnya', 'O'), ('(', 'O'), ('bumi', 'Nature'), ('),', 'O'), ('tetapi', 'O'), ('Dia', 'Allah'), ('menangguhkan', 'O'), ('mereka', 'O'), ('sampai', 'O'), ('waktu', 'O'), ('yang', 'O'), ('sudah', 'O'), ('ditentukan', 'O'), ('.', 'O')]
# correct:
#  [('Seandainya', 'O'), ('Allah', 'Allah'), ('menghukum', 'O'), ('manusia', 'O'), ('karena', 'O'), ('kezaliman', 'O'), ('mereka', 'O'), (',', 'O'), ('niscaya', 'O'), ('tidak', 'O'), ('meninggalkan', 'O'), ('satu', 'O'), ('makhluk', 'O'), ('melata', 'O'), ('pun', 'O'), ('di', 'O'), ('atasnya', 'O'), ('(', 'O'), ('tetapi', 'O'), ('menangguhkan', 'O'), ('mereka', 'O'), ('sampai', 'O'), ('waktu', 'O'), ('yang', 'O'), ('sudah', 'O'), ('ditentukan', 'O'), ('.', 'O')]
# Correct: 27, Guessed: 31, Total: 32
# Metrics(tp=27, fp=4, fn=5, prec=0.8709677419354839, rec=0.84375, fscore=0.8571428571428571)
# ######### Instance 193 ##############
# Label Tokens:
#  [('Maka', 'O'), (',', 'O'), ('apabila', 'O'), ('ajalnya', 'O'), ('tiba', 'O'), (',', 'O'), ('mereka', 'O'), ('tidak', 'O'), ('dapat', 'O'), ('meminta', 'O'), ('penundaan', 'O'), ('dan', 'O'), ('percepatan', 'O'), ('sesaat', 'O'), ('pun', 'O'), ('.', 'O')]
# prediction
# Maka/O ,/O apabila/O ajalnya/O tiba/O ,/O mereka/O tidak/O dapat/O meminta/O penundaan/O dan/O percepatan/O sesaat/O pun/O ./O
# Prediction Tokens:
#  [('Maka', 'O'), (',', 'O'), ('apabila', 'O'), ('ajalnya', 'O'), ('tiba', 'O'), (',', 'O'), ('mereka', 'O'), ('tidak', 'O'), ('dapat', 'O'), ('meminta', 'O'), ('penundaan', 'O'), ('dan', 'O'), ('percepatan', 'O'), ('sesaat', 'O'), ('pun', 'O'), ('.', 'O')]
# correct:
#  [('Maka', 'O'), (',', 'O'), ('apabila', 'O'), ('ajalnya', 'O'), ('tiba', 'O'), (',', 'O'), ('mereka', 'O'), ('tidak', 'O'), ('dapat', 'O'), ('meminta', 'O'), ('penundaan', 'O'), ('dan', 'O'), ('percepatan', 'O'), ('sesaat', 'O'), ('pun', 'O'), ('.', 'O')]
# Correct: 16, Guessed: 16, Total: 16
# Metrics(tp=16, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 194 ##############
# Label Tokens:
#  [('Mereka', 'O'), ('menetapkan', 'O'), ('bagi', 'O'), ('Allah', 'Allah'), ('apa', 'O'), ('yang', 'O'), ('mereka', 'O'), ('sendiri', 'O'), ('membencinya', 'O'), ('dan', 'O'), ('lidah', 'O'), ('mereka', 'O'), ('mengucapkan', 'O'), ('kebohongan', 'O'), ('bahwa', 'O'), ('sesungguhnya', 'O'), ('bagi', 'O'), ('merekalah', 'O'), ('(', 'O'), ('balasan', 'O'), (')', 'O'), ('yang', 'O'), ('terbaik', 'O'), ('(', 'O'), ('surga', 'O'), (')', 'O'), ('.', 'O')]
# prediction
# Mereka/O menetapkan/O bagi/O Allah/Allah apa/O yang/O mereka/O sendiri/O membencinya/O dan/O lidah/O mereka/O mengucapkan/O kebohongan/O bahwa/O sesungguhnya/O bagi/O merekalah/O (/O balasan/O )/O yang/O terbaik/O (/O surga/Paradise )/O ./O
# Prediction Tokens:
#  [('Mereka', 'O'), ('menetapkan', 'O'), ('bagi', 'O'), ('Allah', 'Allah'), ('apa', 'O'), ('yang', 'O'), ('mereka', 'O'), ('sendiri', 'O'), ('membencinya', 'O'), ('dan', 'O'), ('lidah', 'O'), ('mereka', 'O'), ('mengucapkan', 'O'), ('kebohongan', 'O'), ('bahwa', 'O'), ('sesungguhnya', 'O'), ('bagi', 'O'), ('merekalah', 'O'), ('(', 'O'), ('balasan', 'O'), (')', 'O'), ('yang', 'O'), ('terbaik', 'O'), ('(', 'O'), ('surga', 'Paradise'), (')', 'O'), ('.', 'O')]
# correct:
#  [('Mereka', 'O'), ('menetapkan', 'O'), ('bagi', 'O'), ('Allah', 'Allah'), ('apa', 'O'), ('yang', 'O'), ('mereka', 'O'), ('sendiri', 'O'), ('membencinya', 'O'), ('dan', 'O'), ('lidah', 'O'), ('mereka', 'O'), ('mengucapkan', 'O'), ('kebohongan', 'O'), ('bahwa', 'O'), ('sesungguhnya', 'O'), ('bagi', 'O'), ('merekalah', 'O'), ('(', 'O'), ('balasan', 'O'), (')', 'O'), ('yang', 'O'), ('terbaik', 'O'), ('(', 'O'), (')', 'O'), ('.', 'O')]
# Correct: 26, Guessed: 27, Total: 27
# Metrics(tp=26, fp=1, fn=1, prec=0.9629629629629629, rec=0.9629629629629629, fscore=0.9629629629629629)
# ######### Instance 195 ##############
# uncover ```plaintext
# uncover ```
# Label Tokens:
#  [('Tidak', 'O'), ('diragukan', 'O'), ('bahwa', 'O'), ('nerakalah', 'O'), ('(', 'O'), ('tempat', 'O'), ('yang', 'O'), ('layak', 'O'), (')', 'O'), ('bagi', 'O'), ('mereka', 'O'), ('dan', 'O'), ('sesungguhnya', 'O'), ('mereka', 'O'), ('segera', 'O'), ('akan', 'O'), ('dimasukkan', 'O'), ('(', 'O'), ('ke', 'O'), ('dalamnya', 'O'), (')', 'O'), ('.', 'O')]
# prediction ```plaintext
# Tidak/O diragukan/O bahwa/O nerakalah/OtherdsPlace (/O tempat/O yang/O layak/O )/O bagi/O mereka/O dan/O sesungguhnya/O mereka/O segera/O akan/O dimasukkan/O (/O ke/O dalamnya/O )/O ./O
# ```
# Prediction Tokens:
#  [('Tidak', 'O'), ('diragukan', 'O'), ('bahwa', 'O'), ('nerakalah', 'OtherdsPlace'), ('(', 'O'), ('tempat', 'O'), ('yang', 'O'), ('layak', 'O'), (')', 'O'), ('bagi', 'O'), ('mereka', 'O'), ('dan', 'O'), ('sesungguhnya', 'O'), ('mereka', 'O'), ('segera', 'O'), ('akan', 'O'), ('dimasukkan', 'O'), ('(', 'O'), ('ke', 'O'), ('dalamnya', 'O'), (')', 'O'), ('.', 'O')]
# correct:
#  [('Tidak', 'O'), ('diragukan', 'O'), ('bahwa', 'O'), ('(', 'O'), ('tempat', 'O'), ('yang', 'O'), ('layak', 'O'), (')', 'O'), ('bagi', 'O'), ('mereka', 'O'), ('dan', 'O'), ('sesungguhnya', 'O'), ('mereka', 'O'), ('segera', 'O'), ('akan', 'O'), ('dimasukkan', 'O'), ('(', 'O'), ('ke', 'O'), ('dalamnya', 'O'), (')', 'O'), ('.', 'O')]
# Correct: 21, Guessed: 22, Total: 22
# Metrics(tp=21, fp=1, fn=1, prec=0.9545454545454546, rec=0.9545454545454546, fscore=0.9545454545454546)
# ######### Instance 196 ##############
# Label Tokens:
#  [('Demi', 'O'), ('Allah', 'Allah'), (',', 'O'), ('sungguh', 'O'), ('Kami', 'O'), ('telah', 'O'), ('mengutus', 'O'), ('(', 'O'), ('rasul-rasul', 'O'), (')', 'O'), ('kepada', 'O'), ('umat-umat', 'O'), ('sebelum', 'O'), ('engkau', 'O'), ('(', 'O'), ('Nabi', 'O'), ('Muhammad', 'Messenger'), (')', 'O'), ('.', 'O')]
# prediction
# Demi/O Allah/Allah ,/O sungguh/O Kami/O telah/O mengutus/O (/O rasul-rasul/Messenger )/O kepada/O umat-umat/O sebelum/O engkau/O (/O Nabi/O Muhammad/Messenger )/O ./O
# Prediction Tokens:
#  [('Demi', 'O'), ('Allah', 'Allah'), (',', 'O'), ('sungguh', 'O'), ('Kami', 'O'), ('telah', 'O'), ('mengutus', 'O'), ('(', 'O'), ('rasul-rasul', 'Messenger'), (')', 'O'), ('kepada', 'O'), ('umat-umat', 'O'), ('sebelum', 'O'), ('engkau', 'O'), ('(', 'O'), ('Nabi', 'O'), ('Muhammad', 'Messenger'), (')', 'O'), ('.', 'O')]
# correct:
#  [('Demi', 'O'), ('Allah', 'Allah'), (',', 'O'), ('sungguh', 'O'), ('Kami', 'O'), ('telah', 'O'), ('mengutus', 'O'), ('(', 'O'), (')', 'O'), ('kepada', 'O'), ('umat-umat', 'O'), ('sebelum', 'O'), ('engkau', 'O'), ('(', 'O'), ('Nabi', 'O'), ('Muhammad', 'Messenger'), (')', 'O'), ('.', 'O')]
# Correct: 18, Guessed: 19, Total: 19
# Metrics(tp=18, fp=1, fn=1, prec=0.9473684210526315, rec=0.9473684210526315, fscore=0.9473684210526315)
# ######### Instance 197 ##############
# Label Tokens:
#  [('Akan', 'O'), ('tetapi', 'O'), (',', 'O'), ('setan', 'O'), ('menjadikan', 'O'), ('perbuatan', 'O'), ('mereka', 'O'), ('(', 'O'), ('yang', 'O'), ('buruk', 'O'), (')', 'O'), ('terasa', 'O'), ('indah', 'O'), ('bagi', 'O'), ('mereka', 'O'), ('sehingga', 'O'), ('ia', 'O'), ('(', 'O'), ('setan', 'O'), (')', 'O'), ('menjadi', 'O'), ('pemimpin', 'O'), ('mereka', 'O'), ('pada', 'O'), ('hari', 'O'), ('ini', 'O'), ('(', 'O'), ('di', 'O'), ('dunia', 'O'), (')', 'O'), ('dan', 'O'), ('bagi', 'O'), ('mereka', 'O'), ('azab', 'O'), ('yang', 'O'), ('sangat', 'O'), ('pedih', 'O'), ('(', 'O'), ('di', 'O'), ('akhirat', 'O'), (')', 'O'), ('.', 'O')]
# prediction
# Akan/O tetapi/O ,/O setan/Satan menjadikan/O perbuatan/O mereka/O (/O yang/O buruk/O )/O terasa/O indah/O bagi/O mereka/O sehingga/O ia/O (/O setan/Satan )/O menjadi/O pemimpin/O mereka/O pada/O hari/O ini/O (/O di/O dunia/Afterlife )/O dan/O bagi/O mereka/O azab/O yang/O sangat/O pedih/O (/O di/O akhirat/Afterlife )/O ./O
# Prediction Tokens:
#  [('Akan', 'O'), ('tetapi', 'O'), (',', 'O'), ('setan', 'Satan'), ('menjadikan', 'O'), ('perbuatan', 'O'), ('mereka', 'O'), ('(', 'O'), ('yang', 'O'), ('buruk', 'O'), (')', 'O'), ('terasa', 'O'), ('indah', 'O'), ('bagi', 'O'), ('mereka', 'O'), ('sehingga', 'O'), ('ia', 'O'), ('(', 'O'), ('setan', 'Satan'), (')', 'O'), ('menjadi', 'O'), ('pemimpin', 'O'), ('mereka', 'O'), ('pada', 'O'), ('hari', 'O'), ('ini', 'O'), ('(', 'O'), ('di', 'O'), ('dunia', 'Afterlife'), (')', 'O'), ('dan', 'O'), ('bagi', 'O'), ('mereka', 'O'), ('azab', 'O'), ('yang', 'O'), ('sangat', 'O'), ('pedih', 'O'), ('(', 'O'), ('di', 'O'), ('akhirat', 'Afterlife'), (')', 'O'), ('.', 'O')]
# correct:
#  [('Akan', 'O'), ('tetapi', 'O'), (',', 'O'), ('menjadikan', 'O'), ('perbuatan', 'O'), ('mereka', 'O'), ('(', 'O'), ('yang', 'O'), ('buruk', 'O'), (')', 'O'), ('terasa', 'O'), ('indah', 'O'), ('bagi', 'O'), ('mereka', 'O'), ('sehingga', 'O'), ('ia', 'O'), ('(', 'O'), (')', 'O'), ('menjadi', 'O'), ('pemimpin', 'O'), ('mereka', 'O'), ('pada', 'O'), ('hari', 'O'), ('ini', 'O'), ('(', 'O'), ('di', 'O'), (')', 'O'), ('dan', 'O'), ('bagi', 'O'), ('mereka', 'O'), ('azab', 'O'), ('yang', 'O'), ('sangat', 'O'), ('pedih', 'O'), ('(', 'O'), ('di', 'O'), (')', 'O'), ('.', 'O')]
# Correct: 38, Guessed: 42, Total: 42
# Metrics(tp=38, fp=4, fn=4, prec=0.9047619047619048, rec=0.9047619047619048, fscore=0.9047619047619048)
# ######### Instance 198 ##############
# Label Tokens:
#  [('Kami', 'O'), ('tidak', 'O'), ('menurunkan', 'O'), ('Kitab', 'O'), ('(', 'O'), ('Al-Qur’an', 'HolyBook'), (')', 'O'), ('ini', 'O'), ('kepadamu', 'O'), ('(', 'O'), ('Nabi', 'O'), ('Muhammad', 'Messenger'), (')', 'O'), (',', 'O'), ('kecuali', 'O'), ('agar', 'O'), ('engkau', 'O'), ('menjelaskan', 'O'), ('kepada', 'O'), ('mereka', 'O'), ('apa', 'O'), ('yang', 'O'), ('mereka', 'O'), ('perselisihkan', 'O'), ('serta', 'O'), ('menjadi', 'O'), ('petunjuk', 'O'), ('dan', 'O'), ('rahmat', 'O'), ('bagi', 'O'), ('kaum', 'O'), ('yang', 'O'), ('beriman', 'O'), ('.', 'O')]
# prediction
# Kami/O tidak/O menurunkan/O Kitab/HolyBook (/O Al-Qur’an/HolyBook )/O ini/O kepadamu/O (/O Nabi/O Muhammad/Messenger )/O ,/O kecuali/O agar/O engkau/O menjelaskan/O kepada/O mereka/O apa/O yang/O mereka/O perselisihkan/O serta/O menjadi/O petunjuk/O dan/O rahmat/O bagi/O kaum/O yang/O beriman/O ./O
# Prediction Tokens:
#  [('Kami', 'O'), ('tidak', 'O'), ('menurunkan', 'O'), ('Kitab', 'HolyBook'), ('(', 'O'), ('Al-Qur’an', 'HolyBook'), (')', 'O'), ('ini', 'O'), ('kepadamu', 'O'), ('(', 'O'), ('Nabi', 'O'), ('Muhammad', 'Messenger'), (')', 'O'), (',', 'O'), ('kecuali', 'O'), ('agar', 'O'), ('engkau', 'O'), ('menjelaskan', 'O'), ('kepada', 'O'), ('mereka', 'O'), ('apa', 'O'), ('yang', 'O'), ('mereka', 'O'), ('perselisihkan', 'O'), ('serta', 'O'), ('menjadi', 'O'), ('petunjuk', 'O'), ('dan', 'O'), ('rahmat', 'O'), ('bagi', 'O'), ('kaum', 'O'), ('yang', 'O'), ('beriman', 'O'), ('.', 'O')]
# correct:
#  [('Kami', 'O'), ('tidak', 'O'), ('menurunkan', 'O'), ('(', 'O'), ('Al-Qur’an', 'HolyBook'), (')', 'O'), ('ini', 'O'), ('kepadamu', 'O'), ('(', 'O'), ('Nabi', 'O'), ('Muhammad', 'Messenger'), (')', 'O'), (',', 'O'), ('kecuali', 'O'), ('agar', 'O'), ('engkau', 'O'), ('menjelaskan', 'O'), ('kepada', 'O'), ('mereka', 'O'), ('apa', 'O'), ('yang', 'O'), ('mereka', 'O'), ('perselisihkan', 'O'), ('serta', 'O'), ('menjadi', 'O'), ('petunjuk', 'O'), ('dan', 'O'), ('rahmat', 'O'), ('bagi', 'O'), ('kaum', 'O'), ('yang', 'O'), ('beriman', 'O'), ('.', 'O')]
# Correct: 33, Guessed: 34, Total: 34
# Metrics(tp=33, fp=1, fn=1, prec=0.9705882352941176, rec=0.9705882352941176, fscore=0.9705882352941176)
# ######### Instance 199 ##############
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 62
#      60 # Tokenize label and prediction
#      61 label_tokens = tokenize_label_pred(label.strip())
# ---> 62 prediction_tokens = tokenize_label_pred(predictions[id_])
#      64 # Count frequencies of tokens in label and prediction
#      65 label_token_counts = Counter(label_tokens)
#
# Cell In[10], line 11, in tokenize_label_pred(text)
#       9 def tokenize_label_pred(text):
#      10     tokens = []
# ---> 11     for token in text.split():
#      12         if "//" in token:
#      13             token = token.replace("//", "/")
#
# AttributeError: 'NoneType' object has no attribute 'split'
