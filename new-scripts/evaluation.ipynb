# %%
import json
import pandas as pd
from collections import defaultdict, namedtuple, Counter

# Namedtuple to store evaluation metrics
Metrics = namedtuple('Metrics', 'tp fp fn prec rec fscore')

# Tokenize the label and prediction into word/tag pairs
def tokenize_label_pred(text):
    tokens = []
    for token in text.split():
        if "//" in token:
            token = token.replace("//", "/")
        if len(token.split("/")) == 2:
            r = (token.split('/')[-2], token.split('/')[-1])
            tokens.append(r)
        else:
            #Split into two results
            #print(token)
            if len(token.split("/"))==3:
                r1 = (token.split("/")[0], token.split("/")[1][0])
                r2 = (token.split("/")[1][1:], token.split("/")[2])
                tokens.append(r1)
                tokens.append(r2)
            else:
                print("uncover", token)
    return tokens

# Function to calculate precision, recall, and F1 score
def calculate_metrics(correct, guessed, total):
    tp, fp, fn = correct, guessed - correct, total - correct
    # Precision, Recall, F1 Score calculations
    p = 0 if tp + fp == 0 else tp / (tp + fp)
    r = 0 if tp + fn == 0 else tp / (tp + fn)
    f = 0 if p + r == 0 else 2 * p * r / (p + r)
    return Metrics(tp, fp, fn, p, r, f)

# File paths for test labels and predictions
test_labels_path_new = '../new-datasets/test_with_labels.txt'
results_path_new = 'results/results-one-shot-llama-3-70B.json'

# Read ground truth labels
with open(test_labels_path_new, 'r', encoding='utf-8') as f:
    ground_truth = f.readlines()

# Read predictions from the model
with open(results_path_new, 'r', encoding='utf-8') as f:
    predictions = json.load(f)

# Lists to store precision, recall, F1 for each instance
precs, recs, fscores = [], [], []

# Iterate over each label and corresponding prediction
for num, label in enumerate(ground_truth):
    # Initialize counters for correct matches and errors
    correct = 0
    id_ = str(num + 1)  # Key in the predictions JSON
    print(f"######### Instance {id_} ##############")
    
    # Tokenize label and prediction
    label_tokens = tokenize_label_pred(label.strip())
    prediction_tokens = tokenize_label_pred(predictions[id_].strip())

    # Count frequencies of tokens in label and prediction
    label_token_counts = Counter(label_tokens)
    prediction_token_counts = Counter(prediction_tokens)
    
    # Print for debugging
    print("Label Tokens:\n", label_tokens)
    print("prediction", predictions[id_])
    print("Prediction Tokens:\n", prediction_tokens)

    total = len(label_tokens)  # Total actual tokens
    guessed = len(prediction_tokens)  # Total predicted tokens

    # Track seen tokens from the prediction to avoid duplicates
    seen_in_prediction = []
    
    for pred_token in prediction_tokens:
        # Only count correct if the frequency in prediction <= frequency in label
        if pred_token in label_tokens and prediction_token_counts[pred_token] <= label_token_counts[pred_token]:
            if seen_in_prediction.count(pred_token) < label_token_counts[pred_token]:
                correct += 1  # Count true positives
                seen_in_prediction.append(pred_token)  # Mark as seen

    print("correct:\n", seen_in_prediction)
    # Final counts: TP = correct, FP = guessed - correct, FN = total - correct
    print(f"Correct: {correct}, Guessed: {guessed}, Total: {total}")
    metrics = calculate_metrics(correct, guessed, total)
    print(metrics)
    
    # Append the precision, recall, and F1 score for this instance
    precs.append(metrics.prec)
    recs.append(metrics.rec)
    fscores.append(metrics.fscore)

# Compute averages over all instances
avg_precs = sum(precs) / len(precs)
avg_recs = sum(recs) / len(recs)
avg_fscores = sum(fscores) / len(fscores)

# Print final averages
print("Total records in the test set:", len(ground_truth))
print("Average Precision:", avg_precs)
print("Average Recall:", avg_recs)
print("Average F1 Score:", avg_fscores)
# Out:
# ######### Instance 1 ##############
# Label Tokens:
#  [('Tidak', 'O'), ('ada', 'O'), ('sesuatu', 'O'), ('yang', 'O'), ('lebih', 'O'), ('kecil', 'O'), ('dan', 'O'), ('yang', 'O'), ('lebih', 'O'), ('besar', 'O'), ('daripada', 'O'), ('itu', 'O'), (',', 'O'), ('kecuali', 'O'), ('semua', 'O'), ('tercatat', 'O'), ('dalam', 'O'), ('kitab', 'O'), ('yang', 'O'), ('nyata', 'O'), ('(', 'O'), ('Lauh', 'O'), ('Mahfuz', 'O'), (')', 'O'), ('.', 'O')]
# prediction Tidak/O ada/O sesuatu/O yang/O lebih/O kecil/O dan/O yang/O lebih/O besar/O daripada/O itu/O,/O kecuali/O semua/O tercatat/O dalam/O kitab/O yang/O nyata/O (/O Lauh/O Mahfuz/HolyBook )/O./O
# Prediction Tokens:
#  [('Tidak', 'O'), ('ada', 'O'), ('sesuatu', 'O'), ('yang', 'O'), ('lebih', 'O'), ('kecil', 'O'), ('dan', 'O'), ('yang', 'O'), ('lebih', 'O'), ('besar', 'O'), ('daripada', 'O'), ('itu', 'O'), (',', 'O'), ('kecuali', 'O'), ('semua', 'O'), ('tercatat', 'O'), ('dalam', 'O'), ('kitab', 'O'), ('yang', 'O'), ('nyata', 'O'), ('(', 'O'), ('Lauh', 'O'), ('Mahfuz', 'HolyBook'), (')', 'O'), ('.', 'O')]
# correct:
#  [('Tidak', 'O'), ('ada', 'O'), ('sesuatu', 'O'), ('yang', 'O'), ('lebih', 'O'), ('kecil', 'O'), ('dan', 'O'), ('yang', 'O'), ('lebih', 'O'), ('besar', 'O'), ('daripada', 'O'), ('itu', 'O'), (',', 'O'), ('kecuali', 'O'), ('semua', 'O'), ('tercatat', 'O'), ('dalam', 'O'), ('kitab', 'O'), ('yang', 'O'), ('nyata', 'O'), ('(', 'O'), ('Lauh', 'O'), (')', 'O'), ('.', 'O')]
# Correct: 24, Guessed: 25, Total: 25
# Metrics(tp=24, fp=1, fn=1, prec=0.96, rec=0.96, fscore=0.96)
# ######### Instance 2 ##############
# Label Tokens:
#  [('Ketahuilah', 'O'), ('bahwa', 'O'), ('sesungguhnya', 'O'), ('(', 'O'), ('bagi', 'O'), (')', 'O'), ('para', 'O'), ('wali', 'O'), ('Allah', 'Allah'), ('itu', 'O'), ('tidak', 'O'), ('ada', 'O'), ('rasa', 'O'), ('takut', 'O'), ('yang', 'O'), ('menimpa', 'O'), ('mereka', 'O'), ('dan', 'O'), ('mereka', 'O'), ('pun', 'O'), ('tidak', 'O'), ('bersedih', 'O'), ('.', 'O')]
# prediction Ketahuilah/O bahwa/O sesungguhnya/O bagi/O para/O wali/O (/O Allah/Allah )/O itu/O tidak/O ada/O rasa/O takut/O yang/O menimpa/O mereka/O dan/O mereka/O pun/O tidak/O bersedih/O./O
# Prediction Tokens:
#  [('Ketahuilah', 'O'), ('bahwa', 'O'), ('sesungguhnya', 'O'), ('bagi', 'O'), ('para', 'O'), ('wali', 'O'), ('(', 'O'), ('Allah', 'Allah'), (')', 'O'), ('itu', 'O'), ('tidak', 'O'), ('ada', 'O'), ('rasa', 'O'), ('takut', 'O'), ('yang', 'O'), ('menimpa', 'O'), ('mereka', 'O'), ('dan', 'O'), ('mereka', 'O'), ('pun', 'O'), ('tidak', 'O'), ('bersedih', 'O'), ('.', 'O')]
# correct:
#  [('Ketahuilah', 'O'), ('bahwa', 'O'), ('sesungguhnya', 'O'), ('bagi', 'O'), ('para', 'O'), ('wali', 'O'), ('(', 'O'), ('Allah', 'Allah'), (')', 'O'), ('itu', 'O'), ('tidak', 'O'), ('ada', 'O'), ('rasa', 'O'), ('takut', 'O'), ('yang', 'O'), ('menimpa', 'O'), ('mereka', 'O'), ('dan', 'O'), ('mereka', 'O'), ('pun', 'O'), ('tidak', 'O'), ('bersedih', 'O'), ('.', 'O')]
# Correct: 23, Guessed: 23, Total: 23
# Metrics(tp=23, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 3 ##############
# uncover Test
# uncover output:
# uncover (
# uncover )
# Label Tokens:
#  [('(', 'O'), ('Mereka', 'O'), ('adalah', 'O'), (')', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('beriman', 'O'), ('dan', 'O'), ('selalu', 'O'), ('bertakwa', 'O'), ('.', 'O')]
# prediction Test output: ( Mereka/O adalah/O ) orang-orang/O yang/O beriman/O dan/O selalu/O bertakwa/O.
# Prediction Tokens:
#  [('Mereka', 'O'), ('adalah', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('beriman', 'O'), ('dan', 'O'), ('selalu', 'O'), ('bertakwa', 'O.')]
# correct:
#  [('Mereka', 'O'), ('adalah', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('beriman', 'O'), ('dan', 'O'), ('selalu', 'O')]
# Correct: 7, Guessed: 8, Total: 11
# Metrics(tp=7, fp=1, fn=4, prec=0.875, rec=0.6363636363636364, fscore=0.7368421052631579)
# ######### Instance 4 ##############
# Label Tokens:
#  [('Bagi', 'O'), ('mereka', 'O'), ('berita', 'O'), ('gembira', 'O'), ('di', 'O'), ('dalam', 'O'), ('kehidupan', 'O'), ('di', 'O'), ('dunia', 'O'), ('dan', 'O'), ('di', 'O'), ('akhirat', 'O'), ('.', 'O')]
# prediction Bagi/O mereka/O berita/O gembira/O di/O dalam/O kehidupan/O di/O dunia/AfterlifeLocation dan/O di/O akhirat/AfterlifeLocation./O
# Prediction Tokens:
#  [('Bagi', 'O'), ('mereka', 'O'), ('berita', 'O'), ('gembira', 'O'), ('di', 'O'), ('dalam', 'O'), ('kehidupan', 'O'), ('di', 'O'), ('dunia', 'AfterlifeLocation'), ('dan', 'O'), ('di', 'O'), ('akhirat', 'A'), ('fterlifeLocation.', 'O')]
# correct:
#  [('Bagi', 'O'), ('mereka', 'O'), ('berita', 'O'), ('gembira', 'O'), ('di', 'O'), ('dalam', 'O'), ('kehidupan', 'O'), ('di', 'O'), ('dan', 'O'), ('di', 'O')]
# Correct: 10, Guessed: 13, Total: 13
# Metrics(tp=10, fp=3, fn=3, prec=0.7692307692307693, rec=0.7692307692307693, fscore=0.7692307692307693)
# ######### Instance 5 ##############
# Label Tokens:
#  [('Tidak', 'O'), ('ada', 'O'), ('perubahan', 'O'), ('bagi', 'O'), ('kalimat-kalimat', 'O'), ('(', 'O'), ('ketetapan', 'O'), ('dan', 'O'), ('janji', 'O'), (')', 'O'), ('Allah', 'Allah'), ('.', 'O')]
# prediction Tidak/O ada/O perubahan/O bagi/O kalimat-kalimat/O (/O ketetapan/O dan/O janji/O )/O Allah/Allah./O
# Prediction Tokens:
#  [('Tidak', 'O'), ('ada', 'O'), ('perubahan', 'O'), ('bagi', 'O'), ('kalimat-kalimat', 'O'), ('(', 'O'), ('ketetapan', 'O'), ('dan', 'O'), ('janji', 'O'), (')', 'O'), ('Allah', 'A'), ('llah.', 'O')]
# correct:
#  [('Tidak', 'O'), ('ada', 'O'), ('perubahan', 'O'), ('bagi', 'O'), ('kalimat-kalimat', 'O'), ('(', 'O'), ('ketetapan', 'O'), ('dan', 'O'), ('janji', 'O'), (')', 'O')]
# Correct: 10, Guessed: 12, Total: 12
# Metrics(tp=10, fp=2, fn=2, prec=0.8333333333333334, rec=0.8333333333333334, fscore=0.8333333333333334)
# ######### Instance 6 ##############
# Label Tokens:
#  [('Demikian', 'O'), ('itulah', 'O'), ('kemenangan', 'O'), ('yang', 'O'), ('agung', 'O'), ('.', 'O')]
# prediction Demikian/O itulah/O kemenangan/O yang/O agung/O./O
# Prediction Tokens:
#  [('Demikian', 'O'), ('itulah', 'O'), ('kemenangan', 'O'), ('yang', 'O'), ('agung', 'O'), ('.', 'O')]
# correct:
#  [('Demikian', 'O'), ('itulah', 'O'), ('kemenangan', 'O'), ('yang', 'O'), ('agung', 'O'), ('.', 'O')]
# Correct: 6, Guessed: 6, Total: 6
# Metrics(tp=6, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 7 ##############
# Label Tokens:
#  [('Janganlah', 'O'), ('engkau', 'O'), ('(', 'O'), ('Nabi', 'O'), ('Muhammad', 'Messenger'), (')', 'O'), ('sedih', 'O'), ('oleh', 'O'), ('perkataan', 'O'), ('mereka', 'O'), ('.', 'O')]
# prediction Janganlah/O engkau/O (Nabi/O Muhammad/Messenger)/O sedih/O oleh/O perkataan/O mereka/O./O
# Prediction Tokens:
#  [('Janganlah', 'O'), ('engkau', 'O'), ('(Nabi', 'O'), ('Muhammad', 'M'), ('essenger)', 'O'), ('sedih', 'O'), ('oleh', 'O'), ('perkataan', 'O'), ('mereka', 'O'), ('.', 'O')]
# correct:
#  [('Janganlah', 'O'), ('engkau', 'O'), ('sedih', 'O'), ('oleh', 'O'), ('perkataan', 'O'), ('mereka', 'O'), ('.', 'O')]
# Correct: 7, Guessed: 10, Total: 11
# Metrics(tp=7, fp=3, fn=4, prec=0.7, rec=0.6363636363636364, fscore=0.6666666666666666)
# ######### Instance 8 ##############
# Label Tokens:
#  [('Sesungguhnya', 'O'), ('kekuasaan', 'O'), ('itu', 'O'), ('seluruhnya', 'O'), ('milik', 'O'), ('Allah', 'Allah'), ('.', 'O')]
# prediction Sesungguhnya/O kekuasaan/O itu/O seluruhnya/O milik/O Allah/Allah./O
# Prediction Tokens:
#  [('Sesungguhnya', 'O'), ('kekuasaan', 'O'), ('itu', 'O'), ('seluruhnya', 'O'), ('milik', 'O'), ('Allah', 'A'), ('llah.', 'O')]
# correct:
#  [('Sesungguhnya', 'O'), ('kekuasaan', 'O'), ('itu', 'O'), ('seluruhnya', 'O'), ('milik', 'O')]
# Correct: 5, Guessed: 7, Total: 7
# Metrics(tp=5, fp=2, fn=2, prec=0.7142857142857143, rec=0.7142857142857143, fscore=0.7142857142857143)
# ######### Instance 9 ##############
# Label Tokens:
#  [('Dia', 'O'), ('Maha', 'O'), ('Mendengar', 'O'), ('lagi', 'O'), ('Maha', 'O'), ('Mengetahui', 'O'), ('.', 'O')]
# prediction Dia/O Maha/O Mendengar/O lagi/O Maha/O Mengetahui/O./O
# Prediction Tokens:
#  [('Dia', 'O'), ('Maha', 'O'), ('Mendengar', 'O'), ('lagi', 'O'), ('Maha', 'O'), ('Mengetahui', 'O'), ('.', 'O')]
# correct:
#  [('Dia', 'O'), ('Maha', 'O'), ('Mendengar', 'O'), ('lagi', 'O'), ('Maha', 'O'), ('Mengetahui', 'O'), ('.', 'O')]
# Correct: 7, Guessed: 7, Total: 7
# Metrics(tp=7, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 10 ##############
# Label Tokens:
#  [('Ketahuilah', 'O'), ('bahwa', 'O'), ('sesungguhnya', 'O'), ('milik', 'O'), ('Allahlah', 'O'), ('siapa', 'O'), ('yang', 'O'), ('ada', 'O'), ('di', 'O'), ('langit', 'O'), ('dan', 'O'), ('siapa', 'O'), ('yang', 'O'), ('ada', 'O'), ('di', 'O'), ('bumi', 'AstronomicalBody'), ('.', 'O')]
# prediction Ketahuilah/O bahwa/O sesungguhnya/O milik/O (/O Allah/Allah )/O lah/O siapa/O yang/O ada/O di/O (/O langit/AstronomicalBody )/O dan/O siapa/O yang/O ada/O di/O (/O bumi/GeographicalLocation )/O.
# Prediction Tokens:
#  [('Ketahuilah', 'O'), ('bahwa', 'O'), ('sesungguhnya', 'O'), ('milik', 'O'), ('(', 'O'), ('Allah', 'Allah'), (')', 'O'), ('lah', 'O'), ('siapa', 'O'), ('yang', 'O'), ('ada', 'O'), ('di', 'O'), ('(', 'O'), ('langit', 'AstronomicalBody'), (')', 'O'), ('dan', 'O'), ('siapa', 'O'), ('yang', 'O'), ('ada', 'O'), ('di', 'O'), ('(', 'O'), ('bumi', 'GeographicalLocation'), (')', 'O.')]
# correct:
#  [('Ketahuilah', 'O'), ('bahwa', 'O'), ('sesungguhnya', 'O'), ('milik', 'O'), ('siapa', 'O'), ('yang', 'O'), ('ada', 'O'), ('di', 'O'), ('dan', 'O'), ('siapa', 'O'), ('yang', 'O'), ('ada', 'O'), ('di', 'O')]
# Correct: 13, Guessed: 23, Total: 17
# Metrics(tp=13, fp=10, fn=4, prec=0.5652173913043478, rec=0.7647058823529411, fscore=0.65)
# ######### Instance 11 ##############
# uncover ).
# Label Tokens:
#  [('Orang-orang', 'O'), ('yang', 'O'), ('menyeru', 'O'), ('sekutu-sekutu', 'O'), ('selain', 'O'), ('Allah', 'Allah'), ('tidaklah', 'O'), ('mengikuti', 'O'), ('(', 'O'), ('suatu', 'O'), ('kebenaran', 'O'), (')', 'O'), ('.', 'O')]
# prediction Orang-orang/O yang/O menyeru/O sekutu-sekutu/O selain/O Allah/Allah tidaklah/O mengikuti/O (/O suatu/O kebenaran/O ).
# Prediction Tokens:
#  [('Orang-orang', 'O'), ('yang', 'O'), ('menyeru', 'O'), ('sekutu-sekutu', 'O'), ('selain', 'O'), ('Allah', 'Allah'), ('tidaklah', 'O'), ('mengikuti', 'O'), ('(', 'O'), ('suatu', 'O'), ('kebenaran', 'O')]
# correct:
#  [('Orang-orang', 'O'), ('yang', 'O'), ('menyeru', 'O'), ('sekutu-sekutu', 'O'), ('selain', 'O'), ('Allah', 'Allah'), ('tidaklah', 'O'), ('mengikuti', 'O'), ('(', 'O'), ('suatu', 'O'), ('kebenaran', 'O')]
# Correct: 11, Guessed: 11, Total: 13
# Metrics(tp=11, fp=0, fn=2, prec=1.0, rec=0.8461538461538461, fscore=0.9166666666666666)
# ######### Instance 12 ##############
# Label Tokens:
#  [('Mereka', 'O'), ('hanya', 'O'), ('mengikuti', 'O'), ('persangkaan', 'O'), ('belaka', 'O'), ('dan', 'O'), ('mereka', 'O'), ('hanyalah', 'O'), ('menduga-duga', 'O'), ('.', 'O')]
# prediction Mereka/O hanya/O mengikuti/O persangkaan/O belaka/O dan/O mereka/O hanyalah/O menduga-duga/O./O
# Prediction Tokens:
#  [('Mereka', 'O'), ('hanya', 'O'), ('mengikuti', 'O'), ('persangkaan', 'O'), ('belaka', 'O'), ('dan', 'O'), ('mereka', 'O'), ('hanyalah', 'O'), ('menduga-duga', 'O'), ('.', 'O')]
# correct:
#  [('Mereka', 'O'), ('hanya', 'O'), ('mengikuti', 'O'), ('persangkaan', 'O'), ('belaka', 'O'), ('dan', 'O'), ('mereka', 'O'), ('hanyalah', 'O'), ('menduga-duga', 'O'), ('.', 'O')]
# Correct: 10, Guessed: 10, Total: 10
# Metrics(tp=10, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 13 ##############
# Label Tokens:
#  [('Dialah', 'O'), ('yang', 'O'), ('menjadikan', 'O'), ('malam', 'O'), ('bagimu', 'O'), ('agar', 'O'), ('kamu', 'O'), ('beristirahat', 'O'), ('padanya', 'O'), ('dan', 'O'), ('(', 'O'), ('menjadikan', 'O'), (')', 'O'), ('siang', 'O'), ('terang', 'O'), ('benderang', 'O'), ('.', 'O')]
# prediction Dialah/O yang/O menjadikan/O malam/O bagimu/O agar/O kamu/O beristirahat/O padanya/O dan/O (menjadikan)/O siang/O terang/O benderang/O./O
# Prediction Tokens:
#  [('Dialah', 'O'), ('yang', 'O'), ('menjadikan', 'O'), ('malam', 'O'), ('bagimu', 'O'), ('agar', 'O'), ('kamu', 'O'), ('beristirahat', 'O'), ('padanya', 'O'), ('dan', 'O'), ('(menjadikan)', 'O'), ('siang', 'O'), ('terang', 'O'), ('benderang', 'O'), ('.', 'O')]
# correct:
#  [('Dialah', 'O'), ('yang', 'O'), ('menjadikan', 'O'), ('malam', 'O'), ('bagimu', 'O'), ('agar', 'O'), ('kamu', 'O'), ('beristirahat', 'O'), ('padanya', 'O'), ('dan', 'O'), ('siang', 'O'), ('terang', 'O'), ('benderang', 'O'), ('.', 'O')]
# Correct: 14, Guessed: 15, Total: 17
# Metrics(tp=14, fp=1, fn=3, prec=0.9333333333333333, rec=0.8235294117647058, fscore=0.8749999999999999)
# ######### Instance 14 ##############
# Label Tokens:
#  [('Sesungguhnya', 'O'), ('pada', 'O'), ('yang', 'O'), ('demikian', 'O'), ('itu', 'O'), ('benar-benar', 'O'), ('terdapat', 'O'), ('tanda-tanda', 'O'), ('(', 'O'), ('kebesaran', 'O'), ('Allah', 'Allah'), (')', 'O'), ('bagi', 'O'), ('kaum', 'O'), ('yang', 'O'), ('(', 'O'), ('mau', 'O'), (')', 'O'), ('mendengar', 'O'), ('.', 'O')]
# prediction Sesungguhnya/O pada/O yang/O demikian/O itu/O benar-benar/O terdapat/O tanda-tanda/O bagi/O kaum/O yang/O (mau)/O mendengar/O./O (kebesaran/O Allah/Allah )/O
# Prediction Tokens:
#  [('Sesungguhnya', 'O'), ('pada', 'O'), ('yang', 'O'), ('demikian', 'O'), ('itu', 'O'), ('benar-benar', 'O'), ('terdapat', 'O'), ('tanda-tanda', 'O'), ('bagi', 'O'), ('kaum', 'O'), ('yang', 'O'), ('(mau)', 'O'), ('mendengar', 'O'), ('.', 'O'), ('(kebesaran', 'O'), ('Allah', 'Allah'), (')', 'O')]
# correct:
#  [('Sesungguhnya', 'O'), ('pada', 'O'), ('yang', 'O'), ('demikian', 'O'), ('itu', 'O'), ('benar-benar', 'O'), ('terdapat', 'O'), ('tanda-tanda', 'O'), ('bagi', 'O'), ('kaum', 'O'), ('yang', 'O'), ('mendengar', 'O'), ('.', 'O'), ('Allah', 'Allah'), (')', 'O')]
# Correct: 15, Guessed: 17, Total: 20
# Metrics(tp=15, fp=2, fn=5, prec=0.8823529411764706, rec=0.75, fscore=0.8108108108108107)
# ######### Instance 15 ##############
# uncover berkata,“
# Label Tokens:
#  [('Mereka', 'O'), ('(', 'O'), ('yang', 'O'), ('menyekutukan', 'O'), ('Allah', 'Allah'), (')', 'O'), ('berkata', 'O'), (',', 'O'), ('“', 'O'), ('Allah', 'Allah'), ('mengangkat', 'O'), ('anak', 'O'), ('.', 'O')]
# prediction Mereka/O (yang/O menyekutukan/O (/O Allah/Allah ))/O berkata,“ (/O Allah/Allah )/O mengangkat/O anak/O.
# Prediction Tokens:
#  [('Mereka', 'O'), ('(yang', 'O'), ('menyekutukan', 'O'), ('(', 'O'), ('Allah', 'Allah'), ('))', 'O'), ('(', 'O'), ('Allah', 'Allah'), (')', 'O'), ('mengangkat', 'O'), ('anak', 'O.')]
# correct:
#  [('Mereka', 'O'), ('menyekutukan', 'O'), ('Allah', 'Allah'), ('Allah', 'Allah'), (')', 'O'), ('mengangkat', 'O')]
# Correct: 6, Guessed: 11, Total: 13
# Metrics(tp=6, fp=5, fn=7, prec=0.5454545454545454, rec=0.46153846153846156, fscore=0.4999999999999999)
# ######### Instance 16 ##############
# Label Tokens:
#  [('”', 'O'), ('Mahasuci', 'O'), ('Dia', 'O'), ('.', 'O')]
# prediction ”Mahasuci/O Dia/Allah./O
# Prediction Tokens:
#  [('”Mahasuci', 'O'), ('Dia', 'A'), ('llah.', 'O')]
# correct:
#  []
# Correct: 0, Guessed: 3, Total: 4
# Metrics(tp=0, fp=3, fn=4, prec=0.0, rec=0.0, fscore=0)
# ######### Instance 17 ##############
# uncover Yang
# Label Tokens:
#  [('Dialah', 'O'), ('Mahakaya', 'Allah'), ('.', 'O')]
# prediction Dialah/O Yang/O Mahakaya/Allah.
# Prediction Tokens:
#  [('Dialah', 'O'), ('Yang', 'O'), ('Mahakaya', 'Allah.')]
# correct:
#  [('Dialah', 'O')]
# Correct: 1, Guessed: 3, Total: 3
# Metrics(tp=1, fp=2, fn=2, prec=0.3333333333333333, rec=0.3333333333333333, fscore=0.3333333333333333)
# ######### Instance 18 ##############
# Label Tokens:
#  [('Milik-Nyalah', 'O'), ('apa', 'O'), ('yang', 'O'), ('ada', 'O'), ('di', 'O'), ('langit', 'O'), ('dan', 'O'), ('apa', 'O'), ('yang', 'O'), ('ada', 'O'), ('di', 'O'), ('bumi', 'AstronomicalBody'), ('.', 'O')]
# prediction Milik/O Nyalah/O apa/O yang/O ada/O di/O (/O langit/AstronomicalBody )/O dan/O apa/O yang/O ada/O di/O (/O bumi/GeographicalLocation )/O.
# Prediction Tokens:
#  [('Milik', 'O'), ('Nyalah', 'O'), ('apa', 'O'), ('yang', 'O'), ('ada', 'O'), ('di', 'O'), ('(', 'O'), ('langit', 'AstronomicalBody'), (')', 'O'), ('dan', 'O'), ('apa', 'O'), ('yang', 'O'), ('ada', 'O'), ('di', 'O'), ('(', 'O'), ('bumi', 'GeographicalLocation'), (')', 'O.')]
# correct:
#  [('apa', 'O'), ('yang', 'O'), ('ada', 'O'), ('di', 'O'), ('dan', 'O'), ('apa', 'O'), ('yang', 'O'), ('ada', 'O'), ('di', 'O')]
# Correct: 9, Guessed: 17, Total: 13
# Metrics(tp=9, fp=8, fn=4, prec=0.5294117647058824, rec=0.6923076923076923, fscore=0.5999999999999999)
# ######### Instance 19 ##############
# Label Tokens:
#  [('Kamu', 'O'), ('tidak', 'O'), ('mempunyai', 'O'), ('alasan', 'O'), ('kuat', 'O'), ('tentang', 'O'), ('ini', 'O'), ('.', 'O')]
# prediction Kamu/O tidak/O mempunyai/O alasan/O kuat/O tentang/O ini/O./O
# Prediction Tokens:
#  [('Kamu', 'O'), ('tidak', 'O'), ('mempunyai', 'O'), ('alasan', 'O'), ('kuat', 'O'), ('tentang', 'O'), ('ini', 'O'), ('.', 'O')]
# correct:
#  [('Kamu', 'O'), ('tidak', 'O'), ('mempunyai', 'O'), ('alasan', 'O'), ('kuat', 'O'), ('tentang', 'O'), ('ini', 'O'), ('.', 'O')]
# Correct: 8, Guessed: 8, Total: 8
# Metrics(tp=8, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 20 ##############
# Label Tokens:
#  [('Pantaskah', 'O'), ('kamu', 'O'), ('mengatakan', 'O'), ('tentang', 'O'), ('Allah', 'Allah'), ('apa', 'O'), ('yang', 'O'), ('tidak', 'O'), ('kamu', 'O'), ('ketahui', 'O'), ('?', 'O'), ('Katakanlah', 'O'), ('(', 'O'), ('Nabi', 'O'), ('Muhammad', 'Messenger'), (')', 'O'), (',', 'O'), ('“', 'O'), ('Sesungguhnya', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('mengada-adakan', 'O'), ('kebohongan', 'O'), ('terhadap', 'O'), ('Allah', 'Allah'), ('tidak', 'O'), ('akan', 'O'), ('beruntung', 'O'), ('.', 'O')]
# prediction Pantaskah/O kamu/O mengatakan/O tentang/O Allah/Allah apa/O yang/O tidak/O kamu/O ketahui/O?/O Katakanlah/O (/O Nabi/O Muhammad/Messenger ),“/O Sesungguhnya/O orang-orang/O yang/O mengada-adakan/O kebohongan/O terhadap/O Allah/Allah tidak/O akan/O beruntung/O.
# Prediction Tokens:
#  [('Pantaskah', 'O'), ('kamu', 'O'), ('mengatakan', 'O'), ('tentang', 'O'), ('Allah', 'Allah'), ('apa', 'O'), ('yang', 'O'), ('tidak', 'O'), ('kamu', 'O'), ('ketahui', 'O'), ('?', 'O'), ('Katakanlah', 'O'), ('(', 'O'), ('Nabi', 'O'), ('Muhammad', 'Messenger'), ('),“', 'O'), ('Sesungguhnya', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('mengada-adakan', 'O'), ('kebohongan', 'O'), ('terhadap', 'O'), ('Allah', 'Allah'), ('tidak', 'O'), ('akan', 'O'), ('beruntung', 'O.')]
# correct:
#  [('Pantaskah', 'O'), ('kamu', 'O'), ('mengatakan', 'O'), ('tentang', 'O'), ('Allah', 'Allah'), ('apa', 'O'), ('yang', 'O'), ('tidak', 'O'), ('kamu', 'O'), ('ketahui', 'O'), ('?', 'O'), ('Katakanlah', 'O'), ('(', 'O'), ('Nabi', 'O'), ('Muhammad', 'Messenger'), ('Sesungguhnya', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('mengada-adakan', 'O'), ('kebohongan', 'O'), ('terhadap', 'O'), ('Allah', 'Allah'), ('tidak', 'O'), ('akan', 'O')]
# Correct: 24, Guessed: 26, Total: 29
# Metrics(tp=24, fp=2, fn=5, prec=0.9230769230769231, rec=0.8275862068965517, fscore=0.8727272727272727)
# ######### Instance 21 ##############
# uncover ”(Bagi
# uncover )
# uncover )
# Label Tokens:
#  [('”', 'O'), ('(', 'O'), ('Bagi', 'O'), ('mereka', 'O'), (')', 'O'), ('kesenangan', 'O'), ('(', 'O'), ('sesaat', 'O'), (')', 'O'), ('ketika', 'O'), ('di', 'O'), ('dunia', 'O'), (',', 'O'), ('selanjutnya', 'O'), ('kepada', 'O'), ('Kamilah', 'O'), ('tempat', 'O'), ('mereka', 'O'), ('kembali', 'O'), (',', 'O'), ('kemudian', 'O'), ('Kami', 'O'), ('jadikan', 'O'), ('mereka', 'O'), ('merasakan', 'O'), ('azab', 'O'), ('yang', 'O'), ('keras', 'O'), ('karena', 'O'), ('mereka', 'O'), ('selalu', 'O'), ('kufur', 'O'), ('.', 'O')]
# prediction ”(Bagi mereka/O ) kesenangan/O (sesaat/O ) ketika/O di/O dunia/AfterlifeLocation, selanjutnya/O kepada/O Kamilah/Allah tempat/O mereka/O kembali/O, kemudian/O Kami/O jadikan/O mereka/O merasakan/O azab/O yang/O keras/O karena/O mereka/O selalu/O kufur/O.
# Prediction Tokens:
#  [('mereka', 'O'), ('kesenangan', 'O'), ('(sesaat', 'O'), ('ketika', 'O'), ('di', 'O'), ('dunia', 'AfterlifeLocation,'), ('selanjutnya', 'O'), ('kepada', 'O'), ('Kamilah', 'Allah'), ('tempat', 'O'), ('mereka', 'O'), ('kembali', 'O,'), ('kemudian', 'O'), ('Kami', 'O'), ('jadikan', 'O'), ('mereka', 'O'), ('merasakan', 'O'), ('azab', 'O'), ('yang', 'O'), ('keras', 'O'), ('karena', 'O'), ('mereka', 'O'), ('selalu', 'O'), ('kufur', 'O.')]
# correct:
#  [('mereka', 'O'), ('kesenangan', 'O'), ('ketika', 'O'), ('di', 'O'), ('selanjutnya', 'O'), ('kepada', 'O'), ('tempat', 'O'), ('mereka', 'O'), ('kemudian', 'O'), ('Kami', 'O'), ('jadikan', 'O'), ('mereka', 'O'), ('merasakan', 'O'), ('azab', 'O'), ('yang', 'O'), ('keras', 'O'), ('karena', 'O'), ('mereka', 'O'), ('selalu', 'O')]
# Correct: 19, Guessed: 24, Total: 33
# Metrics(tp=19, fp=5, fn=14, prec=0.7916666666666666, rec=0.5757575757575758, fscore=0.6666666666666667)
# ######### Instance 22 ##############
# Label Tokens:
#  [('Bacakanlah', 'O'), ('(', 'O'), ('sampaikanlah', 'O'), ('wahai', 'O'), ('Nabi', 'O'), ('Muhammad', 'Messenger'), (')', 'O'), ('kepada', 'O'), ('mereka', 'O'), ('berita', 'O'), ('penting', 'O'), ('(', 'O'), ('tentang', 'O'), (')', 'O'), ('Nuh', 'Messenger'), ('ketika', 'O'), ('dia', 'O'), ('berkata', 'O'), ('kepada', 'O'), ('kaumnya', 'O'), (',', 'O'), ('“', 'O'), ('Wahai', 'O'), ('kaumku', 'O'), (',', 'O'), ('jika', 'O'), ('terasa', 'O'), ('berat', 'O'), ('bagi', 'O'), ('kamu', 'O'), ('keberadaanku', 'O'), ('tinggal', 'O'), ('(', 'O'), ('bersamamu', 'O'), (')', 'O'), ('dan', 'O'), ('peringatanku', 'O'), ('dengan', 'O'), ('ayat-ayat', 'O'), ('Allah', 'Allah'), (',', 'O'), ('kepada', 'O'), ('Allahlah', 'O'), ('aku', 'O'), ('bertawakal', 'O'), ('.', 'O')]
# prediction Bacakanlah/O (sampaikanlah/O wahai/O (/O Nabi/O Muhammad/Messenger )/O kepada/O mereka/O berita/O penting/O (tentang/O )/O Nuh/Prophet ketika/O dia/O berkata/O kepada/O kaumnya/O,“/O Wahai/O kaumku/O,/O jika/O terasa/O berat/O bagi/O kamu/O keberadaanku/O tinggal/O (bersamamu/O )/O dan/O peringatanku/O dengan/O ayat-ayat/O (/O Allah/Allah )/O,/O kepada/O Allah/O lah/O aku/O bertawakal/O./O
# Prediction Tokens:
#  [('Bacakanlah', 'O'), ('(sampaikanlah', 'O'), ('wahai', 'O'), ('(', 'O'), ('Nabi', 'O'), ('Muhammad', 'Messenger'), (')', 'O'), ('kepada', 'O'), ('mereka', 'O'), ('berita', 'O'), ('penting', 'O'), ('(tentang', 'O'), (')', 'O'), ('Nuh', 'Prophet'), ('ketika', 'O'), ('dia', 'O'), ('berkata', 'O'), ('kepada', 'O'), ('kaumnya', 'O'), (',“', 'O'), ('Wahai', 'O'), ('kaumku', 'O'), (',', 'O'), ('jika', 'O'), ('terasa', 'O'), ('berat', 'O'), ('bagi', 'O'), ('kamu', 'O'), ('keberadaanku', 'O'), ('tinggal', 'O'), ('(bersamamu', 'O'), (')', 'O'), ('dan', 'O'), ('peringatanku', 'O'), ('dengan', 'O'), ('ayat-ayat', 'O'), ('(', 'O'), ('Allah', 'Allah'), (')', 'O'), (',', 'O'), ('kepada', 'O'), ('Allah', 'O'), ('lah', 'O'), ('aku', 'O'), ('bertawakal', 'O'), ('.', 'O')]
# correct:
#  [('Bacakanlah', 'O'), ('wahai', 'O'), ('(', 'O'), ('Nabi', 'O'), ('Muhammad', 'Messenger'), ('kepada', 'O'), ('mereka', 'O'), ('berita', 'O'), ('penting', 'O'), ('ketika', 'O'), ('dia', 'O'), ('berkata', 'O'), ('kepada', 'O'), ('kaumnya', 'O'), ('Wahai', 'O'), ('kaumku', 'O'), (',', 'O'), ('jika', 'O'), ('terasa', 'O'), ('berat', 'O'), ('bagi', 'O'), ('kamu', 'O'), ('keberadaanku', 'O'), ('tinggal', 'O'), ('dan', 'O'), ('peringatanku', 'O'), ('dengan', 'O'), ('ayat-ayat', 'O'), ('(', 'O'), ('Allah', 'Allah'), (',', 'O'), ('kepada', 'O'), ('aku', 'O'), ('bertawakal', 'O'), ('.', 'O')]
# Correct: 35, Guessed: 46, Total: 46
# Metrics(tp=35, fp=11, fn=11, prec=0.7608695652173914, rec=0.7608695652173914, fscore=0.7608695652173914)
# ######### Instance 23 ##############
# Label Tokens:
#  [('Oleh', 'O'), ('karena', 'O'), ('itu', 'O'), (',', 'O'), ('bulatkanlah', 'O'), ('keputusanmu', 'O'), ('dan', 'O'), ('kumpulkanlah', 'O'), ('sekutu-sekutumu', 'O'), ('(', 'O'), ('untuk', 'O'), ('membinasakanku', 'O'), (')', 'O'), (',', 'O'), ('selanjutnya', 'O'), ('janganlah', 'O'), ('keputusanmu', 'O'), ('itu', 'O'), ('dirahasiakan', 'O'), ('.', 'O')]
# prediction Oleh/O karena/O itu/O,/O bulatkanlah/O keputusanmu/O dan/O kumpulkanlah/O sekutu-sekutumu/O (/O untuk/O membinasakanku/O )/O,/O selanjutnya/O janganlah/O keputusanmu/O itu/O dirahasiakan/O./O
# Prediction Tokens:
#  [('Oleh', 'O'), ('karena', 'O'), ('itu', 'O'), (',', 'O'), ('bulatkanlah', 'O'), ('keputusanmu', 'O'), ('dan', 'O'), ('kumpulkanlah', 'O'), ('sekutu-sekutumu', 'O'), ('(', 'O'), ('untuk', 'O'), ('membinasakanku', 'O'), (')', 'O'), (',', 'O'), ('selanjutnya', 'O'), ('janganlah', 'O'), ('keputusanmu', 'O'), ('itu', 'O'), ('dirahasiakan', 'O'), ('.', 'O')]
# correct:
#  [('Oleh', 'O'), ('karena', 'O'), ('itu', 'O'), (',', 'O'), ('bulatkanlah', 'O'), ('keputusanmu', 'O'), ('dan', 'O'), ('kumpulkanlah', 'O'), ('sekutu-sekutumu', 'O'), ('(', 'O'), ('untuk', 'O'), ('membinasakanku', 'O'), (')', 'O'), (',', 'O'), ('selanjutnya', 'O'), ('janganlah', 'O'), ('keputusanmu', 'O'), ('itu', 'O'), ('dirahasiakan', 'O'), ('.', 'O')]
# Correct: 20, Guessed: 20, Total: 20
# Metrics(tp=20, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 24 ##############
# Label Tokens:
#  [('Kemudian', 'O'), (',', 'O'), ('bertindaklah', 'O'), ('terhadap', 'O'), ('diriku', 'O'), ('dan', 'O'), ('janganlah', 'O'), ('kamu', 'O'), ('tunda-tunda', 'O'), ('(', 'O'), ('tindakan', 'O'), ('itu', 'O'), (')', 'O'), ('kepadaku', 'O'), ('.', 'O')]
# prediction Kemudian/O,/O bertindaklah/O terhadap/O diriku/O (/O kamu/O )/O dan/O janganlah/O kamu/O tunda-tunda/O (/O tindakan/O itu/Event )/O kepadaku/O./O
# Prediction Tokens:
#  [('Kemudian', 'O'), (',', 'O'), ('bertindaklah', 'O'), ('terhadap', 'O'), ('diriku', 'O'), ('(', 'O'), ('kamu', 'O'), (')', 'O'), ('dan', 'O'), ('janganlah', 'O'), ('kamu', 'O'), ('tunda-tunda', 'O'), ('(', 'O'), ('tindakan', 'O'), ('itu', 'Event'), (')', 'O'), ('kepadaku', 'O'), ('.', 'O')]
# correct:
#  [('Kemudian', 'O'), (',', 'O'), ('bertindaklah', 'O'), ('terhadap', 'O'), ('diriku', 'O'), ('dan', 'O'), ('janganlah', 'O'), ('tunda-tunda', 'O'), ('tindakan', 'O'), ('kepadaku', 'O'), ('.', 'O')]
# Correct: 11, Guessed: 18, Total: 15
# Metrics(tp=11, fp=7, fn=4, prec=0.6111111111111112, rec=0.7333333333333333, fscore=0.6666666666666666)
# ######### Instance 25 ##############
# Label Tokens:
#  [('Jika', 'O'), ('kamu', 'O'), ('berpaling', 'O'), ('(', 'O'), ('dari', 'O'), ('peringatanku', 'O'), (')', 'O'), (',', 'O'), ('aku', 'O'), ('tidak', 'O'), ('meminta', 'O'), ('imbalan', 'O'), ('sedikit', 'O'), ('pun', 'O'), ('darimu', 'O'), ('.', 'O')]
# prediction Jika/O kamu/O berpaling/O (dari/O peringatanku/O ),/O aku/O tidak/O meminta/O imbalan/O sedikit/O pun/O darimu/O./O
# Prediction Tokens:
#  [('Jika', 'O'), ('kamu', 'O'), ('berpaling', 'O'), ('(dari', 'O'), ('peringatanku', 'O'), ('),', 'O'), ('aku', 'O'), ('tidak', 'O'), ('meminta', 'O'), ('imbalan', 'O'), ('sedikit', 'O'), ('pun', 'O'), ('darimu', 'O'), ('.', 'O')]
# correct:
#  [('Jika', 'O'), ('kamu', 'O'), ('berpaling', 'O'), ('peringatanku', 'O'), ('aku', 'O'), ('tidak', 'O'), ('meminta', 'O'), ('imbalan', 'O'), ('sedikit', 'O'), ('pun', 'O'), ('darimu', 'O'), ('.', 'O')]
# Correct: 12, Guessed: 14, Total: 16
# Metrics(tp=12, fp=2, fn=4, prec=0.8571428571428571, rec=0.75, fscore=0.7999999999999999)
# ######### Instance 26 ##############
# Label Tokens:
#  [('Imbalanku', 'O'), ('tidak', 'O'), ('lain', 'O'), ('hanyalah', 'O'), ('dari', 'O'), ('Allah', 'Allah'), ('dan', 'O'), ('aku', 'O'), ('diperintah', 'O'), ('agar', 'O'), ('aku', 'O'), ('masuk', 'O'), ('ke', 'O'), ('dalam', 'O'), ('golongan', 'O'), ('orang-orang', 'O'), ('muslim', 'O'), ('.', 'O')]
# prediction Imbalanku/O tidak/O lain/O hanyalah/O dari/O Allah/Allah /O dan/O aku/O diperintah/O agar/O aku/O masuk/O ke/O dalam/O golongan/O orang-orang/O muslim/O./O
# Prediction Tokens:
#  [('Imbalanku', 'O'), ('tidak', 'O'), ('lain', 'O'), ('hanyalah', 'O'), ('dari', 'O'), ('Allah', 'Allah'), ('', 'O'), ('dan', 'O'), ('aku', 'O'), ('diperintah', 'O'), ('agar', 'O'), ('aku', 'O'), ('masuk', 'O'), ('ke', 'O'), ('dalam', 'O'), ('golongan', 'O'), ('orang-orang', 'O'), ('muslim', 'O'), ('.', 'O')]
# correct:
#  [('Imbalanku', 'O'), ('tidak', 'O'), ('lain', 'O'), ('hanyalah', 'O'), ('dari', 'O'), ('Allah', 'Allah'), ('dan', 'O'), ('aku', 'O'), ('diperintah', 'O'), ('agar', 'O'), ('aku', 'O'), ('masuk', 'O'), ('ke', 'O'), ('dalam', 'O'), ('golongan', 'O'), ('orang-orang', 'O'), ('muslim', 'O'), ('.', 'O')]
# Correct: 18, Guessed: 19, Total: 18
# Metrics(tp=18, fp=1, fn=0, prec=0.9473684210526315, rec=1.0, fscore=0.972972972972973)
# ######### Instance 27 ##############
# Label Tokens:
#  [('”', 'O'), ('Mereka', 'O'), ('mendustakannya', 'O'), ('(', 'O'), ('Nuh', 'Messenger'), (')', 'O'), ('.', 'O')]
# prediction Mereka/O mendustakannya/O (Nuh/Prophet).
# Prediction Tokens:
#  [('Mereka', 'O'), ('mendustakannya', 'O'), ('(Nuh', 'Prophet).')]
# correct:
#  [('Mereka', 'O'), ('mendustakannya', 'O')]
# Correct: 2, Guessed: 3, Total: 7
# Metrics(tp=2, fp=1, fn=5, prec=0.6666666666666666, rec=0.2857142857142857, fscore=0.4)
# ######### Instance 28 ##############
# Label Tokens:
#  [('Lalu', 'O'), (',', 'O'), ('Kami', 'O'), ('selamatkan', 'O'), ('dia', 'O'), ('dan', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('bersamanya', 'O'), ('di', 'O'), ('dalam', 'O'), ('bahtera', 'O'), ('serta', 'O'), ('Kami', 'O'), ('jadikan', 'O'), ('mereka', 'O'), ('sebagai', 'O'), ('generasi', 'O'), ('penerus', 'O'), ('dan', 'O'), ('Kami', 'O'), ('tenggelamkan', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('mendustakan', 'O'), ('ayat-ayat', 'O'), ('Kami', 'O'), ('.', 'O')]
# prediction Lalu/O,/O Kami/O selamatkan/O dia/O dan/O orang-orang/O yang/O bersamanya/O di/O dalam/O (/O bahtera/Artifact )/O serta/O Kami/O jadikan/O mereka/O sebagai/O generasi/O penerus/O dan/O Kami/O tenggelamkan/O orang-orang/O yang/O mendustakan/O ayat-ayat/O Kami/O./O
# Prediction Tokens:
#  [('Lalu', 'O'), (',', 'O'), ('Kami', 'O'), ('selamatkan', 'O'), ('dia', 'O'), ('dan', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('bersamanya', 'O'), ('di', 'O'), ('dalam', 'O'), ('(', 'O'), ('bahtera', 'Artifact'), (')', 'O'), ('serta', 'O'), ('Kami', 'O'), ('jadikan', 'O'), ('mereka', 'O'), ('sebagai', 'O'), ('generasi', 'O'), ('penerus', 'O'), ('dan', 'O'), ('Kami', 'O'), ('tenggelamkan', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('mendustakan', 'O'), ('ayat-ayat', 'O'), ('Kami', 'O'), ('.', 'O')]
# correct:
#  [('Lalu', 'O'), (',', 'O'), ('Kami', 'O'), ('selamatkan', 'O'), ('dia', 'O'), ('dan', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('bersamanya', 'O'), ('di', 'O'), ('dalam', 'O'), ('serta', 'O'), ('Kami', 'O'), ('jadikan', 'O'), ('mereka', 'O'), ('sebagai', 'O'), ('generasi', 'O'), ('penerus', 'O'), ('dan', 'O'), ('Kami', 'O'), ('tenggelamkan', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('mendustakan', 'O'), ('ayat-ayat', 'O'), ('Kami', 'O'), ('.', 'O')]
# Correct: 27, Guessed: 30, Total: 28
# Metrics(tp=27, fp=3, fn=1, prec=0.9, rec=0.9642857142857143, fscore=0.9310344827586207)
# ######### Instance 29 ##############
# Label Tokens:
#  [('Perhatikanlah', 'O'), ('bagaimana', 'O'), ('kesudahan', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('diberi', 'O'), ('peringatan', 'O'), ('itu', 'O'), ('.', 'O')]
# prediction Perhatikanlah/O bagaimana/O kesudahan/O orang-orang/O yang/O diberi/O peringatan/O itu/O./O
# Prediction Tokens:
#  [('Perhatikanlah', 'O'), ('bagaimana', 'O'), ('kesudahan', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('diberi', 'O'), ('peringatan', 'O'), ('itu', 'O'), ('.', 'O')]
# correct:
#  [('Perhatikanlah', 'O'), ('bagaimana', 'O'), ('kesudahan', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('diberi', 'O'), ('peringatan', 'O'), ('itu', 'O'), ('.', 'O')]
# Correct: 9, Guessed: 9, Total: 9
# Metrics(tp=9, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 30 ##############
# Label Tokens:
#  [('Kemudian', 'O'), (',', 'O'), ('Kami', 'O'), ('mengutus', 'O'), ('setelahnya', 'O'), ('(', 'O'), ('Nuh', 'Messenger'), (')', 'O'), ('beberapa', 'O'), ('rasul', 'O'), ('kepada', 'O'), ('kaum', 'O'), ('mereka', 'O'), ('(', 'O'), ('umat', 'O'), ('masing-masing', 'O'), (')', 'O'), (',', 'O'), ('maka', 'O'), ('rasul-rasul', 'O'), ('itu', 'O'), ('datang', 'O'), ('kepada', 'O'), ('mereka', 'O'), ('dengan', 'O'), ('membawa', 'O'), ('bukti-bukti', 'O'), ('yang', 'O'), ('nyata', 'O'), (',', 'O'), ('tetapi', 'O'), ('mereka', 'O'), ('tidak', 'O'), ('mau', 'O'), ('beriman', 'O'), ('karena', 'O'), ('mereka', 'O'), ('dahulu', 'O'), ('telah', 'O'), ('(', 'O'), ('biasa', 'O'), (')', 'O'), ('mendustakannya', 'O'), ('.', 'O')]
# prediction Kemudian/O,/O Kami/O mengutus/O setelahnya/O (/O Nuh/Prophet )/O beberapa/O rasul/O kepada/O kaum/O mereka/O (/O umat/O masing-masing/GeographicalLocation )/O,/O maka/O rasul-rasul/O itu/O datang/O kepada/O mereka/O dengan/O membawa/O bukti-bukti/O yang/O nyata/O,/O tetapi/O mereka/O tidak/O mau/O beriman/O karena/O mereka/O dahulu/O telah/O (/O biasa/O )/O mendustakannya/O./O
# Prediction Tokens:
#  [('Kemudian', 'O'), (',', 'O'), ('Kami', 'O'), ('mengutus', 'O'), ('setelahnya', 'O'), ('(', 'O'), ('Nuh', 'Prophet'), (')', 'O'), ('beberapa', 'O'), ('rasul', 'O'), ('kepada', 'O'), ('kaum', 'O'), ('mereka', 'O'), ('(', 'O'), ('umat', 'O'), ('masing-masing', 'GeographicalLocation'), (')', 'O'), (',', 'O'), ('maka', 'O'), ('rasul-rasul', 'O'), ('itu', 'O'), ('datang', 'O'), ('kepada', 'O'), ('mereka', 'O'), ('dengan', 'O'), ('membawa', 'O'), ('bukti-bukti', 'O'), ('yang', 'O'), ('nyata', 'O'), (',', 'O'), ('tetapi', 'O'), ('mereka', 'O'), ('tidak', 'O'), ('mau', 'O'), ('beriman', 'O'), ('karena', 'O'), ('mereka', 'O'), ('dahulu', 'O'), ('telah', 'O'), ('(', 'O'), ('biasa', 'O'), (')', 'O'), ('mendustakannya', 'O'), ('.', 'O')]
# correct:
#  [('Kemudian', 'O'), (',', 'O'), ('Kami', 'O'), ('mengutus', 'O'), ('setelahnya', 'O'), ('(', 'O'), (')', 'O'), ('beberapa', 'O'), ('rasul', 'O'), ('kepada', 'O'), ('kaum', 'O'), ('mereka', 'O'), ('(', 'O'), ('umat', 'O'), (')', 'O'), (',', 'O'), ('maka', 'O'), ('rasul-rasul', 'O'), ('itu', 'O'), ('datang', 'O'), ('kepada', 'O'), ('mereka', 'O'), ('dengan', 'O'), ('membawa', 'O'), ('bukti-bukti', 'O'), ('yang', 'O'), ('nyata', 'O'), (',', 'O'), ('tetapi', 'O'), ('mereka', 'O'), ('tidak', 'O'), ('mau', 'O'), ('beriman', 'O'), ('karena', 'O'), ('mereka', 'O'), ('dahulu', 'O'), ('telah', 'O'), ('(', 'O'), ('biasa', 'O'), (')', 'O'), ('mendustakannya', 'O'), ('.', 'O')]
# Correct: 42, Guessed: 44, Total: 44
# Metrics(tp=42, fp=2, fn=2, prec=0.9545454545454546, rec=0.9545454545454546, fscore=0.9545454545454546)
# ######### Instance 31 ##############
# Label Tokens:
#  [('Demikianlah', 'O'), ('Kami', 'O'), ('mengunci', 'O'), ('hati', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('melampaui', 'O'), ('batas', 'O'), ('.', 'O')]
# prediction Demikianlah/O Kami/O mengunci/O hati/O orang-orang/O yang/O melampaui/O batas/O./O
# Prediction Tokens:
#  [('Demikianlah', 'O'), ('Kami', 'O'), ('mengunci', 'O'), ('hati', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('melampaui', 'O'), ('batas', 'O'), ('.', 'O')]
# correct:
#  [('Demikianlah', 'O'), ('Kami', 'O'), ('mengunci', 'O'), ('hati', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('melampaui', 'O'), ('batas', 'O'), ('.', 'O')]
# Correct: 9, Guessed: 9, Total: 9
# Metrics(tp=9, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 32 ##############
# Label Tokens:
#  [('Kemudian', 'O'), (',', 'O'), ('setelah', 'O'), ('mereka', 'O'), ('Kami', 'O'), ('mengutus', 'O'), ('Musa', 'Messenger'), ('dan', 'O'), ('Harun', 'Prophet'), ('kepada', 'O'), ('Fir‘aun', 'Person'), ('dan', 'O'), ('para', 'O'), ('pemuka', 'O'), ('kaumnya', 'O'), (',', 'O'), ('dengan', 'O'), ('membawa', 'O'), ('tanda-tanda', 'O'), ('(', 'O'), ('kekuasaan', 'O'), (')', 'O'), ('Kami', 'O'), ('.', 'O')]
# prediction Kemudian/O,/O setelah/O mereka/O Kami/O mengutus/O (/O Musa/Prophet )/O dan/O (/O Harun/Prophet )/O kepada/O (/O Fir‘aun/Person )/O dan/O para/O pemuka/O kaumnya/O,/O dengan/O membawa/O tanda-tanda/O (/O kekuasaan/O )/O Kami/O./O
# Prediction Tokens:
#  [('Kemudian', 'O'), (',', 'O'), ('setelah', 'O'), ('mereka', 'O'), ('Kami', 'O'), ('mengutus', 'O'), ('(', 'O'), ('Musa', 'Prophet'), (')', 'O'), ('dan', 'O'), ('(', 'O'), ('Harun', 'Prophet'), (')', 'O'), ('kepada', 'O'), ('(', 'O'), ('Fir‘aun', 'Person'), (')', 'O'), ('dan', 'O'), ('para', 'O'), ('pemuka', 'O'), ('kaumnya', 'O'), (',', 'O'), ('dengan', 'O'), ('membawa', 'O'), ('tanda-tanda', 'O'), ('(', 'O'), ('kekuasaan', 'O'), (')', 'O'), ('Kami', 'O'), ('.', 'O')]
# correct:
#  [('Kemudian', 'O'), (',', 'O'), ('setelah', 'O'), ('mereka', 'O'), ('Kami', 'O'), ('mengutus', 'O'), ('dan', 'O'), ('Harun', 'Prophet'), ('kepada', 'O'), ('Fir‘aun', 'Person'), ('dan', 'O'), ('para', 'O'), ('pemuka', 'O'), ('kaumnya', 'O'), (',', 'O'), ('dengan', 'O'), ('membawa', 'O'), ('tanda-tanda', 'O'), ('kekuasaan', 'O'), ('Kami', 'O'), ('.', 'O')]
# Correct: 21, Guessed: 30, Total: 24
# Metrics(tp=21, fp=9, fn=3, prec=0.7, rec=0.875, fscore=0.7777777777777777)
# ######### Instance 33 ##############
# Label Tokens:
#  [('Lalu', 'O'), (',', 'O'), ('mereka', 'O'), ('menyombongkan', 'O'), ('diri', 'O'), ('dan', 'O'), ('mereka', 'O'), ('adalah', 'O'), ('kaum', 'O'), ('pendurhaka', 'O'), ('.', 'O')]
# prediction Lalu/O, mereka/O menyombongkan/O diri/O dan/O mereka/O adalah/O kaum/O pendurhaka/O./O
# Prediction Tokens:
#  [('Lalu', 'O,'), ('mereka', 'O'), ('menyombongkan', 'O'), ('diri', 'O'), ('dan', 'O'), ('mereka', 'O'), ('adalah', 'O'), ('kaum', 'O'), ('pendurhaka', 'O'), ('.', 'O')]
# correct:
#  [('mereka', 'O'), ('menyombongkan', 'O'), ('diri', 'O'), ('dan', 'O'), ('mereka', 'O'), ('adalah', 'O'), ('kaum', 'O'), ('pendurhaka', 'O'), ('.', 'O')]
# Correct: 9, Guessed: 10, Total: 11
# Metrics(tp=9, fp=1, fn=2, prec=0.9, rec=0.8181818181818182, fscore=0.8571428571428572)
# ######### Instance 34 ##############
# Label Tokens:
#  [('Ketika', 'O'), ('telah', 'O'), ('datang', 'O'), ('kepada', 'O'), ('mereka', 'O'), ('kebenaran', 'O'), ('(', 'O'), ('mukjizat', 'O'), (')', 'O'), ('dari', 'O'), ('sisi', 'O'), ('Kami', 'O'), (',', 'O'), ('mereka', 'O'), ('berkata', 'O'), (',', 'O'), ('“', 'O'), ('Sesungguhnya', 'O'), ('ini', 'O'), ('benar-benar', 'O'), ('sihir', 'O'), ('yang', 'O'), ('nyata', 'O'), ('.', 'O')]
# prediction Ketika/O telah/O datang/O kepada/O mereka/O kebenaran/O (mukjizat/Messenger) dari/O sisi/O Kami/O,/O mereka/O berkata,“/O Sesungguhnya/O ini/O benar-benar/O sihir/O yang/O nyata/O.
# Prediction Tokens:
#  [('Ketika', 'O'), ('telah', 'O'), ('datang', 'O'), ('kepada', 'O'), ('mereka', 'O'), ('kebenaran', 'O'), ('(mukjizat', 'Messenger)'), ('dari', 'O'), ('sisi', 'O'), ('Kami', 'O'), (',', 'O'), ('mereka', 'O'), ('berkata,“', 'O'), ('Sesungguhnya', 'O'), ('ini', 'O'), ('benar-benar', 'O'), ('sihir', 'O'), ('yang', 'O'), ('nyata', 'O.')]
# correct:
#  [('Ketika', 'O'), ('telah', 'O'), ('datang', 'O'), ('kepada', 'O'), ('mereka', 'O'), ('kebenaran', 'O'), ('dari', 'O'), ('sisi', 'O'), ('Kami', 'O'), (',', 'O'), ('mereka', 'O'), ('Sesungguhnya', 'O'), ('ini', 'O'), ('benar-benar', 'O'), ('sihir', 'O'), ('yang', 'O')]
# Correct: 16, Guessed: 19, Total: 24
# Metrics(tp=16, fp=3, fn=8, prec=0.8421052631578947, rec=0.6666666666666666, fscore=0.744186046511628)
# ######### Instance 35 ##############
# uncover berkata,“
# Label Tokens:
#  [('”', 'O'), ('Musa', 'Messenger'), ('berkata', 'O'), (',', 'O'), ('“', 'O'), ('Apakah', 'O'), ('(', 'O'), ('pantas', 'O'), (')', 'O'), ('kamu', 'O'), ('mengatakan', 'O'), ('terhadap', 'O'), ('kebenaran', 'O'), ('(', 'O'), ('mukjizat', 'O'), (')', 'O'), ('ketika', 'O'), ('ia', 'O'), ('datang', 'O'), ('kepadamu', 'O'), (',', 'O'), ('‘sihirkah', 'O'), ('ini', 'O'), ('?', 'O'), ('’', 'O'), ('Padahal', 'O'), (',', 'O'), ('para', 'O'), ('penyihir', 'O'), ('itu', 'O'), ('tidaklah', 'O'), ('mendapat', 'O'), ('kemenangan', 'O'), ('.', 'O')]
# prediction ”Musa/Prophet berkata,“ Apakah/O kamu/O mengatakan/O terhadap/O kebenaran/O (mukjizat/Messenger )/O ketika/O ia/O datang/O kepadamu/O, ‘sihirkah/O ini/O? ’/O Padahal/O, para/O penyihir/O itu/O tidaklah/O mendapat/O kemenangan/O./O
# Prediction Tokens:
#  [('”Musa', 'Prophet'), ('Apakah', 'O'), ('kamu', 'O'), ('mengatakan', 'O'), ('terhadap', 'O'), ('kebenaran', 'O'), ('(mukjizat', 'Messenger'), (')', 'O'), ('ketika', 'O'), ('ia', 'O'), ('datang', 'O'), ('kepadamu', 'O,'), ('‘sihirkah', 'O'), ('ini', 'O?'), ('’', 'O'), ('Padahal', 'O,'), ('para', 'O'), ('penyihir', 'O'), ('itu', 'O'), ('tidaklah', 'O'), ('mendapat', 'O'), ('kemenangan', 'O'), ('.', 'O')]
# correct:
#  [('Apakah', 'O'), ('kamu', 'O'), ('mengatakan', 'O'), ('terhadap', 'O'), ('kebenaran', 'O'), (')', 'O'), ('ketika', 'O'), ('ia', 'O'), ('datang', 'O'), ('‘sihirkah', 'O'), ('’', 'O'), ('para', 'O'), ('penyihir', 'O'), ('itu', 'O'), ('tidaklah', 'O'), ('mendapat', 'O'), ('kemenangan', 'O'), ('.', 'O')]
# Correct: 18, Guessed: 23, Total: 34
# Metrics(tp=18, fp=5, fn=16, prec=0.782608695652174, rec=0.5294117647058824, fscore=0.631578947368421)
# ######### Instance 36 ##############
# Label Tokens:
#  [('”', 'O'), ('Mereka', 'O'), ('berkata', 'O'), (',', 'O'), ('“', 'O'), ('Apakah', 'O'), ('engkau', 'O'), ('(', 'O'), ('Musa', 'Messenger'), (')', 'O'), ('datang', 'O'), ('kepada', 'O'), ('kami', 'O'), ('untuk', 'O'), ('memalingkan', 'O'), ('kami', 'O'), ('dari', 'O'), ('apa', 'O'), ('yang', 'O'), ('kami', 'O'), ('dapati', 'O'), ('pada', 'O'), ('nenek', 'O'), ('moyang', 'O'), ('kami', 'O'), ('(', 'O'), ('menyembah', 'O'), ('berhala', 'O'), (')', 'O'), (',', 'O'), ('dan', 'O'), ('agar', 'O'), ('kamu', 'O'), ('berdua', 'O'), ('(', 'O'), ('Musa', 'Messenger'), ('dan', 'O'), ('Harun', 'Prophet'), (')', 'O'), ('mempunyai', 'O'), ('kekuasaan', 'O'), ('di', 'O'), ('bumi', 'AstronomicalBody'), ('(', 'O'), ('negeri', 'O'), ('Mesir', 'GeographicalLocation'), (')', 'O'), ('?', 'O'), ('Kami', 'O'), ('tidak', 'O'), ('akan', 'O'), ('beriman', 'O'), ('kepada', 'O'), ('kamu', 'O'), ('berdua', 'O'), ('.', 'O')]
# prediction ”Mereka/O berkata/O,“/O Apakah/O engkau/O (/O Musa/Prophet )/O datang/O kepada/O kami/O untuk/O memalingkan/O kami/O dari/O apa/O yang/O kami/O dapati/O pada/O nenek/O moyang/O kami/O (menyembah/O berhala/O )/O,/O dan/O agar/O kamu/O berdua/O (/O Musa/Prophet dan/O Harun/Prophet )/O mempunyai/O kekuasaan/O di/O bumi/O (/O negeri/O Mesir/GeographicalLocation )/O?/O Kami/O tidak/O akan/O beriman/O kepada/O kamu/O berdua/O./O
# Prediction Tokens:
#  [('”Mereka', 'O'), ('berkata', 'O'), (',“', 'O'), ('Apakah', 'O'), ('engkau', 'O'), ('(', 'O'), ('Musa', 'Prophet'), (')', 'O'), ('datang', 'O'), ('kepada', 'O'), ('kami', 'O'), ('untuk', 'O'), ('memalingkan', 'O'), ('kami', 'O'), ('dari', 'O'), ('apa', 'O'), ('yang', 'O'), ('kami', 'O'), ('dapati', 'O'), ('pada', 'O'), ('nenek', 'O'), ('moyang', 'O'), ('kami', 'O'), ('(menyembah', 'O'), ('berhala', 'O'), (')', 'O'), (',', 'O'), ('dan', 'O'), ('agar', 'O'), ('kamu', 'O'), ('berdua', 'O'), ('(', 'O'), ('Musa', 'Prophet'), ('dan', 'O'), ('Harun', 'Prophet'), (')', 'O'), ('mempunyai', 'O'), ('kekuasaan', 'O'), ('di', 'O'), ('bumi', 'O'), ('(', 'O'), ('negeri', 'O'), ('Mesir', 'GeographicalLocation'), (')', 'O'), ('?', 'O'), ('Kami', 'O'), ('tidak', 'O'), ('akan', 'O'), ('beriman', 'O'), ('kepada', 'O'), ('kamu', 'O'), ('berdua', 'O'), ('.', 'O')]
# correct:
#  [('berkata', 'O'), ('Apakah', 'O'), ('engkau', 'O'), ('(', 'O'), (')', 'O'), ('datang', 'O'), ('kepada', 'O'), ('kami', 'O'), ('untuk', 'O'), ('memalingkan', 'O'), ('kami', 'O'), ('dari', 'O'), ('apa', 'O'), ('yang', 'O'), ('kami', 'O'), ('dapati', 'O'), ('pada', 'O'), ('nenek', 'O'), ('moyang', 'O'), ('kami', 'O'), ('berhala', 'O'), (')', 'O'), (',', 'O'), ('dan', 'O'), ('agar', 'O'), ('kamu', 'O'), ('berdua', 'O'), ('(', 'O'), ('dan', 'O'), ('Harun', 'Prophet'), (')', 'O'), ('mempunyai', 'O'), ('kekuasaan', 'O'), ('di', 'O'), ('(', 'O'), ('negeri', 'O'), ('Mesir', 'GeographicalLocation'), (')', 'O'), ('?', 'O'), ('Kami', 'O'), ('tidak', 'O'), ('akan', 'O'), ('beriman', 'O'), ('kepada', 'O'), ('kamu', 'O'), ('berdua', 'O'), ('.', 'O')]
# Correct: 47, Guessed: 53, Total: 56
# Metrics(tp=47, fp=6, fn=9, prec=0.8867924528301887, rec=0.8392857142857143, fscore=0.8623853211009174)
# ######### Instance 37 ##############
# uncover )
# uncover berkata
# uncover ),“
# uncover ),
# uncover )
# uncover berkata
# uncover ),“
# uncover ),
# uncover )
# uncover berkata,“
# uncover ).
# Label Tokens:
#  [('”', 'O'), ('Fir‘aun', 'Person'), ('berkata', 'O'), ('(', 'O'), ('kepada', 'O'), ('para', 'O'), ('pemuka', 'O'), ('kaumnya', 'O'), (')', 'O'), (',', 'O'), ('“', 'O'), ('Datangkanlah', 'O'), ('kepadaku', 'O'), ('semua', 'O'), ('penyihir', 'O'), ('yang', 'O'), ('ulung', 'O'), ('!', 'O'), ('”', 'O'), ('Ketika', 'O'), ('para', 'O'), ('penyihir', 'O'), ('itu', 'O'), ('datang', 'O'), (',', 'O'), ('Musa', 'Messenger'), ('berkata', 'O'), ('kepada', 'O'), ('mereka', 'O'), (',', 'O'), ('“', 'O'), ('Lemparkanlah', 'O'), ('apa', 'O'), ('yang', 'O'), ('hendak', 'O'), ('kamu', 'O'), ('lemparkan', 'O'), ('!', 'O'), ('”', 'O'), ('Setelah', 'O'), ('mereka', 'O'), ('melemparkan', 'O'), ('(', 'O'), ('tali-temali', 'O'), (')', 'O'), (',', 'O'), ('Musa', 'Messenger'), ('berkata', 'O'), (',', 'O'), ('“', 'O'), ('Apa', 'O'), ('yang', 'O'), ('kamu', 'O'), ('bawa', 'O'), ('itulah', 'O'), ('sihir', 'O'), ('.', 'O')]
# prediction ”(/O Fir‘aun/Person ) berkata (/O kepada/O para/O pemuka/O kaumnya/O ),“ (/O Datangkanlah/O kepadaku/O semua/O penyihir/O yang/O ulung/O! ”(/O Ketika/O para/O penyihir/O itu/O datang/O ), (/O Musa/Prophet ) berkata (/O kepada/O mereka/O ),“ (/O Lemparkanlah/O apa/O yang/O hendak/O kamu/O lemparkan/O! ”(/O Setelah/O mereka/O melemparkan/O (tali-temali/O ), (/O Musa/Prophet ) berkata,“ (/O Apa/O yang/O kamu/O bawa/O itulah/O sihir/O ).
# Prediction Tokens:
#  [('”(', 'O'), ('Fir‘aun', 'Person'), ('(', 'O'), ('kepada', 'O'), ('para', 'O'), ('pemuka', 'O'), ('kaumnya', 'O'), ('(', 'O'), ('Datangkanlah', 'O'), ('kepadaku', 'O'), ('semua', 'O'), ('penyihir', 'O'), ('yang', 'O'), ('ulung', 'O!'), ('”(', 'O'), ('Ketika', 'O'), ('para', 'O'), ('penyihir', 'O'), ('itu', 'O'), ('datang', 'O'), ('(', 'O'), ('Musa', 'Prophet'), ('(', 'O'), ('kepada', 'O'), ('mereka', 'O'), ('(', 'O'), ('Lemparkanlah', 'O'), ('apa', 'O'), ('yang', 'O'), ('hendak', 'O'), ('kamu', 'O'), ('lemparkan', 'O!'), ('”(', 'O'), ('Setelah', 'O'), ('mereka', 'O'), ('melemparkan', 'O'), ('(tali-temali', 'O'), ('(', 'O'), ('Musa', 'Prophet'), ('(', 'O'), ('Apa', 'O'), ('yang', 'O'), ('kamu', 'O'), ('bawa', 'O'), ('itulah', 'O'), ('sihir', 'O')]
# correct:
#  [('Fir‘aun', 'Person'), ('kepada', 'O'), ('para', 'O'), ('pemuka', 'O'), ('kaumnya', 'O'), ('Datangkanlah', 'O'), ('kepadaku', 'O'), ('semua', 'O'), ('penyihir', 'O'), ('yang', 'O'), ('Ketika', 'O'), ('para', 'O'), ('penyihir', 'O'), ('itu', 'O'), ('datang', 'O'), ('kepada', 'O'), ('mereka', 'O'), ('Lemparkanlah', 'O'), ('apa', 'O'), ('yang', 'O'), ('hendak', 'O'), ('kamu', 'O'), ('Setelah', 'O'), ('mereka', 'O'), ('melemparkan', 'O'), ('Apa', 'O'), ('yang', 'O'), ('kamu', 'O'), ('bawa', 'O'), ('itulah', 'O'), ('sihir', 'O')]
# Correct: 31, Guessed: 46, Total: 57
# Metrics(tp=31, fp=15, fn=26, prec=0.6739130434782609, rec=0.543859649122807, fscore=0.6019417475728156)
# ######### Instance 38 ##############
# Label Tokens:
#  [('Sesungguhnya', 'O'), ('Allah', 'Allah'), ('akan', 'O'), ('membatalkan', 'O'), ('(', 'O'), ('mengalahkan', 'O'), (')', 'O'), ('-nya', 'O'), ('.', 'O')]
# prediction Sesungguhnya/O Allah/Allah akan/O membatalkan/O (mengalahkan/O )-nya/O.
# Prediction Tokens:
#  [('Sesungguhnya', 'O'), ('Allah', 'Allah'), ('akan', 'O'), ('membatalkan', 'O'), ('(mengalahkan', 'O'), (')-nya', 'O.')]
# correct:
#  [('Sesungguhnya', 'O'), ('Allah', 'Allah'), ('akan', 'O'), ('membatalkan', 'O')]
# Correct: 4, Guessed: 6, Total: 9
# Metrics(tp=4, fp=2, fn=5, prec=0.6666666666666666, rec=0.4444444444444444, fscore=0.5333333333333333)
# ######### Instance 39 ##############
# Label Tokens:
#  [('Sesungguhnya', 'O'), ('Allah', 'Allah'), ('tidak', 'O'), ('membiarkan', 'O'), ('perbuatan', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('berbuat', 'O'), ('kerusakan', 'O'), ('.', 'O')]
# prediction Sesungguhnya/O Allah/Allah tidak/O membiarkan/O perbuatan/O orang-orang/O yang/O berbuat/O kerusakan/O./O
# Prediction Tokens:
#  [('Sesungguhnya', 'O'), ('Allah', 'Allah'), ('tidak', 'O'), ('membiarkan', 'O'), ('perbuatan', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('berbuat', 'O'), ('kerusakan', 'O'), ('.', 'O')]
# correct:
# ...
# ######### Instance 300 ##############
# Label Tokens:
#  [('Sesungguhnya', 'O'), ('Tuhanmu', 'O'), ('setelah', 'O'), ('itu', 'O'), ('benar-benar', 'O'), ('Maha', 'O'), ('Pengampun', 'O'), ('lagi', 'O'), ('Maha', 'O'), ('Penyayang', 'O'), ('.', 'O')]
# prediction Sesungguhnya/O Tuhanmu/O Allah/O setelah/O itu/O benar-benar/O Maha/O Pengampun/O lagi/O Maha/O Penyayang/O./O
# Prediction Tokens:
#  [('Sesungguhnya', 'O'), ('Tuhanmu', 'O'), ('Allah', 'O'), ('setelah', 'O'), ('itu', 'O'), ('benar-benar', 'O'), ('Maha', 'O'), ('Pengampun', 'O'), ('lagi', 'O'), ('Maha', 'O'), ('Penyayang', 'O'), ('.', 'O')]
# correct:
#  [('Sesungguhnya', 'O'), ('Tuhanmu', 'O'), ('setelah', 'O'), ('itu', 'O'), ('benar-benar', 'O'), ('Maha', 'O'), ('Pengampun', 'O'), ('lagi', 'O'), ('Maha', 'O'), ('Penyayang', 'O'), ('.', 'O')]
# Correct: 11, Guessed: 12, Total: 11
# Metrics(tp=11, fp=1, fn=0, prec=0.9166666666666666, rec=1.0, fscore=0.9565217391304348)
# ######### Instance 301 ##############
# Label Tokens:
#  [('Sesungguhnya', 'O'), ('Ibrahim', 'Messenger'), ('adalah', 'O'), ('imam', 'O'), ('(', 'O'), ('sosokanutan', 'O'), (')', 'O'), ('yang', 'O'), ('patuh', 'O'), ('kepada', 'O'), ('Allah', 'Allah'), (',', 'O'), ('hanif', 'O'), ('(', 'O'), ('lurus', 'O'), (')', 'O'), (',', 'O'), ('dan', 'O'), ('bukan', 'O'), ('termasuk', 'O'), ('orang-orang', 'O'), ('musyrik', 'O'), ('.', 'O')]
# prediction Sesungguhnya/O Ibrahim/Person adalah/O imam/O (sosokanutan/O )/O yang/O patuh/O kepada/O Allah/Allah,/O hanif/O (lurus/O )/O,/O dan/O bukan/O termasuk/O orang-orang/O musyrik/O./O
# Prediction Tokens:
#  [('Sesungguhnya', 'O'), ('Ibrahim', 'Person'), ('adalah', 'O'), ('imam', 'O'), ('(sosokanutan', 'O'), (')', 'O'), ('yang', 'O'), ('patuh', 'O'), ('kepada', 'O'), ('Allah', 'A'), ('llah,', 'O'), ('hanif', 'O'), ('(lurus', 'O'), (')', 'O'), (',', 'O'), ('dan', 'O'), ('bukan', 'O'), ('termasuk', 'O'), ('orang-orang', 'O'), ('musyrik', 'O'), ('.', 'O')]
# correct:
#  [('Sesungguhnya', 'O'), ('adalah', 'O'), ('imam', 'O'), (')', 'O'), ('yang', 'O'), ('patuh', 'O'), ('kepada', 'O'), ('hanif', 'O'), (')', 'O'), (',', 'O'), ('dan', 'O'), ('bukan', 'O'), ('termasuk', 'O'), ('orang-orang', 'O'), ('musyrik', 'O'), ('.', 'O')]
# Correct: 16, Guessed: 21, Total: 23
# Metrics(tp=16, fp=5, fn=7, prec=0.7619047619047619, rec=0.6956521739130435, fscore=0.7272727272727272)
# ######### Instance 302 ##############
# uncover Test
# uncover output:
# uncover (
# uncover )
# uncover )
# Label Tokens:
#  [('(', 'O'), ('Ibrahim', 'Messenger'), (')', 'O'), ('bersyukur', 'O'), ('atas', 'O'), ('nikmat-nikmat-Nya', 'O'), ('(', 'O'), ('dan', 'O'), ('Allah', 'Allah'), (')', 'O'), ('telah', 'O'), ('memilih', 'O'), ('serta', 'O'), ('menunjukinya', 'O'), ('ke', 'O'), ('jalan', 'O'), ('yang', 'O'), ('lurus', 'O'), ('.', 'O')]
# prediction Test output: ( Ibrahim/Prophet ) bersyukur/O atas/O nikmat-nikmat-Nya/O (dan/O Allah/Allah ) telah/O memilih/O serta/O menunjukinya/O ke/O jalan/O yang/O lurus/O./O
# Prediction Tokens:
#  [('Ibrahim', 'Prophet'), ('bersyukur', 'O'), ('atas', 'O'), ('nikmat-nikmat-Nya', 'O'), ('(dan', 'O'), ('Allah', 'Allah'), ('telah', 'O'), ('memilih', 'O'), ('serta', 'O'), ('menunjukinya', 'O'), ('ke', 'O'), ('jalan', 'O'), ('yang', 'O'), ('lurus', 'O'), ('.', 'O')]
# correct:
#  [('bersyukur', 'O'), ('atas', 'O'), ('nikmat-nikmat-Nya', 'O'), ('Allah', 'Allah'), ('telah', 'O'), ('memilih', 'O'), ('serta', 'O'), ('menunjukinya', 'O'), ('ke', 'O'), ('jalan', 'O'), ('yang', 'O'), ('lurus', 'O'), ('.', 'O')]
# Correct: 13, Guessed: 15, Total: 19
# Metrics(tp=13, fp=2, fn=6, prec=0.8666666666666667, rec=0.6842105263157895, fscore=0.7647058823529413)
# ######### Instance 303 ##############
# Label Tokens:
#  [('Kami', 'O'), ('berikan', 'O'), ('kepadanya', 'O'), ('kebaikan', 'O'), ('di', 'O'), ('dunia', 'O'), ('dan', 'O'), ('sesungguhnya', 'O'), ('di', 'O'), ('akhirat', 'O'), ('dia', 'O'), ('termasuk', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('saleh', 'O'), ('.', 'O')]
# prediction Kami/O berikan/O kepadanya/O kebaikan/O di/O dunia/AfterlifeLocation dan/O sesungguhnya/O di/O akhirat/AfterlifeLocation dia/O termasuk/O orang-orang/O yang/O saleh/O./O
# Prediction Tokens:
#  [('Kami', 'O'), ('berikan', 'O'), ('kepadanya', 'O'), ('kebaikan', 'O'), ('di', 'O'), ('dunia', 'AfterlifeLocation'), ('dan', 'O'), ('sesungguhnya', 'O'), ('di', 'O'), ('akhirat', 'AfterlifeLocation'), ('dia', 'O'), ('termasuk', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('saleh', 'O'), ('.', 'O')]
# correct:
#  [('Kami', 'O'), ('berikan', 'O'), ('kepadanya', 'O'), ('kebaikan', 'O'), ('di', 'O'), ('dan', 'O'), ('sesungguhnya', 'O'), ('di', 'O'), ('dia', 'O'), ('termasuk', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('saleh', 'O'), ('.', 'O')]
# Correct: 14, Guessed: 16, Total: 16
# Metrics(tp=14, fp=2, fn=2, prec=0.875, rec=0.875, fscore=0.875)
# ######### Instance 304 ##############
# uncover agama
# uncover (
# Label Tokens:
#  [('Kemudian', 'O'), (',', 'O'), ('Kami', 'O'), ('wahyukan', 'O'), ('kepadamu', 'O'), ('(', 'O'), ('Nabi', 'O'), ('Muhammad', 'Messenger'), (')', 'O'), (',', 'O'), ('“', 'O'), ('Ikutilah', 'O'), ('Ibrahim', 'Religion'), ('sebagai', 'O'), ('(', 'O'), ('sosok', 'O'), (')', 'O'), ('yang', 'O'), ('hanif', 'O'), ('dan', 'O'), ('tidak', 'O'), ('termasuk', 'O'), ('orang-orang', 'O'), ('musyrik', 'O'), ('.', 'O')]
# prediction Kemudian/O, Kami/O wahyukan/O kepadamu/O (/O Nabi/O Muhammad/Messenger ),“/O Ikutilah/O agama/O (/O Ibrahim/Prophet )/O sebagai/O ( sosok/O )/O yang/O hanif/O dan/O tidak/O termasuk/O orang-orang/O musyrik/O./O
# Prediction Tokens:
#  [('Kemudian', 'O,'), ('Kami', 'O'), ('wahyukan', 'O'), ('kepadamu', 'O'), ('(', 'O'), ('Nabi', 'O'), ('Muhammad', 'Messenger'), ('),“', 'O'), ('Ikutilah', 'O'), ('agama', 'O'), ('(', 'O'), ('Ibrahim', 'Prophet'), (')', 'O'), ('sebagai', 'O'), ('sosok', 'O'), (')', 'O'), ('yang', 'O'), ('hanif', 'O'), ('dan', 'O'), ('tidak', 'O'), ('termasuk', 'O'), ('orang-orang', 'O'), ('musyrik', 'O'), ('.', 'O')]
# correct:
#  [('Kami', 'O'), ('wahyukan', 'O'), ('kepadamu', 'O'), ('(', 'O'), ('Nabi', 'O'), ('Muhammad', 'Messenger'), ('Ikutilah', 'O'), ('(', 'O'), (')', 'O'), ('sebagai', 'O'), ('sosok', 'O'), (')', 'O'), ('yang', 'O'), ('hanif', 'O'), ('dan', 'O'), ('tidak', 'O'), ('termasuk', 'O'), ('orang-orang', 'O'), ('musyrik', 'O'), ('.', 'O')]
# Correct: 20, Guessed: 24, Total: 25
# Metrics(tp=20, fp=4, fn=5, prec=0.8333333333333334, rec=0.8, fscore=0.816326530612245)
# ######### Instance 305 ##############
# uncover hari
# Label Tokens:
#  [('”', 'O'), ('Sesungguhnya', 'O'), ('(', 'O'), ('mengagungkan', 'O'), (')', 'O'), ('Sabtu', 'Event'), ('hanya', 'O'), ('diwajibkan', 'O'), ('bagi', 'O'), ('orang-orang', 'O'), ('(', 'O'), ('Yahudi', 'Person'), (')', 'O'), ('yang', 'O'), ('memperselisihkannya', 'O'), ('.', 'O')]
# prediction ”Sesungguhnya/O mengagungkan/O hari/O Sabtu/O hanya/O diwajibkan/O bagi/O orang-orang/O (/O Yahudi/Person )/O yang/O memperselisihkannya/O./O
# Prediction Tokens:
#  [('”Sesungguhnya', 'O'), ('mengagungkan', 'O'), ('hari', 'O'), ('Sabtu', 'O'), ('hanya', 'O'), ('diwajibkan', 'O'), ('bagi', 'O'), ('orang-orang', 'O'), ('(', 'O'), ('Yahudi', 'Person'), (')', 'O'), ('yang', 'O'), ('memperselisihkannya', 'O'), ('.', 'O')]
# correct:
#  [('mengagungkan', 'O'), ('hanya', 'O'), ('diwajibkan', 'O'), ('bagi', 'O'), ('orang-orang', 'O'), ('(', 'O'), ('Yahudi', 'Person'), (')', 'O'), ('yang', 'O'), ('memperselisihkannya', 'O'), ('.', 'O')]
# Correct: 11, Guessed: 14, Total: 16
# Metrics(tp=11, fp=3, fn=5, prec=0.7857142857142857, rec=0.6875, fscore=0.7333333333333334)
# ######### Instance 306 ##############
# uncover hari
# Label Tokens:
#  [('Sesungguhnya', 'O'), ('Tuhanmu', 'O'), ('benar-benar', 'O'), ('akan', 'O'), ('memberi', 'O'), ('keputusan', 'O'), ('di', 'O'), ('antara', 'O'), ('mereka', 'O'), ('pada', 'O'), ('Kiamat', 'Event'), ('tentang', 'O'), ('apa', 'O'), ('yang', 'O'), ('mereka', 'O'), ('perselisihkan', 'O'), ('.', 'O')]
# prediction Sesungguhnya/O Tuhanmu/Allah benar-benar/O akan/O memberi/O keputusan/O di/O antara/O mereka/O pada/O hari/O (/O Kiamat/AfterlifeLocation )/O tentang/O apa/O yang/O mereka/O perselisihkan/O./O
# Prediction Tokens:
#  [('Sesungguhnya', 'O'), ('Tuhanmu', 'Allah'), ('benar-benar', 'O'), ('akan', 'O'), ('memberi', 'O'), ('keputusan', 'O'), ('di', 'O'), ('antara', 'O'), ('mereka', 'O'), ('pada', 'O'), ('hari', 'O'), ('(', 'O'), ('Kiamat', 'AfterlifeLocation'), (')', 'O'), ('tentang', 'O'), ('apa', 'O'), ('yang', 'O'), ('mereka', 'O'), ('perselisihkan', 'O'), ('.', 'O')]
# correct:
#  [('Sesungguhnya', 'O'), ('benar-benar', 'O'), ('akan', 'O'), ('memberi', 'O'), ('keputusan', 'O'), ('di', 'O'), ('antara', 'O'), ('mereka', 'O'), ('pada', 'O'), ('tentang', 'O'), ('apa', 'O'), ('yang', 'O'), ('mereka', 'O'), ('perselisihkan', 'O'), ('.', 'O')]
# Correct: 15, Guessed: 20, Total: 17
# Metrics(tp=15, fp=5, fn=2, prec=0.75, rec=0.8823529411764706, fscore=0.8108108108108107)
# ######### Instance 307 ##############
# Label Tokens:
#  [('Serulah', 'O'), ('(', 'O'), ('manusia', 'O'), (')', 'O'), ('ke', 'O'), ('jalan', 'O'), ('Tuhanmu', 'O'), ('dengan', 'O'), ('hikmah', 'O'), ('dan', 'O'), ('pengajaran', 'O'), ('yang', 'O'), ('baik', 'O'), ('serta', 'O'), ('debatlah', 'O'), ('mereka', 'O'), ('dengan', 'O'), ('cara', 'O'), ('yang', 'O'), ('lebih', 'O'), ('baik', 'O'), ('.', 'O')]
# prediction Serulah/O (manusia/Person) ke/O jalan/O (Tuhanmu/Allah) dengan/O hikmah/O dan/O pengajaran/O yang/O baik/O serta/O debatlah/O mereka/O dengan/O cara/O yang/O lebih/O baik/O./O
# Prediction Tokens:
#  [('Serulah', 'O'), ('(manusia', 'Person)'), ('ke', 'O'), ('jalan', 'O'), ('(Tuhanmu', 'Allah)'), ('dengan', 'O'), ('hikmah', 'O'), ('dan', 'O'), ('pengajaran', 'O'), ('yang', 'O'), ('baik', 'O'), ('serta', 'O'), ('debatlah', 'O'), ('mereka', 'O'), ('dengan', 'O'), ('cara', 'O'), ('yang', 'O'), ('lebih', 'O'), ('baik', 'O'), ('.', 'O')]
# correct:
#  [('Serulah', 'O'), ('ke', 'O'), ('jalan', 'O'), ('dengan', 'O'), ('hikmah', 'O'), ('dan', 'O'), ('pengajaran', 'O'), ('yang', 'O'), ('baik', 'O'), ('serta', 'O'), ('debatlah', 'O'), ('mereka', 'O'), ('dengan', 'O'), ('cara', 'O'), ('yang', 'O'), ('lebih', 'O'), ('baik', 'O'), ('.', 'O')]
# Correct: 18, Guessed: 20, Total: 22
# Metrics(tp=18, fp=2, fn=4, prec=0.9, rec=0.8181818181818182, fscore=0.8571428571428572)
# ######### Instance 308 ##############
# Label Tokens:
#  [('Sesungguhnya', 'O'), ('Tuhanmu', 'O'), ('Dialah', 'O'), ('yang', 'O'), ('paling', 'O'), ('tahu', 'O'), ('siapa', 'O'), ('yang', 'O'), ('tersesat', 'O'), ('dari', 'O'), ('jalan-Nya', 'O'), ('dan', 'O'), ('Dia', 'O'), ('(', 'O'), ('pula', 'O'), (')', 'O'), ('yang', 'O'), ('paling', 'O'), ('tahu', 'O'), ('siapa', 'O'), ('yang', 'O'), ('mendapat', 'O'), ('petunjuk', 'O'), ('.', 'O')]
# prediction Sesungguhnya/O Tuhanmu/O Dialah/Allah yang/O paling/O tahu/O siapa/O yang/O tersesat/O dari/O jalan-Nya/O dan/O Dia/O pula/O yang/O paling/O tahu/O siapa/O yang/O mendapat/O petunjuk/O./O
# Prediction Tokens:
#  [('Sesungguhnya', 'O'), ('Tuhanmu', 'O'), ('Dialah', 'Allah'), ('yang', 'O'), ('paling', 'O'), ('tahu', 'O'), ('siapa', 'O'), ('yang', 'O'), ('tersesat', 'O'), ('dari', 'O'), ('jalan-Nya', 'O'), ('dan', 'O'), ('Dia', 'O'), ('pula', 'O'), ('yang', 'O'), ('paling', 'O'), ('tahu', 'O'), ('siapa', 'O'), ('yang', 'O'), ('mendapat', 'O'), ('petunjuk', 'O'), ('.', 'O')]
# correct:
#  [('Sesungguhnya', 'O'), ('Tuhanmu', 'O'), ('yang', 'O'), ('paling', 'O'), ('tahu', 'O'), ('siapa', 'O'), ('yang', 'O'), ('tersesat', 'O'), ('dari', 'O'), ('jalan-Nya', 'O'), ('dan', 'O'), ('Dia', 'O'), ('pula', 'O'), ('yang', 'O'), ('paling', 'O'), ('tahu', 'O'), ('siapa', 'O'), ('yang', 'O'), ('mendapat', 'O'), ('petunjuk', 'O'), ('.', 'O')]
# Correct: 21, Guessed: 22, Total: 24
# Metrics(tp=21, fp=1, fn=3, prec=0.9545454545454546, rec=0.875, fscore=0.9130434782608695)
# ######### Instance 309 ##############
# Label Tokens:
#  [('Jika', 'O'), ('kamu', 'O'), ('membalas', 'O'), (',', 'O'), ('balaslah', 'O'), ('dengan', 'O'), ('(', 'O'), ('balasan', 'O'), (')', 'O'), ('yang', 'O'), ('sama', 'O'), ('dengan', 'O'), ('siksaan', 'O'), ('yang', 'O'), ('ditimpakan', 'O'), ('kepadamu', 'O'), ('.', 'O')]
# prediction Jika/O kamu/O membalas/O,/O balaslah/O dengan/O (/O balasan/O )/O yang/O sama/O dengan/O siksaan/O yang/O ditimpakan/O kepadamu/O./O
# Prediction Tokens:
#  [('Jika', 'O'), ('kamu', 'O'), ('membalas', 'O'), (',', 'O'), ('balaslah', 'O'), ('dengan', 'O'), ('(', 'O'), ('balasan', 'O'), (')', 'O'), ('yang', 'O'), ('sama', 'O'), ('dengan', 'O'), ('siksaan', 'O'), ('yang', 'O'), ('ditimpakan', 'O'), ('kepadamu', 'O'), ('.', 'O')]
# correct:
#  [('Jika', 'O'), ('kamu', 'O'), ('membalas', 'O'), (',', 'O'), ('balaslah', 'O'), ('dengan', 'O'), ('(', 'O'), ('balasan', 'O'), (')', 'O'), ('yang', 'O'), ('sama', 'O'), ('dengan', 'O'), ('siksaan', 'O'), ('yang', 'O'), ('ditimpakan', 'O'), ('kepadamu', 'O'), ('.', 'O')]
# Correct: 17, Guessed: 17, Total: 17
# Metrics(tp=17, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 310 ##############
# Label Tokens:
#  [('Sungguh', 'O'), (',', 'O'), ('jika', 'O'), ('kamu', 'O'), ('bersabar', 'O'), (',', 'O'), ('hal', 'O'), ('itu', 'O'), ('benar-benar', 'O'), ('lebih', 'O'), ('baik', 'O'), ('bagi', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('sabar', 'O'), ('.', 'O')]
# prediction Sungguh/O, jika/O kamu/O bersabar/O, hal/O itu/O benar-benar/O lebih/O baik/O bagi/O orang-orang/O yang/O sabar/O./O
# Prediction Tokens:
#  [('Sungguh', 'O,'), ('jika', 'O'), ('kamu', 'O'), ('bersabar', 'O,'), ('hal', 'O'), ('itu', 'O'), ('benar-benar', 'O'), ('lebih', 'O'), ('baik', 'O'), ('bagi', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('sabar', 'O'), ('.', 'O')]
# correct:
#  [('jika', 'O'), ('kamu', 'O'), ('hal', 'O'), ('itu', 'O'), ('benar-benar', 'O'), ('lebih', 'O'), ('baik', 'O'), ('bagi', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('sabar', 'O'), ('.', 'O')]
# Correct: 12, Guessed: 14, Total: 16
# Metrics(tp=12, fp=2, fn=4, prec=0.8571428571428571, rec=0.75, fscore=0.7999999999999999)
# ######### Instance 311 ##############
# Label Tokens:
#  [('Bersabarlah', 'O'), ('(', 'O'), ('Nabi', 'O'), ('Muhammad', 'Messenger'), (')', 'O'), ('dan', 'O'), ('kesabaranmu', 'O'), ('itu', 'O'), ('semata-mata', 'O'), ('dengan', 'O'), ('(', 'O'), ('pertolongan', 'O'), (')', 'O'), ('Allah', 'Allah'), (',', 'O'), ('janganlah', 'O'), ('bersedih', 'O'), ('terhadap', 'O'), ('(', 'O'), ('kekufuran', 'O'), (')', 'O'), ('mereka', 'O'), (',', 'O'), ('dan', 'O'), ('jangan', 'O'), ('(', 'O'), ('pula', 'O'), (')', 'O'), ('bersempit', 'O'), ('dada', 'O'), ('terhadap', 'O'), ('tipu', 'O'), ('daya', 'O'), ('yang', 'O'), ('mereka', 'O'), ('rencanakan', 'O'), ('.', 'O')]
# prediction Bersabarlah/O (Nabi/O Muhammad/Messenger) dan/O kesabaranmu/O itu/O semata-mata/O dengan/O (pertolongan/Event) Allah/Allah, janganlah/O bersedih/O terhadap/O (kekufuran/Event) mereka,/O dan/O jangan/O (pula/O) bersempit/O dada/O terhadap/O tipu/O daya/O yang/O mereka/O rencanakan/O./O
# Prediction Tokens:
#  [('Bersabarlah', 'O'), ('(Nabi', 'O'), ('Muhammad', 'Messenger)'), ('dan', 'O'), ('kesabaranmu', 'O'), ('itu', 'O'), ('semata-mata', 'O'), ('dengan', 'O'), ('(pertolongan', 'Event)'), ('Allah', 'Allah,'), ('janganlah', 'O'), ('bersedih', 'O'), ('terhadap', 'O'), ('(kekufuran', 'Event)'), ('mereka,', 'O'), ('dan', 'O'), ('jangan', 'O'), ('(pula', 'O)'), ('bersempit', 'O'), ('dada', 'O'), ('terhadap', 'O'), ('tipu', 'O'), ('daya', 'O'), ('yang', 'O'), ('mereka', 'O'), ('rencanakan', 'O'), ('.', 'O')]
# correct:
#  [('Bersabarlah', 'O'), ('dan', 'O'), ('kesabaranmu', 'O'), ('itu', 'O'), ('semata-mata', 'O'), ('dengan', 'O'), ('janganlah', 'O'), ('bersedih', 'O'), ('terhadap', 'O'), ('dan', 'O'), ('jangan', 'O'), ('bersempit', 'O'), ('dada', 'O'), ('terhadap', 'O'), ('tipu', 'O'), ('daya', 'O'), ('yang', 'O'), ('mereka', 'O'), ('rencanakan', 'O'), ('.', 'O')]
# Correct: 20, Guessed: 27, Total: 37
# Metrics(tp=20, fp=7, fn=17, prec=0.7407407407407407, rec=0.5405405405405406, fscore=0.625)
# Total records in the test set: 311
# Average Precision: 0.8526767991995076
# Average Recall: 0.8204375586061858
# Average F1 Score: 0.830821249778022
